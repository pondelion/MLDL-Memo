# %%
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender imageio==2.4.1 atari-py==0.2.6 gym==0.17.3
# !apt-get install x11-utils > /dev/null 2>&1 
# !pip install pyglet > /dev/null 2>&1 
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install ptan pytorch-ignite pybullet
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colabgymrender
#   Downloading colabgymrender-1.1.0.tar.gz (3.5 kB)
# Collecting imageio==2.4.1
#   Downloading imageio-2.4.1.tar.gz (3.3 MB)
#      |████████████████████████████████| 3.3 MB 4.8 MB/s
# Collecting atari-py==0.2.6
#   Downloading atari-py-0.2.6.tar.gz (790 kB)
#      |████████████████████████████████| 790 kB 66.4 MB/s
# Collecting gym==0.17.3
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 45.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from imageio==2.4.1) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from imageio==2.4.1) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from atari-py==0.2.6) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from gym==0.17.3) (1.7.3)
# Collecting pyglet<=1.5.0,>=1.4.0
#   Downloading pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 55.3 MB/s
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (0.16.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.8/dist-packages (from colabgymrender) (0.2.3.5)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.8/dist-packages (from moviepy->colabgymrender) (4.64.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.8/dist-packages (from moviepy->colabgymrender) (4.4.2)
# WARNING: The candidate selected for download or install is a yanked version: 'atari-py' candidate (version 0.2.6 at https://files.pythonhosted.org/packages/43/dd/2721f34a89dc520d2e09363fd23d110a33bbab2399e50fdced6eb2ed2157/atari-py-0.2.6.tar.gz#sha256=6249ad5079b0489e87eb44e65485bb1b07cc1b5af729f1ee52ece749503ceb1d (from https://pypi.org/simple/atari-py/))
# Reason for being yanked: re-release with new wheels
# Building wheels for collected packages: imageio, atari-py, gym, colabgymrender
#   Building wheel for imageio (setup.py) ... done
#   Created wheel for imageio: filename=imageio-2.4.1-py3-none-any.whl size=3303886 sha256=df959185d87e38a0a94fd26eb7105b6d2642de802d5f90fbe9dba3b243356ae2
#   Stored in directory: /root/.cache/pip/wheels/be/7b/04/4d8d56f1d503e5c404f0de6018c0cfa592c71588a39b49e002
#   Building wheel for atari-py (setup.py) ... done
#   Created wheel for atari-py: filename=atari_py-0.2.6-cp38-cp38-linux_x86_64.whl size=3092627 sha256=fabd5444c9a9d65a1fe4e78377af20b7e1530c312a636323cd7ca0fa8e89f864
#   Stored in directory: /root/.cache/pip/wheels/7f/5e/27/2e90b9887063d82ee2f9f8b2f8db76bb2290aa281dc40449c8
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654651 sha256=a78d88c14e48679d42a699ec6180740767a6ee06336b3c33d8f4f6dce9d320f3
#   Stored in directory: /root/.cache/pip/wheels/84/40/e7/14efb9870cfc92ac236d78cb721dce614ddec9666c8a5e0a35
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.1.0-py3-none-any.whl size=3130 sha256=78265f6ec98fb84f8d7ee77f6e814766ff0e7f423be841ab7dab9e3a3e074986
#   Stored in directory: /root/.cache/pip/wheels/e4/d2/e1/cc1c940178ad92438325422b51c3e8c3d927b9ef8381da8840
# Successfully built imageio atari-py gym colabgymrender
# Installing collected packages: imageio, pyglet, gym, colabgymrender, atari-py
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.9.0
#     Uninstalling imageio-2.9.0:
#       Successfully uninstalled imageio-2.9.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Attempting uninstall: atari-py
#     Found existing installation: atari-py 0.2.9
#     Uninstalling atari-py-0.2.9:
#       Successfully uninstalled atari-py-0.2.9
# Successfully installed atari-py-0.2.6 colabgymrender-1.1.0 gym-0.17.3 imageio-2.4.1 pyglet-1.5.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.13).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting piglet
#   Downloading piglet-1.0.0-py2.py3-none-any.whl (2.2 kB)
# Collecting piglet-templates
#   Downloading piglet_templates-1.3.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.0 MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from piglet-templates->piglet) (3.0.9)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.8/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from piglet-templates->piglet) (22.1.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.8/dist-packages (from piglet-templates->piglet) (2.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse->piglet-templates->piglet) (0.38.4)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from astunparse->piglet-templates->piglet) (1.15.0)
# Installing collected packages: piglet-templates, piglet
# Successfully installed piglet-1.0.0 piglet-templates-1.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ptan
#   Downloading ptan-0.7.tar.gz (20 kB)
# Collecting pytorch-ignite
#   Downloading pytorch_ignite-0.4.10-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 6.7 MB/s
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      |████████████████████████████████| 91.7 MB 1.2 MB/s
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp38-cp38-manylinux1_x86_64.whl (776.8 MB)
#      |████████████████████████████████| 776.8 MB 84 bytes/s
# Requirement already satisfied: gym in /usr/local/lib/python3.8/dist-packages (from ptan) (0.17.3)
# Requirement already satisfied: atari-py in /usr/local/lib/python3.8/dist-packages (from ptan) (0.2.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ptan) (1.21.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from ptan) (4.6.0.66)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from torch==1.7.0->ptan) (0.16.0)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.7.0->ptan) (4.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from pytorch-ignite) (21.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from atari-py->ptan) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from gym->ptan) (1.7.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym->ptan) (1.5.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from gym->ptan) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->pytorch-ignite) (3.0.9)
# Building wheels for collected packages: ptan
#   Building wheel for ptan (setup.py) ... done
#   Created wheel for ptan: filename=ptan-0.7-py3-none-any.whl size=23504 sha256=92afbdda79fa78e24d27c8932bf311fce429b81ff002c956e4e83b05b0109cfe
#   Stored in directory: /root/.cache/pip/wheels/4e/c0/b7/67750bb433409ebfe80cefcb7403aec8014372ff47d5efe8fb
# Successfully built ptan
# Installing collected packages: dataclasses, torch, pytorch-ignite, pybullet, ptan
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.0+cu116 requires torch==1.13.0, but you have torch 1.7.0 which is incompatible.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.7.0 which is incompatible.
# Successfully installed dataclasses-0.6 ptan-0.7 pybullet-3.2.5 pytorch-ignite-0.4.10 torch-1.7.0
# Found existing installation: torch 1.7.0
# Uninstalling torch-1.7.0:
#   Successfully uninstalled torch-1.7.0
# Found existing installation: torchvision 0.14.0+cu116
# Uninstalling torchvision-0.14.0+cu116:
#   Successfully uninstalled torchvision-0.14.0+cu116
# Found existing installation: torchaudio 0.13.0+cu116
# Uninstalling torchaudio-0.13.0+cu116:
#   Successfully uninstalled torchaudio-0.13.0+cu116
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.13.1%2Bcu116-cp38-cp38-linux_x86_64.whl (1977.9 MB)
#      |█████████████▌                  | 834.1 MB 1.3 MB/s eta 0:14:24tcmalloc: large alloc 1147494400 bytes == 0x3929a000 @  0x7fed49d0b615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |█████████████████               | 1055.7 MB 28.9 MB/s eta 0:00:32tcmalloc: large alloc 1434370048 bytes == 0x7d8f0000 @  0x7fed49d0b615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |█████████████████████▋          | 1336.2 MB 1.3 MB/s eta 0:08:07tcmalloc: large alloc 1792966656 bytes == 0x2722000 @  0x7fed49d0b615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |███████████████████████████▍    | 1691.1 MB 1.1 MB/s eta 0:04:18tcmalloc: large alloc 2241208320 bytes == 0x6d50a000 @  0x7fed49d0b615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |████████████████████████████████| 1977.9 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1977925632 bytes == 0xf2e6c000 @  0x7fed49d0a1e7 0x4d30a0 0x4d312c 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x4fd8b5 0x49abe4 0x55cd91
# tcmalloc: large alloc 2472411136 bytes == 0x1dd156000 @  0x7fed49d0b615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x4fd8b5 0x49abe4 0x55cd91 0x5d8941 0x4fe318
#      |████████████████████████████████| 1977.9 MB 3.0 kB/s
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.14.1%2Bcu116-cp38-cp38-linux_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 1.3 MB/s
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu116/torchaudio-0.13.1%2Bcu116-cp38-cp38-linux_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 48.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision) (2.10)
# Installing collected packages: torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.13.1+cu116 which is incompatible.
# ptan 0.7 requires torch==1.7.0, but you have torch 1.13.1+cu116 which is incompatible.
# Successfully installed torch-1.13.1+cu116 torchaudio-0.13.1+cu116 torchvision-0.14.1+cu116

# %%
import collections
from typing import Union
import math
import random
from copy import deepcopy
from typing import Optional

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import gym
from gym.spaces import Box
from gym.wrappers import FrameStack
import pybullet_envs
from colabgymrender.recorder import Recorder
from fastprogress import progress_bar as pb
import matplotlib.pyplot as plt

# %%
class NoisyLinear(nn.Linear):

    def __init__(self, in_features, out_features, sigma_init=0.017, bias=True):
        super(NoisyLinear, self).__init__(in_features, out_features, bias=bias)
        w = torch.full((out_features, in_features), sigma_init)
        self._sigma_weight = nn.Parameter(w)
        z = torch.zeros(out_features, in_features)
        self.register_buffer("epsilon_weight", z)
        if bias:
            w = torch.full((out_features,), sigma_init)
            self._sigma_bias = nn.Parameter(w)
            z = torch.zeros(out_features)
            self.register_buffer("epsilon_bias", z)
        self.reset_parameters()

    def reset_parameters(self):
        std = math.sqrt(3 / self.in_features)
        self.weight.data.uniform_(-std, std)
        self.bias.data.uniform_(-std, std)

    def forward(self, input):
        self.epsilon_weight.normal_()
        bias = self.bias
        if bias is not None:
            self.epsilon_bias.normal_()
            bias = bias + self._sigma_bias * \
                   self.epsilon_bias.data
        v = self._sigma_weight * self.epsilon_weight.data + \
            self.weight
        return F.linear(input, v, bias)

# %%
class DDPGCritic(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGCritic, self).__init__()

        self.obs_net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
        )

        self.out_net = nn.Sequential(
            nn.Linear(400 + act_size, 300),
            nn.ReLU(),
            nn.Linear(300, 1)
        )

    def forward(self, x, a):
        obs = self.obs_net(x)
        return self.out_net(torch.cat([obs, a], dim=1))

# %%
class DDPGActor(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGActor, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, act_size),
            nn.Tanh()
        )

    def forward(self, x):
        return self.net(x)

# %%
class NStepPriorityReplayBuffer:

    def __init__(
        self,
        max_size: int,
        prob_alpha: float = 0.6,
        beta_start: float = 0.4,
        beta_frames: float = 100000,
        n_step: int = 4,
        gamma: float = 0.99,
    ):
        self._prob_alpha = prob_alpha
        self._max_size = max_size
        self._pos = 0
        self._buf = []
        self._priorities = np.zeros((max_size,), dtype=np.float32)
        self._beta_start = beta_start
        self._beta = beta_start
        self._beta_frames = beta_frames
        self._n_step = n_step
        self._gamma = gamma
        self._total_discounted_rewards = np.array([np.nan]*max_size)
        self._last_states = [np.nan]*max_size

    def update_bata(self, idx) -> None:
        beta = self._beta_start + idx * (1.0 - self._beta_start) / self._beta_frames
        self._beta = min(1.0, beta)
        return self._beta

    def __len__(self):
        return len(self._buf)

    def append(
        self,
        state: np.ndarray,
        action: int,
        reward: Union[int, float],
        done: bool,
        next_state: np.ndarray,
    ) -> None:
        max_prio = self._priorities.max() if self._buf else 1.0
        if len(self._buf) < self._max_size:
            self._buf.append(
                (state, action, reward, done, next_state)
            )
        else:
            self._buf[self._pos] = (state, action, reward, done, next_state)
        self._priorities[self._pos] = max_prio

        if len(self._buf) >= self._n_step:
            dis_r = 0.0
            last_state = self._buf[self._pos][0]
            for i in range(self._n_step):
                state, _, r, done, _ = self._buf[self._pos - i]
                dis_r = r + self._gamma * dis_r
                if done:
                    last_state = state
                self._total_discounted_rewards[self._pos - i] = dis_r
                self._last_states[self._pos - i] = last_state
            
            for i in range(self._n_step-1):
                done = self._buf[self._pos - i][3]
                if done:
                    break
                self._total_discounted_rewards[self._pos - i] = np.nan
                self._last_states[self._pos - i] = np.nan

        self._pos = (self._pos + 1) % self._max_size

    def sample(self, size: int):
        sample_target_indices = np.where(~np.isnan(self._total_discounted_rewards[:len(self._buf)]))[0]
        # prios = self._priorities[sample_target_indices]  #self._priorities if len(self._buf) == self._max_size else self._priorities[:self._pos]
        prios = self._priorities
        probs = prios * self._prob_alpha
        # probs /= np.nan_to_num(probs, 0.0).sum()
        probs /= probs[sample_target_indices].sum()
        sampled_indices = np.random.choice(
            sample_target_indices,
            # np.where(~np.isnan(self._total_discounted_rewards[:len(self._buf)]))[0],
            size, p=probs[sample_target_indices]
        )
        states, actions, rewards, dones, next_states = zip(*[self._buf[idx] for idx in sampled_indices])
        states = np.array(states)
        actions = np.array(actions)
        rewards = np.array(rewards)
        dones = np.array(dones)
        next_states = np.array(next_states)
        total_discounted_rewards = self._total_discounted_rewards[sampled_indices]
        last_states = np.stack([self._last_states[idx] for idx in sampled_indices])
        total = len(self._buf)
        weights = np.array((total * probs[sampled_indices]) ** (-self._beta), dtype=np.float32)
        # weights = np.array((total * probs) ** (-self._beta), dtype=np.float32)
        weights /= weights.max()
        return states, actions, rewards, dones, total_discounted_rewards, last_states, sampled_indices, weights

    def update_priorities(self, sample_indices: np.ndarray, sample_priorities: np.ndarray) -> None:
        self._priorities[sample_indices] = sample_priorities

    @property
    def gamma(self) -> float:
        return self._gamma

    @property
    def n_step(self) -> float:
        return self._n_step

# %%
class Agent:

    def __init__(
        self,
        env,
        exp_buffer: NStepPriorityReplayBuffer,
        act_net: nn.Module,
        crt_net: nn.Module,
        epsilon_start: float = 1.0,
        epsilon_final: float = 0.01,
        epsilon_decay_last_step: int = 200000,
        tgt_sync_steps: int = 10000,
        learning_rate: float = 1e-4,
        adam_eps: float = None,
        device: str = 'cuda' if torch.cuda.is_available() else 'cpu'
    ):
        self._env = env
        self._exp_buffer = exp_buffer
        self._act_net = act_net
        self._crt_net = crt_net
        self._tgt_act_net = deepcopy(act_net)
        self._tgt_crt_net = deepcopy(crt_net)
        for p in self._tgt_act_net.parameters():
            p.requires_grad = False
        for p in self._tgt_crt_net.parameters():
            p.requires_grad = False
        self._epsilon_start = epsilon_start
        self._epsilon_final = epsilon_final
        self._epsilon_decay_last_step = epsilon_decay_last_step
        self._epsilon = epsilon_start
        self._device = device
        self._total_step = 0
        self._total_trained_samples = 0
        self._tgt_sync_steps = tgt_sync_steps
        adam_kwargs = {}
        if adam_eps is not None:
            adam_kwargs['eps'] = adam_eps
        self._crt_optimizer = torch.optim.Adam(self._crt_net.parameters(), lr=learning_rate, **adam_kwargs)
        self._act_optimizer = torch.optim.Adam(self._act_net.parameters(), lr=learning_rate, **adam_kwargs)
        self._reset_episode()

    def _reset_episode(self):
        self._state = self._env.reset()
        self._total_reward = 0.0

    @torch.no_grad()
    def play_step(self, epsilon: Optional[float] = None, sync_target: bool = True):
        if epsilon is None:
            epsilon = self._epsilon
        done_reward = None

        if np.random.random() < epsilon:
            action = self._env.action_space.sample()
        else:
            state_a = np.array([self._state], copy=False)
            state_v = torch.tensor(state_a).float().to(self._device)
            mu_v = self._act_net(state_v)
            action = mu_v.squeeze(dim=0).data.cpu().numpy()
            action = np.clip(action, -1, 1)

        next_state, reward, is_done, _ = self._env.step(action)
        self._total_reward += reward

        self._exp_buffer.append(
            self._state, action, reward, is_done, next_state
        )
        self._state = next_state
        if is_done:
            done_reward = self._total_reward
            self._reset_episode()

        self._total_step += 1
        self._update_epsilon(self._total_step)
        self._exp_buffer.update_bata(self._total_step)

        # if self._total_step % self._tgt_sync_steps == 0 and sync_target:
        #     self._alpha_sync(self._act_net, self._tgt_act_net, alpha=1 - 1e-3)
        #     self._alpha_sync(self._crt_net, self._tgt_crt_net, alpha=1 - 1e-3)
        #     print(f'synced target net')

        return done_reward

    def train(self, n_iter: int = 1, batch_size: int = 32) -> None:
        n_step_gamma = self._exp_buffer.gamma ** self._exp_buffer.n_step
        for i in range(n_iter):
            states, actions, rewards, dones, total_discounted_rewards, \
                last_states, sampled_indices, weights = self._exp_buffer.sample(batch_size)
            states_v = torch.tensor(states).float().to(self._device)
            actions_v = torch.tensor(actions).to(self._device)
            discounted_rewards_v = torch.tensor(total_discounted_rewards).to(self._device)
            done_mask = torch.BoolTensor(dones).to(self._device)
            weights_v = torch.tensor(weights).to(self._device)
            last_states_v = torch.tensor(last_states).float().to(self._device)

            # train critic
            self._crt_optimizer.zero_grad()
            q_v = self._crt_net(states_v, actions_v)
            last_act_v = self._tgt_act_net(last_states_v)
            q_last_v = self._tgt_crt_net(last_states_v, last_act_v)
            q_last_v[done_mask] = 0.0
            q_ref_v = discounted_rewards_v.unsqueeze(dim=-1) + \
                        q_last_v * n_step_gamma
            # q_ref_v = discounted_rewards_v + q_last_v * n_step_gamma
            critic_loss_v = F.mse_loss(q_v.float(), q_ref_v.float().detach())
            critic_loss_v.backward()
            self._crt_optimizer.step()

            # train actor
            self._act_optimizer.zero_grad()
            cur_actions_v = self._act_net(states_v)
            actor_loss_v = -self._crt_net(states_v, cur_actions_v)
            actor_loss_v = actor_loss_v.mean()
            actor_loss_v.backward()
            self._act_optimizer.step()

            self._alpha_sync(self._act_net, self._tgt_act_net, alpha=1 - 1e-3)
            self._alpha_sync(self._crt_net, self._tgt_crt_net, alpha=1 - 1e-3)

            # self._exp_buffer.update_priorities(sampled_indices, prios)
            self._total_trained_samples += batch_size

    def initial_exploration(self, n_steps: int = 10000, epsilon: float = 1.0) -> None:
        eps_bak = self._epsilon
        try:
            for i in pb(range(n_steps)):
                self._epsilon = epsilon
                self.play_step(sync_target=False)
        finally:
            self._total_step = 0
            self._epsilon = eps_bak

    def _update_epsilon(self, step_index: int) -> None:
        self._epsilon = max(
            self._epsilon_final,
            self._epsilon_start - step_index / self._epsilon_decay_last_step
        )

    def _sync(self, net, tgt_net):
        tgt_net.load_state_dict(net.state_dict())

    def _alpha_sync(self, net, tgt_net, alpha):
        assert isinstance(alpha, float)
        assert 0.0 < alpha <= 1.0
        state = net.state_dict()
        tgt_state = tgt_net.state_dict()
        for k, v in state.items():
            tgt_state[k] = tgt_state[k] * alpha + (1 - alpha) * v
        tgt_net.load_state_dict(tgt_state)

# %%
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = False
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return obs, total_reward, done, info


class GrayScaleObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        obs_shape = self.observation_space.shape[:2]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def permute_orientation(self, observation):
        print(observation.shape)
        observation = np.transpose(observation, (2, 0, 1))
        observation = torch.tensor(observation.copy(), dtype=torch.float)
        return observation

    def observation(self, observation):
        observation = self.permute_orientation(observation)
        transform = T.Grayscale()
        observation = transform(observation)
        return observation


class ResizeObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        super().__init__(env)
        if isinstance(shape, int):
            self.shape = (shape, shape)
        else:
            self.shape = tuple(shape)

        obs_shape = self.shape + self.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        transforms = T.Compose(
            [T.Resize(self.shape), T.Normalize(0, 255)]
        )
        observation = transforms(observation).squeeze(0)
        return observation


class LazyFramesToNumpy(gym.ObservationWrapper):
    def __init__(self, env):
        super(LazyFramesToNumpy, self).__init__(env)

    def observation(self, observation):
        return observation.__array__()

# %%
SEED = 77

# %%
random.seed(SEED)
torch.manual_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# !rm -rf /content/video

env = gym.make("MinitaurBulletEnv-v0")
# env = SkipFrame(env, skip=4)
# env = GrayScaleObservation(env)
# env = ResizeObservation(env, shape=224)
# env = FrameStack(env, num_stack=4)
# env = LazyFramesToNumpy(env)
directory = './video'
# env = Recorder(env, directory)
# Out:
# urdf_root=/usr/local/lib/python3.8/dist-packages/pybullet_data

# %%
env.observation_space.shape, env.action_space
# Out:
# ((28,), Box(-1.0, 1.0, (8,), float32))

# %%
env.action_space.sample()
# Out:
# array([-0.8341588 , -0.7444319 , -0.8518454 , -0.36063766, -0.59968734,
#         0.36393377, -0.19871397,  0.57056695], dtype=float32)

# %%
state = env.reset()

# %%
state
# Out:
# array([ 1.50347167e+00,  1.49345370e+00,  1.49832819e+00,  1.49064648e+00,
#         1.50536190e+00,  1.50923600e+00,  1.50500672e+00,  1.50608901e+00,
#         6.40519842e-01,  6.47282536e-01,  6.59688347e-01,  6.64291650e-01,
#         5.56672518e-01,  5.42466522e-01,  5.74675669e-01,  5.59422781e-01,
#         4.41218854e-01,  5.21378915e-01,  4.80078117e-01,  5.41632601e-01,
#         4.37156256e-01,  4.08011548e-01,  4.37387937e-01,  4.30968607e-01,
#        -1.04792965e-03,  1.02313633e-03, -2.65745175e-04,  9.99998892e-01])

# %%
act_net = DDPGActor(
    env.observation_space.shape[0],
    env.action_space.shape[0]).to(device)
crt_net = DDPGCritic(
    env.observation_space.shape[0],
    env.action_space.shape[0]).to(device)

# %%
act_net
# Out:
# DDPGActor(
#   (net): Sequential(
#     (0): Linear(in_features=28, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=8, bias=True)
#     (5): Tanh()
#   )
# )

# %%
exp_buffer = NStepPriorityReplayBuffer(
    max_size=30000,
    prob_alpha=0.6,
    beta_start=0.4,
    beta_frames=30000, #100000,
    n_step=2,
    gamma=0.99,
)
agent = Agent(
    env=env,
    exp_buffer=exp_buffer,
    crt_net=crt_net,
    act_net=act_net,
    epsilon_start=0.6,
    epsilon_final=0.002,
    epsilon_decay_last_step=30000, #200000,
    tgt_sync_steps=1000,
    learning_rate=1e-4,
    device=device
)

# %%
torch.tensor(state).unsqueeze(0).to(device).float()
# Out:
# tensor([[ 1.5035e+00,  1.4935e+00,  1.4983e+00,  1.4906e+00,  1.5054e+00,
#           1.5092e+00,  1.5050e+00,  1.5061e+00,  6.4052e-01,  6.4728e-01,
#           6.5969e-01,  6.6429e-01,  5.5667e-01,  5.4247e-01,  5.7468e-01,
#           5.5942e-01,  4.4122e-01,  5.2138e-01,  4.8008e-01,  5.4163e-01,
#           4.3716e-01,  4.0801e-01,  4.3739e-01,  4.3097e-01, -1.0479e-03,
#           1.0231e-03, -2.6575e-04,  1.0000e+00]])

# %%
act_net(torch.tensor(state).unsqueeze(0).float().to(device))
# Out:
# tensor([[-0.0153,  0.1402,  0.1065,  0.1975,  0.0655, -0.1678, -0.0566,  0.1452]],
#        grad_fn=<TanhBackward0>)

# %%
crt_net(
    torch.tensor(state).unsqueeze(0).float().to(device),
    act_net(torch.tensor(state).unsqueeze(0).float().to(device))
)
# Out:
# tensor([[-0.0607]], grad_fn=<AddmmBackward0>)

# %%
agent.initial_exploration(n_steps=10000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 01:24&lt;00:00]
#     </div>

# %%
# !rm -rf /content/video/*

# %%
episode = 0

while True:

    for stp in range(20):
        done_reward = agent.play_step()
        if done_reward is not None:
            print(f'episode : {episode}, done reward : {done_reward}, total_step : {agent._total_step}, cur_epsilon : {agent._epsilon}')
            episode += 1
    
    agent.train(n_iter=20, batch_size=32)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# episode : 15491, done reward : 7.19029525020631, total_step : 1664109, cur_epsilon : 0.002
# episode : 15492, done reward : 1.1205969503731883, total_step : 1664257, cur_epsilon : 0.002
# episode : 15493, done reward : 1.5770994272552301, total_step : 1664444, cur_epsilon : 0.002
# episode : 15494, done reward : 2.483479184636427, total_step : 1664716, cur_epsilon : 0.002
# episode : 15495, done reward : 1.7819490854713296, total_step : 1664933, cur_epsilon : 0.002
# episode : 15496, done reward : 8.835673940938314, total_step : 1665671, cur_epsilon : 0.002
# episode : 15497, done reward : 1.102849894935035, total_step : 1665816, cur_epsilon : 0.002
# episode : 15498, done reward : 0.21336969414905183, total_step : 1665864, cur_epsilon : 0.002
# episode : 15499, done reward : 0.2055622566395502, total_step : 1665909, cur_epsilon : 0.002
# episode : 15500, done reward : 0.4768498071069902, total_step : 1665978, cur_epsilon : 0.002
# episode : 15501, done reward : 0.7570788590633205, total_step : 1666076, cur_epsilon : 0.002
# episode : 15502, done reward : 1.7713715438060396, total_step : 1666278, cur_epsilon : 0.002
# episode : 15503, done reward : 0.22810862399301013, total_step : 1666323, cur_epsilon : 0.002
# episode : 15504, done reward : 11.014265542712945, total_step : 1667182, cur_epsilon : 0.002
# episode : 15505, done reward : 1.426008182934639, total_step : 1667344, cur_epsilon : 0.002
# episode : 15506, done reward : 0.4493769579080343, total_step : 1667539, cur_epsilon : 0.002
# episode : 15507, done reward : 0.14776570048266965, total_step : 1667577, cur_epsilon : 0.002
# episode : 15508, done reward : 2.302377265017658, total_step : 1667836, cur_epsilon : 0.002
# episode : 15509, done reward : 2.282331875089542, total_step : 1668836, cur_epsilon : 0.002
# episode : 15510, done reward : 0.3041740284167215, total_step : 1668886, cur_epsilon : 0.002
# episode : 15511, done reward : 1.7837286475317997, total_step : 1669100, cur_epsilon : 0.002
# episode : 15512, done reward : 0.38942323160323894, total_step : 1669234, cur_epsilon : 0.002
# episode : 15513, done reward : 0.6363272911794552, total_step : 1669430, cur_epsilon : 0.002
# episode : 15514, done reward : 1.1031015732391136, total_step : 1669568, cur_epsilon : 0.002
# episode : 15515, done reward : 0.8402773309490931, total_step : 1669686, cur_epsilon : 0.002
# episode : 15516, done reward : 11.121690204803787, total_step : 1670686, cur_epsilon : 0.002
# episode : 15517, done reward : 10.067075517235129, total_step : 1671686, cur_epsilon : 0.002
# episode : 15518, done reward : 1.1794362562429823, total_step : 1671863, cur_epsilon : 0.002
# episode : 15519, done reward : 10.445218555949625, total_step : 1672863, cur_epsilon : 0.002
# episode : 15520, done reward : 7.818632523638559, total_step : 1673680, cur_epsilon : 0.002
# episode : 15521, done reward : 0.17275736129127414, total_step : 1673724, cur_epsilon : 0.002
# episode : 15522, done reward : 0.16327656937076993, total_step : 1673762, cur_epsilon : 0.002
# episode : 15523, done reward : 0.5721047233209076, total_step : 1673888, cur_epsilon : 0.002
# episode : 15524, done reward : 1.658516753152479, total_step : 1674210, cur_epsilon : 0.002
# episode : 15525, done reward : 10.972062675273941, total_step : 1675210, cur_epsilon : 0.002
# episode : 15526, done reward : 0.9336577675068299, total_step : 1675413, cur_epsilon : 0.002
# episode : 15527, done reward : 1.7909283186887834, total_step : 1675862, cur_epsilon : 0.002
# episode : 15528, done reward : 5.170263746054137, total_step : 1676504, cur_epsilon : 0.002
# episode : 15529, done reward : 10.157267902469592, total_step : 1677504, cur_epsilon : 0.002
# episode : 15530, done reward : 0.7457003291746174, total_step : 1677708, cur_epsilon : 0.002
# episode : 15531, done reward : 4.00637416220391, total_step : 1678148, cur_epsilon : 0.002
# episode : 15532, done reward : 2.511986267746347, total_step : 1678616, cur_epsilon : 0.002
# episode : 15533, done reward : 2.171538742341101, total_step : 1678846, cur_epsilon : 0.002
# episode : 15534, done reward : 0.6748669415898396, total_step : 1678937, cur_epsilon : 0.002
# episode : 15535, done reward : 0.3002267756081818, total_step : 1678986, cur_epsilon : 0.002
# episode : 15536, done reward : 0.7851042121674974, total_step : 1679111, cur_epsilon : 0.002
# episode : 15537, done reward : 0.4082152859569157, total_step : 1679203, cur_epsilon : 0.002
# episode : 15538, done reward : 0.1651858914584783, total_step : 1679248, cur_epsilon : 0.002
# episode : 15539, done reward : 3.748245444298765, total_step : 1679665, cur_epsilon : 0.002
# episode : 15540, done reward : 1.0085818130560609, total_step : 1679818, cur_epsilon : 0.002
# episode : 15541, done reward : 0.4220459441379539, total_step : 1679960, cur_epsilon : 0.002
# episode : 15542, done reward : 8.947294861579506, total_step : 1680871, cur_epsilon : 0.002
# episode : 15543, done reward : 9.306114557170302, total_step : 1681646, cur_epsilon : 0.002
# episode : 15544, done reward : 8.462693820091364, total_step : 1682646, cur_epsilon : 0.002
# episode : 15545, done reward : 2.93835186076237, total_step : 1682967, cur_epsilon : 0.002
# episode : 15546, done reward : 3.9609737727829626, total_step : 1683310, cur_epsilon : 0.002
# episode : 15547, done reward : 1.656315362243505, total_step : 1683515, cur_epsilon : 0.002
# episode : 15548, done reward : 12.793595331499338, total_step : 1684515, cur_epsilon : 0.002
# episode : 15549, done reward : 7.460818999571117, total_step : 1685151, cur_epsilon : 0.002
# episode : 15550, done reward : 6.359277111463124, total_step : 1686151, cur_epsilon : 0.002
# episode : 15551, done reward : 0.518341814661176, total_step : 1686241, cur_epsilon : 0.002
# episode : 15552, done reward : 0.4439164629089909, total_step : 1686325, cur_epsilon : 0.002
# episode : 15553, done reward : 9.860452497770844, total_step : 1687325, cur_epsilon : 0.002
# episode : 15554, done reward : 1.3275520295010237, total_step : 1687530, cur_epsilon : 0.002
# episode : 15555, done reward : 6.335843787417338, total_step : 1688174, cur_epsilon : 0.002
# episode : 15556, done reward : 0.3056020693807845, total_step : 1688226, cur_epsilon : 0.002
# episode : 15557, done reward : 0.6114529507416663, total_step : 1688343, cur_epsilon : 0.002
# episode : 15558, done reward : 10.766826773910743, total_step : 1689343, cur_epsilon : 0.002
# episode : 15559, done reward : 0.556889820828268, total_step : 1689471, cur_epsilon : 0.002
# episode : 15560, done reward : 1.83890857685151, total_step : 1689778, cur_epsilon : 0.002
# episode : 15561, done reward : 5.64750142481402, total_step : 1690347, cur_epsilon : 0.002
# episode : 15562, done reward : 7.87944600466264, total_step : 1691265, cur_epsilon : 0.002
# episode : 15563, done reward : 1.418428488451189, total_step : 1691461, cur_epsilon : 0.002
# episode : 15564, done reward : 2.987738379940417, total_step : 1691736, cur_epsilon : 0.002
# episode : 15565, done reward : 0.7802773773706977, total_step : 1691879, cur_epsilon : 0.002
# episode : 15566, done reward : 0.9797750652885496, total_step : 1692005, cur_epsilon : 0.002
# episode : 15567, done reward : 4.415203438669469, total_step : 1692636, cur_epsilon : 0.002
# episode : 15568, done reward : 1.7143966100550474, total_step : 1692867, cur_epsilon : 0.002
# episode : 15569, done reward : 1.2458558468871541, total_step : 1693021, cur_epsilon : 0.002
# episode : 15570, done reward : 1.8594206655205134, total_step : 1693224, cur_epsilon : 0.002
# episode : 15571, done reward : 2.3167547469809593, total_step : 1693520, cur_epsilon : 0.002
# episode : 15572, done reward : 0.5314386066118959, total_step : 1693624, cur_epsilon : 0.002
# episode : 15573, done reward : 0.8223298133488335, total_step : 1693738, cur_epsilon : 0.002
# episode : 15574, done reward : 0.2797388859429569, total_step : 1693797, cur_epsilon : 0.002
# episode : 15575, done reward : 2.8757128493564625, total_step : 1694172, cur_epsilon : 0.002
# episode : 15576, done reward : 1.3373646879157657, total_step : 1694329, cur_epsilon : 0.002
# episode : 15577, done reward : 0.4497282537897228, total_step : 1694395, cur_epsilon : 0.002
# episode : 15578, done reward : 0.6310302963564631, total_step : 1694510, cur_epsilon : 0.002
# episode : 15579, done reward : 11.042069394878697, total_step : 1695510, cur_epsilon : 0.002
# episode : 15580, done reward : 0.23251195169746644, total_step : 1695557, cur_epsilon : 0.002
# episode : 15581, done reward : 10.881414004627638, total_step : 1696523, cur_epsilon : 0.002
# episode : 15582, done reward : 3.3987665653676644, total_step : 1696813, cur_epsilon : 0.002
# episode : 15583, done reward : 0.9896566098470385, total_step : 1696990, cur_epsilon : 0.002
# episode : 15584, done reward : 5.084179679474144, total_step : 1697424, cur_epsilon : 0.002
# episode : 15585, done reward : 10.142145012131275, total_step : 1698329, cur_epsilon : 0.002
# episode : 15586, done reward : 0.36544204673391106, total_step : 1698393, cur_epsilon : 0.002
# episode : 15587, done reward : 0.22481899991808754, total_step : 1698443, cur_epsilon : 0.002
# episode : 15588, done reward : 2.8911308045301047, total_step : 1698769, cur_epsilon : 0.002
# episode : 15589, done reward : 7.343297845322153, total_step : 1699491, cur_epsilon : 0.002
# episode : 15590, done reward : 11.102900106373555, total_step : 1700491, cur_epsilon : 0.002
# episode : 15591, done reward : 2.877172823375322, total_step : 1700915, cur_epsilon : 0.002
# episode : 15592, done reward : 2.184551594599377, total_step : 1701237, cur_epsilon : 0.002
# episode : 15593, done reward : 8.20430268476609, total_step : 1702146, cur_epsilon : 0.002
# episode : 15594, done reward : 0.3233381154584286, total_step : 1702203, cur_epsilon : 0.002
# episode : 15595, done reward : 12.597170366639, total_step : 1703203, cur_epsilon : 0.002
# episode : 15596, done reward : 13.751938165087635, total_step : 1704203, cur_epsilon : 0.002
# episode : 15597, done reward : 0.2961194196648858, total_step : 1704259, cur_epsilon : 0.002
# episode : 15598, done reward : 0.3874612220781487, total_step : 1704318, cur_epsilon : 0.002
# episode : 15599, done reward : 0.1963528484905064, total_step : 1704362, cur_epsilon : 0.002
# episode : 15600, done reward : 0.6971724562930085, total_step : 1704476, cur_epsilon : 0.002
# episode : 15601, done reward : 11.158543867846987, total_step : 1705297, cur_epsilon : 0.002
# episode : 15602, done reward : 0.47728138477664994, total_step : 1705448, cur_epsilon : 0.002
# episode : 15603, done reward : 0.3751318932984467, total_step : 1705508, cur_epsilon : 0.002
# episode : 15604, done reward : 0.28123003697306953, total_step : 1705558, cur_epsilon : 0.002
# episode : 15605, done reward : 0.3544347278096376, total_step : 1705615, cur_epsilon : 0.002
# episode : 15606, done reward : 0.30212399045611954, total_step : 1706615, cur_epsilon : 0.002
# episode : 15607, done reward : 0.6455764837484977, total_step : 1706803, cur_epsilon : 0.002
# episode : 15608, done reward : 0.2186958575931561, total_step : 1706849, cur_epsilon : 0.002
# episode : 15609, done reward : 0.5358295840109293, total_step : 1706922, cur_epsilon : 0.002
# episode : 15610, done reward : 0.6839741062539944, total_step : 1707077, cur_epsilon : 0.002
# episode : 15611, done reward : 0.28942080924709124, total_step : 1707130, cur_epsilon : 0.002
# episode : 15612, done reward : 0.8129619681383816, total_step : 1707836, cur_epsilon : 0.002
# episode : 15613, done reward : 6.940642651664792, total_step : 1708713, cur_epsilon : 0.002
# episode : 15614, done reward : 0.2762687976401103, total_step : 1708764, cur_epsilon : 0.002
# episode : 15615, done reward : 0.2310042439410117, total_step : 1708808, cur_epsilon : 0.002
# episode : 15616, done reward : 0.5412929148731181, total_step : 1708903, cur_epsilon : 0.002
# episode : 15617, done reward : 0.4111440053100727, total_step : 1708965, cur_epsilon : 0.002
# episode : 15618, done reward : 9.32420821264314, total_step : 1709965, cur_epsilon : 0.002
# episode : 15619, done reward : 0.37599600824702856, total_step : 1710031, cur_epsilon : 0.002
# episode : 15620, done reward : 11.000874501506894, total_step : 1711031, cur_epsilon : 0.002
# episode : 15621, done reward : 7.910440704547077, total_step : 1711795, cur_epsilon : 0.002
# episode : 15622, done reward : 0.2677501422888893, total_step : 1711844, cur_epsilon : 0.002
# episode : 15623, done reward : 0.6376855075697883, total_step : 1712005, cur_epsilon : 0.002
# episode : 15624, done reward : 0.3251210737586339, total_step : 1712057, cur_epsilon : 0.002
# episode : 15625, done reward : 0.3243130826206401, total_step : 1712113, cur_epsilon : 0.002
# episode : 15626, done reward : 0.5719455731764175, total_step : 1712240, cur_epsilon : 0.002
# episode : 15627, done reward : 8.602440611978029, total_step : 1713128, cur_epsilon : 0.002
# episode : 15628, done reward : 0.280270607223752, total_step : 1713178, cur_epsilon : 0.002
# episode : 15629, done reward : 0.6369145013086767, total_step : 1713344, cur_epsilon : 0.002
# episode : 15630, done reward : 0.3875145801802566, total_step : 1713405, cur_epsilon : 0.002
# episode : 15631, done reward : 12.769044115450882, total_step : 1714405, cur_epsilon : 0.002
# episode : 15632, done reward : 0.305770073566961, total_step : 1714458, cur_epsilon : 0.002
# episode : 15633, done reward : 0.453100168511153, total_step : 1714529, cur_epsilon : 0.002
# episode : 15634, done reward : 0.24152813933834597, total_step : 1714585, cur_epsilon : 0.002
# episode : 15635, done reward : 0.21307762739358077, total_step : 1714640, cur_epsilon : 0.002
# episode : 15636, done reward : 0.1797775510791602, total_step : 1714684, cur_epsilon : 0.002
# episode : 15637, done reward : 0.226624890921984, total_step : 1714731, cur_epsilon : 0.002
# episode : 15638, done reward : 14.646011752104284, total_step : 1715731, cur_epsilon : 0.002
# episode : 15639, done reward : 9.029990693313195, total_step : 1716587, cur_epsilon : 0.002
# episode : 15640, done reward : 0.6413761872004335, total_step : 1716776, cur_epsilon : 0.002
# episode : 15641, done reward : 13.473330617776556, total_step : 1717776, cur_epsilon : 0.002
# episode : 15642, done reward : 0.36948323199307953, total_step : 1717895, cur_epsilon : 0.002
# episode : 15643, done reward : 13.897180177579354, total_step : 1718895, cur_epsilon : 0.002
# episode : 15644, done reward : 1.912792145662171, total_step : 1719336, cur_epsilon : 0.002
# episode : 15645, done reward : 4.600063612216575, total_step : 1719854, cur_epsilon : 0.002
# episode : 15646, done reward : 10.0819090279328, total_step : 1720854, cur_epsilon : 0.002
# episode : 15647, done reward : 0.23183645835217637, total_step : 1720900, cur_epsilon : 0.002
# episode : 15648, done reward : 2.1435608293793793, total_step : 1721166, cur_epsilon : 0.002
# episode : 15649, done reward : 0.5303607251080223, total_step : 1721280, cur_epsilon : 0.002
# episode : 15650, done reward : 0.4026825905636926, total_step : 1721345, cur_epsilon : 0.002
# episode : 15651, done reward : 0.2071862268138545, total_step : 1721390, cur_epsilon : 0.002
# episode : 15652, done reward : 10.247378027980442, total_step : 1722362, cur_epsilon : 0.002
# episode : 15653, done reward : 7.213934629207076, total_step : 1722926, cur_epsilon : 0.002
# episode : 15654, done reward : 1.7503033523004026, total_step : 1723126, cur_epsilon : 0.002
# episode : 15655, done reward : 3.685062759996906, total_step : 1723789, cur_epsilon : 0.002
# episode : 15656, done reward : 1.2368997452887502, total_step : 1723958, cur_epsilon : 0.002
# episode : 15657, done reward : 4.16101216615307, total_step : 1724421, cur_epsilon : 0.002
# episode : 15658, done reward : 10.461372104754703, total_step : 1725421, cur_epsilon : 0.002
# episode : 15659, done reward : 0.09668354932163636, total_step : 1725463, cur_epsilon : 0.002
# episode : 15660, done reward : 6.455604024512124, total_step : 1726040, cur_epsilon : 0.002
# episode : 15661, done reward : 0.2673377938189092, total_step : 1726183, cur_epsilon : 0.002
# episode : 15662, done reward : 0.12418292533829722, total_step : 1726227, cur_epsilon : 0.002
# episode : 15663, done reward : 13.382690112757917, total_step : 1727178, cur_epsilon : 0.002
# episode : 15664, done reward : 0.8902735098086116, total_step : 1727313, cur_epsilon : 0.002
# episode : 15665, done reward : 1.375825642501634, total_step : 1727491, cur_epsilon : 0.002
# episode : 15666, done reward : 11.955689488949576, total_step : 1728448, cur_epsilon : 0.002
# episode : 15667, done reward : 0.12546033235619555, total_step : 1728494, cur_epsilon : 0.002
# episode : 15668, done reward : 2.696284540735219, total_step : 1728839, cur_epsilon : 0.002
# episode : 15669, done reward : 6.529042417980798, total_step : 1729571, cur_epsilon : 0.002
# episode : 15670, done reward : 0.0962086453356922, total_step : 1729610, cur_epsilon : 0.002
# episode : 15671, done reward : 1.5425863821600505, total_step : 1729795, cur_epsilon : 0.002
# episode : 15672, done reward : 6.567098880030009, total_step : 1730378, cur_epsilon : 0.002
# episode : 15673, done reward : 2.9513877742216725, total_step : 1730690, cur_epsilon : 0.002
# episode : 15674, done reward : 0.4804228120114944, total_step : 1730760, cur_epsilon : 0.002
# episode : 15675, done reward : 1.0485866031331195, total_step : 1730952, cur_epsilon : 0.002
# episode : 15676, done reward : 0.23972591321831122, total_step : 1731007, cur_epsilon : 0.002
# episode : 15677, done reward : 0.8184727219823901, total_step : 1731138, cur_epsilon : 0.002
# episode : 15678, done reward : 0.10817991099984142, total_step : 1731183, cur_epsilon : 0.002
# episode : 15679, done reward : 1.6256474445969427, total_step : 1731405, cur_epsilon : 0.002
# episode : 15680, done reward : 0.11477341243895219, total_step : 1731449, cur_epsilon : 0.002
# episode : 15681, done reward : 0.9354766871142155, total_step : 1731572, cur_epsilon : 0.002
# episode : 15682, done reward : 2.5995301707001808, total_step : 1731858, cur_epsilon : 0.002
# episode : 15683, done reward : 0.9195280754533134, total_step : 1732071, cur_epsilon : 0.002
# episode : 15684, done reward : 4.371066212566946, total_step : 1732535, cur_epsilon : 0.002
# episode : 15685, done reward : 0.9015176111428379, total_step : 1732670, cur_epsilon : 0.002
# episode : 15686, done reward : 0.13350671564331282, total_step : 1732718, cur_epsilon : 0.002
# episode : 15687, done reward : 7.649911078302052, total_step : 1733356, cur_epsilon : 0.002
# episode : 15688, done reward : 12.544427201586856, total_step : 1734313, cur_epsilon : 0.002
# episode : 15689, done reward : 2.51672434999054, total_step : 1734605, cur_epsilon : 0.002
# episode : 15690, done reward : 3.159612397773111, total_step : 1734901, cur_epsilon : 0.002
# episode : 15691, done reward : 9.974040529569177, total_step : 1735640, cur_epsilon : 0.002
# episode : 15692, done reward : 0.5599937837756258, total_step : 1735767, cur_epsilon : 0.002
# episode : 15693, done reward : 9.446297248443292, total_step : 1736502, cur_epsilon : 0.002
# episode : 15694, done reward : 3.096623275864051, total_step : 1736781, cur_epsilon : 0.002
# episode : 15695, done reward : 3.507077686248092, total_step : 1737129, cur_epsilon : 0.002
# episode : 15696, done reward : 1.654187963447071, total_step : 1737354, cur_epsilon : 0.002
# episode : 15697, done reward : 0.43462540664832333, total_step : 1737498, cur_epsilon : 0.002
# episode : 15698, done reward : 0.7233599910548735, total_step : 1737612, cur_epsilon : 0.002
# episode : 15699, done reward : 0.7689084922225907, total_step : 1737740, cur_epsilon : 0.002
# episode : 15700, done reward : 1.1138614596200216, total_step : 1737886, cur_epsilon : 0.002
# episode : 15701, done reward : 0.6869291270643757, total_step : 1737994, cur_epsilon : 0.002
# episode : 15702, done reward : 9.87039604734058, total_step : 1738867, cur_epsilon : 0.002
# episode : 15703, done reward : 1.5968910546181618, total_step : 1739037, cur_epsilon : 0.002
# episode : 15704, done reward : 0.15355153216453277, total_step : 1739077, cur_epsilon : 0.002
# episode : 15705, done reward : 0.11009802916229627, total_step : 1739118, cur_epsilon : 0.002
# episode : 15706, done reward : 9.942628164082688, total_step : 1739913, cur_epsilon : 0.002
# episode : 15707, done reward : 2.5083996845542913, total_step : 1740195, cur_epsilon : 0.002
# episode : 15708, done reward : 3.992256671216095, total_step : 1740539, cur_epsilon : 0.002
# episode : 15709, done reward : 0.9841920475536098, total_step : 1740915, cur_epsilon : 0.002
# episode : 15710, done reward : 1.1800678135527862, total_step : 1741168, cur_epsilon : 0.002
# episode : 15711, done reward : 0.34895812289706246, total_step : 1741264, cur_epsilon : 0.002
# episode : 15712, done reward : 4.000780618393692, total_step : 1741598, cur_epsilon : 0.002
# episode : 15713, done reward : 4.6747449396463026, total_step : 1742070, cur_epsilon : 0.002
# episode : 15714, done reward : 3.24200611151816, total_step : 1742451, cur_epsilon : 0.002
# episode : 15715, done reward : 1.8145672056187552, total_step : 1742668, cur_epsilon : 0.002
# episode : 15716, done reward : 3.5298425363007757, total_step : 1743045, cur_epsilon : 0.002
# episode : 15717, done reward : 13.082437465914941, total_step : 1744032, cur_epsilon : 0.002
# episode : 15718, done reward : 1.9235874627530338, total_step : 1744289, cur_epsilon : 0.002
# episode : 15719, done reward : 2.3231673366127623, total_step : 1744531, cur_epsilon : 0.002
# episode : 15720, done reward : 0.8012578639284095, total_step : 1744659, cur_epsilon : 0.002
# episode : 15721, done reward : 1.3972033265566375, total_step : 1744808, cur_epsilon : 0.002
# episode : 15722, done reward : 0.09280074206150692, total_step : 1744853, cur_epsilon : 0.002
# episode : 15723, done reward : 0.12234714897001764, total_step : 1744895, cur_epsilon : 0.002
# episode : 15724, done reward : 5.883208839992268, total_step : 1745408, cur_epsilon : 0.002
# episode : 15725, done reward : 8.84968394463595, total_step : 1746217, cur_epsilon : 0.002
# episode : 15726, done reward : 0.10208580464965888, total_step : 1746262, cur_epsilon : 0.002
# episode : 15727, done reward : 2.4628772750608485, total_step : 1746551, cur_epsilon : 0.002
# episode : 15728, done reward : 2.6611724152262073, total_step : 1746788, cur_epsilon : 0.002
# episode : 15729, done reward : 1.0857857323102351, total_step : 1746972, cur_epsilon : 0.002
# episode : 15730, done reward : 1.1964927179456355, total_step : 1747239, cur_epsilon : 0.002
# episode : 15731, done reward : 3.1354424403285286, total_step : 1747546, cur_epsilon : 0.002
# episode : 15732, done reward : 0.17561423797765463, total_step : 1747592, cur_epsilon : 0.002
# episode : 15733, done reward : 0.4016745141996586, total_step : 1747681, cur_epsilon : 0.002
# episode : 15734, done reward : 2.365512843709951, total_step : 1747991, cur_epsilon : 0.002
# episode : 15735, done reward : 1.502813957804782, total_step : 1748153, cur_epsilon : 0.002
# episode : 15736, done reward : 0.1266378726009467, total_step : 1748223, cur_epsilon : 0.002
# episode : 15737, done reward : 3.5466178878010464, total_step : 1748573, cur_epsilon : 0.002
# episode : 15738, done reward : 1.4147082415574113, total_step : 1748792, cur_epsilon : 0.002
# episode : 15739, done reward : 12.853800518878488, total_step : 1749792, cur_epsilon : 0.002
# episode : 15740, done reward : 4.377601771049477, total_step : 1750232, cur_epsilon : 0.002
# episode : 15741, done reward : 0.13627342439391474, total_step : 1750280, cur_epsilon : 0.002
# episode : 15742, done reward : 0.18426239995784338, total_step : 1750337, cur_epsilon : 0.002
# episode : 15743, done reward : 0.8728483320607454, total_step : 1750485, cur_epsilon : 0.002
# episode : 15744, done reward : 10.6885991721533, total_step : 1751485, cur_epsilon : 0.002
# episode : 15745, done reward : 2.0350227931048304, total_step : 1751767, cur_epsilon : 0.002
# episode : 15746, done reward : 7.339640936566787, total_step : 1752554, cur_epsilon : 0.002
# episode : 15747, done reward : 0.8259521807208944, total_step : 1752672, cur_epsilon : 0.002
# episode : 15748, done reward : 5.34698924694768, total_step : 1753131, cur_epsilon : 0.002
# episode : 15749, done reward : 7.323643161664729, total_step : 1753791, cur_epsilon : 0.002
# episode : 15750, done reward : 12.488827552467088, total_step : 1754791, cur_epsilon : 0.002
# episode : 15751, done reward : 0.19902909702030103, total_step : 1754837, cur_epsilon : 0.002
# episode : 15752, done reward : 0.15757230487006404, total_step : 1754875, cur_epsilon : 0.002
# episode : 15753, done reward : 0.1349399790960518, total_step : 1754910, cur_epsilon : 0.002
# episode : 15754, done reward : 0.16837944611662437, total_step : 1754948, cur_epsilon : 0.002
# episode : 15755, done reward : 0.16194123770548546, total_step : 1754988, cur_epsilon : 0.002
# episode : 15756, done reward : 0.16206194070817576, total_step : 1755025, cur_epsilon : 0.002
# episode : 15757, done reward : 0.16612398128758615, total_step : 1755065, cur_epsilon : 0.002
# episode : 15758, done reward : 0.1746340164227247, total_step : 1755106, cur_epsilon : 0.002
# episode : 15759, done reward : 0.20377532392325923, total_step : 1755149, cur_epsilon : 0.002
# episode : 15760, done reward : 0.22358135887522468, total_step : 1755196, cur_epsilon : 0.002
# episode : 15761, done reward : 0.1164775916941607, total_step : 1755234, cur_epsilon : 0.002
# episode : 15762, done reward : 2.035703648234429, total_step : 1755515, cur_epsilon : 0.002
# episode : 15763, done reward : 11.699738007404742, total_step : 1756515, cur_epsilon : 0.002
# episode : 15764, done reward : 0.15233554483566505, total_step : 1756552, cur_epsilon : 0.002
# episode : 15765, done reward : 0.14111847346157178, total_step : 1756589, cur_epsilon : 0.002
# episode : 15766, done reward : 0.13431953257058496, total_step : 1756623, cur_epsilon : 0.002
# episode : 15767, done reward : 0.16994571442689121, total_step : 1756661, cur_epsilon : 0.002
# episode : 15768, done reward : 0.18247378222751626, total_step : 1756704, cur_epsilon : 0.002
# episode : 15769, done reward : 0.15981258250798602, total_step : 1756742, cur_epsilon : 0.002
# episode : 15770, done reward : 3.4979770417526987, total_step : 1757129, cur_epsilon : 0.002
# episode : 15771, done reward : 0.15883867400519208, total_step : 1757167, cur_epsilon : 0.002
# episode : 15772, done reward : 0.15632192426793395, total_step : 1757201, cur_epsilon : 0.002
# episode : 15773, done reward : 2.1089931480463746, total_step : 1757530, cur_epsilon : 0.002
# episode : 15774, done reward : 0.1891314932674148, total_step : 1757571, cur_epsilon : 0.002
# episode : 15775, done reward : 7.8902627134542715, total_step : 1758342, cur_epsilon : 0.002
# episode : 15776, done reward : 0.18463823330598045, total_step : 1758382, cur_epsilon : 0.002
# episode : 15777, done reward : 0.16959334921777908, total_step : 1758421, cur_epsilon : 0.002
# episode : 15778, done reward : 0.15080315809544342, total_step : 1758457, cur_epsilon : 0.002
# episode : 15779, done reward : 0.20387363644286616, total_step : 1758499, cur_epsilon : 0.002
# episode : 15780, done reward : 0.15696325865836913, total_step : 1758536, cur_epsilon : 0.002
# episode : 15781, done reward : 0.14726687070783823, total_step : 1758571, cur_epsilon : 0.002
# episode : 15782, done reward : 0.17076129268975038, total_step : 1758610, cur_epsilon : 0.002
# episode : 15783, done reward : 0.21244004137339853, total_step : 1758652, cur_epsilon : 0.002
# episode : 15784, done reward : 0.1672083331447929, total_step : 1758691, cur_epsilon : 0.002
# episode : 15785, done reward : 0.18705149963167184, total_step : 1758729, cur_epsilon : 0.002
# episode : 15786, done reward : 1.081310848467545, total_step : 1758897, cur_epsilon : 0.002
# episode : 15787, done reward : 0.20043572821161823, total_step : 1758940, cur_epsilon : 0.002
# episode : 15788, done reward : 0.4944794152958798, total_step : 1759062, cur_epsilon : 0.002
# episode : 15789, done reward : 1.1908927297755567, total_step : 1759203, cur_epsilon : 0.002
# episode : 15790, done reward : 0.3226851269535519, total_step : 1759329, cur_epsilon : 0.002
# episode : 15791, done reward : 0.2600179900539894, total_step : 1759388, cur_epsilon : 0.002
# episode : 15792, done reward : 1.2466437961435548, total_step : 1759568, cur_epsilon : 0.002
# episode : 15793, done reward : 0.26932057019452477, total_step : 1759622, cur_epsilon : 0.002
# episode : 15794, done reward : 0.27730328206286026, total_step : 1759685, cur_epsilon : 0.002
# episode : 15795, done reward : 3.4545048756628045, total_step : 1760027, cur_epsilon : 0.002
# episode : 15796, done reward : 4.3557010009301464, total_step : 1760459, cur_epsilon : 0.002
# episode : 15797, done reward : 0.22982112397440987, total_step : 1760505, cur_epsilon : 0.002
# episode : 15798, done reward : 0.1612898205339559, total_step : 1760544, cur_epsilon : 0.002
# episode : 15799, done reward : 0.24056301934275506, total_step : 1760593, cur_epsilon : 0.002
# episode : 15800, done reward : 0.18417561624763007, total_step : 1760636, cur_epsilon : 0.002
# episode : 15801, done reward : 0.23031033834087195, total_step : 1760681, cur_epsilon : 0.002
# episode : 15802, done reward : 12.478371976494495, total_step : 1761666, cur_epsilon : 0.002
# episode : 15803, done reward : 0.21094863603949854, total_step : 1761706, cur_epsilon : 0.002
# episode : 15804, done reward : 0.1104089641115744, total_step : 1761742, cur_epsilon : 0.002
# episode : 15805, done reward : 0.12015970728676566, total_step : 1761776, cur_epsilon : 0.002
# episode : 15806, done reward : 0.1459423002108478, total_step : 1761813, cur_epsilon : 0.002
# episode : 15807, done reward : 0.12685593541218626, total_step : 1761847, cur_epsilon : 0.002
# episode : 15808, done reward : 0.14418351556469083, total_step : 1761881, cur_epsilon : 0.002
# episode : 15809, done reward : 0.14422971751682823, total_step : 1761918, cur_epsilon : 0.002
# episode : 15810, done reward : 0.12201710618991736, total_step : 1761953, cur_epsilon : 0.002
# episode : 15811, done reward : 0.14238904650661455, total_step : 1761987, cur_epsilon : 0.002
# episode : 15812, done reward : 0.13100731806138807, total_step : 1762023, cur_epsilon : 0.002
# episode : 15813, done reward : 0.15642349911091766, total_step : 1762061, cur_epsilon : 0.002
# episode : 15814, done reward : 0.11400189366666524, total_step : 1762094, cur_epsilon : 0.002
# episode : 15815, done reward : 0.15667437757532332, total_step : 1762131, cur_epsilon : 0.002
# episode : 15816, done reward : 0.16210327404028002, total_step : 1762169, cur_epsilon : 0.002
# episode : 15817, done reward : 0.15795216289129144, total_step : 1762205, cur_epsilon : 0.002
# episode : 15818, done reward : 0.2921260365588017, total_step : 1762276, cur_epsilon : 0.002
# episode : 15819, done reward : 2.392450711245041, total_step : 1762522, cur_epsilon : 0.002
# episode : 15820, done reward : 0.17590167998242864, total_step : 1762564, cur_epsilon : 0.002
# episode : 15821, done reward : 0.16593329710462382, total_step : 1762605, cur_epsilon : 0.002
# episode : 15822, done reward : 0.12169790662093462, total_step : 1762641, cur_epsilon : 0.002
# episode : 15823, done reward : 10.01030057960913, total_step : 1763641, cur_epsilon : 0.002
# episode : 15824, done reward : 0.12963290168427966, total_step : 1763684, cur_epsilon : 0.002
# episode : 15825, done reward : 0.12454623472423168, total_step : 1763719, cur_epsilon : 0.002
# episode : 15826, done reward : 0.12984372898482796, total_step : 1763754, cur_epsilon : 0.002
# episode : 15827, done reward : 0.1921746876418266, total_step : 1763798, cur_epsilon : 0.002
# episode : 15828, done reward : 0.143829745955093, total_step : 1763838, cur_epsilon : 0.002
# episode : 15829, done reward : 0.13606963636799793, total_step : 1763877, cur_epsilon : 0.002
# episode : 15830, done reward : 0.1348755248953312, total_step : 1763917, cur_epsilon : 0.002
# episode : 15831, done reward : 0.10549543091982973, total_step : 1763949, cur_epsilon : 0.002
# episode : 15832, done reward : 2.9717116578151557, total_step : 1764272, cur_epsilon : 0.002
# episode : 15833, done reward : 0.1568481765347781, total_step : 1764315, cur_epsilon : 0.002
# episode : 15834, done reward : 0.14500392120507805, total_step : 1764352, cur_epsilon : 0.002
# episode : 15835, done reward : 0.16358879795492587, total_step : 1764395, cur_epsilon : 0.002
# episode : 15836, done reward : 0.09659262922366735, total_step : 1764429, cur_epsilon : 0.002
# episode : 15837, done reward : 0.1265168517847584, total_step : 1764466, cur_epsilon : 0.002
# episode : 15838, done reward : 0.15435172077537876, total_step : 1764508, cur_epsilon : 0.002
# episode : 15839, done reward : 0.1118028737219839, total_step : 1764542, cur_epsilon : 0.002
# episode : 15840, done reward : 0.13321093064504455, total_step : 1764578, cur_epsilon : 0.002
# episode : 15841, done reward : 0.20114371496721686, total_step : 1764620, cur_epsilon : 0.002
# episode : 15842, done reward : 0.1707039550543157, total_step : 1764660, cur_epsilon : 0.002
# episode : 15843, done reward : 0.13119840587710901, total_step : 1764696, cur_epsilon : 0.002
# episode : 15844, done reward : 0.16611245086841525, total_step : 1764735, cur_epsilon : 0.002
# episode : 15845, done reward : 0.13774988250592832, total_step : 1764773, cur_epsilon : 0.002
# episode : 15846, done reward : 0.13705120413590954, total_step : 1764810, cur_epsilon : 0.002
# episode : 15847, done reward : 0.16722287923644077, total_step : 1764850, cur_epsilon : 0.002
# episode : 15848, done reward : 0.10591669123933149, total_step : 1764883, cur_epsilon : 0.002
# episode : 15849, done reward : 0.14904586345270396, total_step : 1764924, cur_epsilon : 0.002
# episode : 15850, done reward : 0.11115205167886333, total_step : 1764959, cur_epsilon : 0.002
# episode : 15851, done reward : 0.11991473077533527, total_step : 1764995, cur_epsilon : 0.002
# episode : 15852, done reward : 0.16120739571152412, total_step : 1765033, cur_epsilon : 0.002
# episode : 15853, done reward : 0.062410797761757064, total_step : 1765063, cur_epsilon : 0.002
# episode : 15854, done reward : 0.1002741210407504, total_step : 1765098, cur_epsilon : 0.002
# episode : 15855, done reward : 0.08212708990641039, total_step : 1765127, cur_epsilon : 0.002
# episode : 15856, done reward : 0.15369936279663693, total_step : 1765164, cur_epsilon : 0.002
# episode : 15857, done reward : 0.1119339203830358, total_step : 1765195, cur_epsilon : 0.002
# episode : 15858, done reward : 0.11731706544509943, total_step : 1765229, cur_epsilon : 0.002
# episode : 15859, done reward : 0.1014868015498911, total_step : 1765261, cur_epsilon : 0.002
# episode : 15860, done reward : 0.0749819056344806, total_step : 1765294, cur_epsilon : 0.002
# episode : 15861, done reward : 0.07864599819268278, total_step : 1765325, cur_epsilon : 0.002
# episode : 15862, done reward : 0.13371551377598906, total_step : 1765361, cur_epsilon : 0.002
# episode : 15863, done reward : 0.07456532663847446, total_step : 1765388, cur_epsilon : 0.002
# episode : 15864, done reward : 0.13571817537997416, total_step : 1765424, cur_epsilon : 0.002
# episode : 15865, done reward : 0.1241331227660856, total_step : 1765459, cur_epsilon : 0.002
# episode : 15866, done reward : 0.09119743283223149, total_step : 1765490, cur_epsilon : 0.002
# episode : 15867, done reward : 0.10586115359860641, total_step : 1765520, cur_epsilon : 0.002
# episode : 15868, done reward : 6.2681079631884025, total_step : 1766026, cur_epsilon : 0.002
# episode : 15869, done reward : 0.09150768708458214, total_step : 1766057, cur_epsilon : 0.002
# episode : 15870, done reward : 0.150249759531964, total_step : 1766096, cur_epsilon : 0.002
# episode : 15871, done reward : 0.13954202567525995, total_step : 1766138, cur_epsilon : 0.002
# episode : 15872, done reward : 0.12311041517481194, total_step : 1766171, cur_epsilon : 0.002
# episode : 15873, done reward : 0.1695317337705236, total_step : 1766212, cur_epsilon : 0.002
# episode : 15874, done reward : 0.10134879078782402, total_step : 1766243, cur_epsilon : 0.002
# episode : 15875, done reward : 0.09572592659540313, total_step : 1766273, cur_epsilon : 0.002
# episode : 15876, done reward : 0.15649607383086594, total_step : 1766310, cur_epsilon : 0.002
# episode : 15877, done reward : 0.09111957978401006, total_step : 1766342, cur_epsilon : 0.002
# episode : 15878, done reward : 0.07168638963279249, total_step : 1766370, cur_epsilon : 0.002
# episode : 15879, done reward : 0.08898171210177355, total_step : 1766403, cur_epsilon : 0.002
# episode : 15880, done reward : 0.09205427063418097, total_step : 1766436, cur_epsilon : 0.002
# episode : 15881, done reward : 0.1489989217850848, total_step : 1766475, cur_epsilon : 0.002
# episode : 15882, done reward : 0.19154269732280457, total_step : 1766518, cur_epsilon : 0.002
# episode : 15883, done reward : 0.13543192857920694, total_step : 1766553, cur_epsilon : 0.002
# episode : 15884, done reward : 0.11325165871977355, total_step : 1766586, cur_epsilon : 0.002
# episode : 15885, done reward : 0.11105058836768794, total_step : 1766618, cur_epsilon : 0.002
# episode : 15886, done reward : 0.1493599764055024, total_step : 1766656, cur_epsilon : 0.002
# episode : 15887, done reward : 0.13414859080649277, total_step : 1766691, cur_epsilon : 0.002
# episode : 15888, done reward : 0.1508728209562514, total_step : 1766729, cur_epsilon : 0.002
# episode : 15889, done reward : 0.0764537225869069, total_step : 1766758, cur_epsilon : 0.002
# episode : 15890, done reward : 0.13097933474994328, total_step : 1766797, cur_epsilon : 0.002
# episode : 15891, done reward : 0.0785142472128701, total_step : 1766825, cur_epsilon : 0.002
# episode : 15892, done reward : 0.08603475305679247, total_step : 1766857, cur_epsilon : 0.002
# episode : 15893, done reward : 0.10398816841789389, total_step : 1766888, cur_epsilon : 0.002
# episode : 15894, done reward : 0.059372618613809935, total_step : 1766917, cur_epsilon : 0.002
# episode : 15895, done reward : 0.18314788633472193, total_step : 1766961, cur_epsilon : 0.002
# episode : 15896, done reward : 0.10677481750359777, total_step : 1766997, cur_epsilon : 0.002
# episode : 15897, done reward : 0.09287083481337569, total_step : 1767031, cur_epsilon : 0.002
# episode : 15898, done reward : 0.09560497132707554, total_step : 1767062, cur_epsilon : 0.002
# episode : 15899, done reward : 0.10845237275689171, total_step : 1767095, cur_epsilon : 0.002
# episode : 15900, done reward : 0.1029269367485571, total_step : 1767127, cur_epsilon : 0.002
# episode : 15901, done reward : 0.09942458419991337, total_step : 1767160, cur_epsilon : 0.002
# episode : 15902, done reward : 0.08981923057333321, total_step : 1767192, cur_epsilon : 0.002
# episode : 15903, done reward : 0.12000342388632407, total_step : 1767226, cur_epsilon : 0.002
# episode : 15904, done reward : 0.11058937448704263, total_step : 1767259, cur_epsilon : 0.002
# episode : 15905, done reward : 0.12250111977923346, total_step : 1767290, cur_epsilon : 0.002
# episode : 15906, done reward : 0.11057616549675361, total_step : 1767322, cur_epsilon : 0.002
# episode : 15907, done reward : 0.059726054167054995, total_step : 1767350, cur_epsilon : 0.002
# episode : 15908, done reward : 0.11264553779423805, total_step : 1767384, cur_epsilon : 0.002
# episode : 15909, done reward : 0.08704341939175435, total_step : 1767417, cur_epsilon : 0.002
# episode : 15910, done reward : 0.15320531476194185, total_step : 1767453, cur_epsilon : 0.002
# episode : 15911, done reward : 0.07617223244575334, total_step : 1767484, cur_epsilon : 0.002
# episode : 15912, done reward : 0.08571708191798143, total_step : 1767512, cur_epsilon : 0.002
# episode : 15913, done reward : 0.1033782994921387, total_step : 1767545, cur_epsilon : 0.002
# episode : 15914, done reward : 0.13778452068105845, total_step : 1767581, cur_epsilon : 0.002
# episode : 15915, done reward : 0.08333488945194949, total_step : 1767610, cur_epsilon : 0.002
# episode : 15916, done reward : 0.07444394906241342, total_step : 1767641, cur_epsilon : 0.002
# episode : 15917, done reward : 0.09300594826867116, total_step : 1767669, cur_epsilon : 0.002
# episode : 15918, done reward : 0.11202303606565686, total_step : 1767703, cur_epsilon : 0.002
# episode : 15919, done reward : 0.599164289365241, total_step : 1767788, cur_epsilon : 0.002
# episode : 15920, done reward : 0.14849884532591495, total_step : 1767826, cur_epsilon : 0.002
# episode : 15921, done reward : 0.08629075501601999, total_step : 1767856, cur_epsilon : 0.002
# episode : 15922, done reward : 0.06980815862541097, total_step : 1767887, cur_epsilon : 0.002
# episode : 15923, done reward : 0.1841190294356013, total_step : 1767932, cur_epsilon : 0.002
# episode : 15924, done reward : 0.16382180476255095, total_step : 1767973, cur_epsilon : 0.002
# episode : 15925, done reward : 0.1163987455808112, total_step : 1768009, cur_epsilon : 0.002
# episode : 15926, done reward : 11.578520476245352, total_step : 1769009, cur_epsilon : 0.002
# episode : 15927, done reward : 0.08141726472166835, total_step : 1769036, cur_epsilon : 0.002
# episode : 15928, done reward : 0.12515491748494542, total_step : 1769071, cur_epsilon : 0.002
# episode : 15929, done reward : 0.1649567093768341, total_step : 1769110, cur_epsilon : 0.002
# episode : 15930, done reward : 0.18483595692934, total_step : 1769152, cur_epsilon : 0.002
# episode : 15931, done reward : 0.20235563258448785, total_step : 1769195, cur_epsilon : 0.002
# episode : 15932, done reward : 0.15261950886461473, total_step : 1769235, cur_epsilon : 0.002
# episode : 15933, done reward : 0.2636131088105436, total_step : 1769286, cur_epsilon : 0.002
# episode : 15934, done reward : 0.09946448240490682, total_step : 1769318, cur_epsilon : 0.002
# episode : 15935, done reward : 0.1514563236185396, total_step : 1769354, cur_epsilon : 0.002
# episode : 15936, done reward : 0.14265067822679026, total_step : 1769391, cur_epsilon : 0.002
# episode : 15937, done reward : 0.12587959618970426, total_step : 1769424, cur_epsilon : 0.002
# episode : 15938, done reward : 0.1262855542679714, total_step : 1769461, cur_epsilon : 0.002
# episode : 15939, done reward : 0.12518434894275773, total_step : 1769492, cur_epsilon : 0.002
# episode : 15940, done reward : 0.12317834900810368, total_step : 1769530, cur_epsilon : 0.002
# episode : 15941, done reward : 0.10819217747558203, total_step : 1769560, cur_epsilon : 0.002
# episode : 15942, done reward : 0.10653302707738178, total_step : 1769590, cur_epsilon : 0.002
# episode : 15943, done reward : 0.12979128577306748, total_step : 1769623, cur_epsilon : 0.002
# episode : 15944, done reward : 0.17273833278667916, total_step : 1769667, cur_epsilon : 0.002
# episode : 15945, done reward : 0.14939949849501238, total_step : 1769702, cur_epsilon : 0.002
# episode : 15946, done reward : 0.1347953217388855, total_step : 1769734, cur_epsilon : 0.002
# episode : 15947, done reward : 0.10521475980781708, total_step : 1769764, cur_epsilon : 0.002
# episode : 15948, done reward : 0.14205076079454498, total_step : 1769797, cur_epsilon : 0.002
# episode : 15949, done reward : 0.17463593526782387, total_step : 1769838, cur_epsilon : 0.002
# episode : 15950, done reward : 0.10530890477045309, total_step : 1769870, cur_epsilon : 0.002
# episode : 15951, done reward : 0.518048379650142, total_step : 1769950, cur_epsilon : 0.002
# episode : 15952, done reward : 0.09757394694601529, total_step : 1769982, cur_epsilon : 0.002
# episode : 15953, done reward : 0.11961541408656473, total_step : 1770015, cur_epsilon : 0.002
# episode : 15954, done reward : 0.11143785625339599, total_step : 1770047, cur_epsilon : 0.002
# episode : 15955, done reward : 0.1435321630047881, total_step : 1770080, cur_epsilon : 0.002
# episode : 15956, done reward : 0.13952887913601847, total_step : 1770114, cur_epsilon : 0.002
# episode : 15957, done reward : 0.11562869967555887, total_step : 1770149, cur_epsilon : 0.002
# episode : 15958, done reward : 0.15202920579465762, total_step : 1770184, cur_epsilon : 0.002
# episode : 15959, done reward : 0.12382300745850719, total_step : 1770216, cur_epsilon : 0.002
# episode : 15960, done reward : 0.1465601436841711, total_step : 1770251, cur_epsilon : 0.002
# episode : 15961, done reward : 0.12894503697412993, total_step : 1770289, cur_epsilon : 0.002
# episode : 15962, done reward : 0.13377438722791274, total_step : 1770321, cur_epsilon : 0.002
# episode : 15963, done reward : 0.14416111771742784, total_step : 1770354, cur_epsilon : 0.002
# episode : 15964, done reward : 0.11292183518793954, total_step : 1770387, cur_epsilon : 0.002
# episode : 15965, done reward : 0.11931822510691399, total_step : 1770420, cur_epsilon : 0.002
# episode : 15966, done reward : 0.11777236969352581, total_step : 1770452, cur_epsilon : 0.002
# episode : 15967, done reward : 0.15020738362565875, total_step : 1770491, cur_epsilon : 0.002
# episode : 15968, done reward : 0.1827228338998503, total_step : 1770529, cur_epsilon : 0.002
# episode : 15969, done reward : 0.17539625348816268, total_step : 1770568, cur_epsilon : 0.002
# episode : 15970, done reward : 0.1017222135509562, total_step : 1770597, cur_epsilon : 0.002
# episode : 15971, done reward : 0.10909139991017557, total_step : 1770629, cur_epsilon : 0.002
# episode : 15972, done reward : 0.13785742661544378, total_step : 1770661, cur_epsilon : 0.002
# episode : 15973, done reward : 0.08519421728220984, total_step : 1770689, cur_epsilon : 0.002
# episode : 15974, done reward : 0.09987604044662347, total_step : 1770719, cur_epsilon : 0.002
# episode : 15975, done reward : 0.10511811028559145, total_step : 1770749, cur_epsilon : 0.002
# episode : 15976, done reward : 0.09913093272962549, total_step : 1770783, cur_epsilon : 0.002
# episode : 15977, done reward : 0.11773269544993095, total_step : 1770815, cur_epsilon : 0.002
# episode : 15978, done reward : 0.09963711494727338, total_step : 1770846, cur_epsilon : 0.002
# episode : 15979, done reward : 0.09522550976542557, total_step : 1770881, cur_epsilon : 0.002
# episode : 15980, done reward : 0.09337702349640845, total_step : 1770912, cur_epsilon : 0.002
# episode : 15981, done reward : 0.08333041996472838, total_step : 1770941, cur_epsilon : 0.002
# episode : 15982, done reward : 0.10087689021260583, total_step : 1770969, cur_epsilon : 0.002
# episode : 15983, done reward : 0.1375949548522803, total_step : 1771006, cur_epsilon : 0.002
# episode : 15984, done reward : 0.1054916807732201, total_step : 1771042, cur_epsilon : 0.002
# episode : 15985, done reward : 0.10907021778530529, total_step : 1771073, cur_epsilon : 0.002
# episode : 15986, done reward : 0.10431303111160285, total_step : 1771107, cur_epsilon : 0.002
# episode : 15987, done reward : 0.11687004021036337, total_step : 1771139, cur_epsilon : 0.002
# episode : 15988, done reward : 0.3644833866095787, total_step : 1771226, cur_epsilon : 0.002
# episode : 15989, done reward : 0.10737516682313249, total_step : 1771259, cur_epsilon : 0.002
# episode : 15990, done reward : 0.13735864322629002, total_step : 1771290, cur_epsilon : 0.002
# episode : 15991, done reward : 0.11531956612974581, total_step : 1771323, cur_epsilon : 0.002
# episode : 15992, done reward : 0.09429590468832787, total_step : 1771352, cur_epsilon : 0.002
# episode : 15993, done reward : 0.12933314219130285, total_step : 1771385, cur_epsilon : 0.002
# episode : 15994, done reward : 0.12064633394207294, total_step : 1771417, cur_epsilon : 0.002
# episode : 15995, done reward : 0.09904517983873536, total_step : 1771449, cur_epsilon : 0.002
# episode : 15996, done reward : 0.10126872194263815, total_step : 1771481, cur_epsilon : 0.002
# episode : 15997, done reward : 0.13627728883372847, total_step : 1771516, cur_epsilon : 0.002
# episode : 15998, done reward : 0.08027053062958593, total_step : 1771546, cur_epsilon : 0.002
# episode : 15999, done reward : 0.13718466869283022, total_step : 1771579, cur_epsilon : 0.002
# episode : 16000, done reward : 0.12335565315139702, total_step : 1771610, cur_epsilon : 0.002
# episode : 16001, done reward : 0.08888240853059531, total_step : 1771641, cur_epsilon : 0.002
# episode : 16002, done reward : 0.12518625500616495, total_step : 1771673, cur_epsilon : 0.002
# episode : 16003, done reward : 0.13676983175863006, total_step : 1771707, cur_epsilon : 0.002
# episode : 16004, done reward : 0.12637576263372302, total_step : 1771742, cur_epsilon : 0.002
# ...
# episode : 20319, done reward : 13.58516508679268, total_step : 2538807, cur_epsilon : 0.002
# episode : 20320, done reward : 4.921111252364728, total_step : 2539295, cur_epsilon : 0.002
# episode : 20321, done reward : 3.6432401987588485, total_step : 2539636, cur_epsilon : 0.002
# episode : 20322, done reward : 3.5857648804082003, total_step : 2539923, cur_epsilon : 0.002
# episode : 20323, done reward : 10.937193007037807, total_step : 2540923, cur_epsilon : 0.002
# episode : 20324, done reward : 1.5556282868230438, total_step : 2541088, cur_epsilon : 0.002
# episode : 20325, done reward : 5.5017899410740565, total_step : 2541539, cur_epsilon : 0.002
# episode : 20326, done reward : 3.993130036246646, total_step : 2541901, cur_epsilon : 0.002
# episode : 20327, done reward : 3.4319243483186472, total_step : 2542248, cur_epsilon : 0.002
# episode : 20328, done reward : 8.256995264652254, total_step : 2542968, cur_epsilon : 0.002
# episode : 20329, done reward : 11.57468113876471, total_step : 2543968, cur_epsilon : 0.002
# episode : 20330, done reward : 2.721003130667332, total_step : 2544249, cur_epsilon : 0.002
# episode : 20331, done reward : 11.247466215514354, total_step : 2545249, cur_epsilon : 0.002
# episode : 20332, done reward : 3.100018927892565, total_step : 2545490, cur_epsilon : 0.002
# episode : 20333, done reward : 9.915764940771954, total_step : 2546490, cur_epsilon : 0.002
# episode : 20334, done reward : 9.792886118380387, total_step : 2547490, cur_epsilon : 0.002
# episode : 20335, done reward : 4.529297012001184, total_step : 2547847, cur_epsilon : 0.002
# episode : 20336, done reward : 2.4925181186890346, total_step : 2548097, cur_epsilon : 0.002
# episode : 20337, done reward : 13.283752505360432, total_step : 2549097, cur_epsilon : 0.002
# episode : 20338, done reward : 6.636259258516058, total_step : 2549590, cur_epsilon : 0.002
# episode : 20339, done reward : 9.70471653089306, total_step : 2550299, cur_epsilon : 0.002
# episode : 20340, done reward : 0.8709902284913276, total_step : 2550414, cur_epsilon : 0.002
# episode : 20341, done reward : 10.44992455976331, total_step : 2551414, cur_epsilon : 0.002
# episode : 20342, done reward : 2.854405707785751, total_step : 2551646, cur_epsilon : 0.002
# episode : 20343, done reward : 2.812777279108785, total_step : 2551873, cur_epsilon : 0.002
# episode : 20344, done reward : 13.58217922436454, total_step : 2552873, cur_epsilon : 0.002
# episode : 20345, done reward : 6.249821853626319, total_step : 2553423, cur_epsilon : 0.002
# episode : 20346, done reward : 2.2166428508696643, total_step : 2553627, cur_epsilon : 0.002
# episode : 20347, done reward : 6.080467278036718, total_step : 2554186, cur_epsilon : 0.002
# episode : 20348, done reward : 11.486089036018727, total_step : 2555186, cur_epsilon : 0.002
# episode : 20349, done reward : 9.698960789550929, total_step : 2556186, cur_epsilon : 0.002
# episode : 20350, done reward : 2.602022626340851, total_step : 2556390, cur_epsilon : 0.002
# episode : 20351, done reward : 4.281800404645635, total_step : 2556828, cur_epsilon : 0.002
# episode : 20352, done reward : 9.94463056826206, total_step : 2557594, cur_epsilon : 0.002
# episode : 20353, done reward : 4.331166304666988, total_step : 2557952, cur_epsilon : 0.002
# episode : 20354, done reward : 11.128538989741843, total_step : 2558952, cur_epsilon : 0.002
# episode : 20355, done reward : 10.983216720463068, total_step : 2559952, cur_epsilon : 0.002
# episode : 20356, done reward : 10.050366065854679, total_step : 2560952, cur_epsilon : 0.002
# episode : 20357, done reward : 6.961207754713274, total_step : 2561642, cur_epsilon : 0.002
# episode : 20358, done reward : 3.599468732754904, total_step : 2561997, cur_epsilon : 0.002
# episode : 20359, done reward : 10.168820895404767, total_step : 2562827, cur_epsilon : 0.002
# episode : 20360, done reward : 9.04378124284742, total_step : 2563827, cur_epsilon : 0.002
# episode : 20361, done reward : 3.9777012827876894, total_step : 2564186, cur_epsilon : 0.002
# episode : 20362, done reward : 3.5280216587128446, total_step : 2564501, cur_epsilon : 0.002
# episode : 20363, done reward : 3.221032820602094, total_step : 2564738, cur_epsilon : 0.002
# episode : 20364, done reward : 4.376373724340121, total_step : 2565135, cur_epsilon : 0.002
# episode : 20365, done reward : 7.974052653448919, total_step : 2565697, cur_epsilon : 0.002
# episode : 20366, done reward : 2.043711504912778, total_step : 2565891, cur_epsilon : 0.002
# episode : 20367, done reward : 4.798805153507694, total_step : 2566248, cur_epsilon : 0.002
# episode : 20368, done reward : 0.11910671359701513, total_step : 2566283, cur_epsilon : 0.002
# episode : 20369, done reward : 4.5034754394754675, total_step : 2566613, cur_epsilon : 0.002
# episode : 20370, done reward : 3.6705094839169425, total_step : 2566924, cur_epsilon : 0.002
# episode : 20371, done reward : 4.224402096394219, total_step : 2567257, cur_epsilon : 0.002
# episode : 20372, done reward : 2.5350008534906197, total_step : 2567460, cur_epsilon : 0.002
# episode : 20373, done reward : 5.405256920772603, total_step : 2567935, cur_epsilon : 0.002
# episode : 20374, done reward : 3.2364036091886845, total_step : 2568186, cur_epsilon : 0.002
# episode : 20375, done reward : 2.2920759624230365, total_step : 2568383, cur_epsilon : 0.002
# episode : 20376, done reward : 2.2671579412129037, total_step : 2568575, cur_epsilon : 0.002
# episode : 20377, done reward : 11.218065199198024, total_step : 2569575, cur_epsilon : 0.002
# episode : 20378, done reward : 8.47246690488116, total_step : 2570264, cur_epsilon : 0.002
# episode : 20379, done reward : 0.09693232286674226, total_step : 2570359, cur_epsilon : 0.002
# episode : 20380, done reward : 5.138943548518416, total_step : 2570831, cur_epsilon : 0.002
# episode : 20381, done reward : 10.406350683525934, total_step : 2571831, cur_epsilon : 0.002
# episode : 20382, done reward : 11.818663644575569, total_step : 2572831, cur_epsilon : 0.002
# episode : 20383, done reward : 12.641959304409438, total_step : 2573831, cur_epsilon : 0.002
# episode : 20384, done reward : 7.351608558609214, total_step : 2574508, cur_epsilon : 0.002
# episode : 20385, done reward : 10.975541673883075, total_step : 2575412, cur_epsilon : 0.002
# episode : 20386, done reward : 11.812498600662176, total_step : 2576400, cur_epsilon : 0.002
# episode : 20387, done reward : 3.5903713221329583, total_step : 2576757, cur_epsilon : 0.002
# episode : 20388, done reward : 9.292230253794456, total_step : 2577663, cur_epsilon : 0.002
# episode : 20389, done reward : 13.438905916342181, total_step : 2578663, cur_epsilon : 0.002
# episode : 20390, done reward : 1.1081230006478218, total_step : 2578795, cur_epsilon : 0.002
# episode : 20391, done reward : 3.5672706498118583, total_step : 2579169, cur_epsilon : 0.002
# episode : 20392, done reward : 3.594059838203957, total_step : 2579559, cur_epsilon : 0.002
# episode : 20393, done reward : 11.739236931900791, total_step : 2580559, cur_epsilon : 0.002
# episode : 20394, done reward : 4.558886534663156, total_step : 2580881, cur_epsilon : 0.002
# episode : 20395, done reward : 3.958008489244312, total_step : 2581298, cur_epsilon : 0.002
# episode : 20396, done reward : 12.785748922010736, total_step : 2582298, cur_epsilon : 0.002
# episode : 20397, done reward : 5.9043671503564745, total_step : 2582886, cur_epsilon : 0.002
# episode : 20398, done reward : 1.7573730619516423, total_step : 2583053, cur_epsilon : 0.002
# episode : 20399, done reward : 4.366592762089499, total_step : 2583404, cur_epsilon : 0.002
# episode : 20400, done reward : 5.71625009896266, total_step : 2583953, cur_epsilon : 0.002
# episode : 20401, done reward : 6.892775158596483, total_step : 2584486, cur_epsilon : 0.002
# episode : 20402, done reward : 13.90682389287575, total_step : 2585486, cur_epsilon : 0.002
# episode : 20403, done reward : 11.62243964713412, total_step : 2586486, cur_epsilon : 0.002
# episode : 20404, done reward : 1.8510931316960464, total_step : 2586655, cur_epsilon : 0.002
# episode : 20405, done reward : 1.9342438237513084, total_step : 2586838, cur_epsilon : 0.002
# episode : 20406, done reward : 8.967738264326531, total_step : 2587648, cur_epsilon : 0.002
# episode : 20407, done reward : 5.377356401267028, total_step : 2588231, cur_epsilon : 0.002
# episode : 20408, done reward : 3.674809449025613, total_step : 2588522, cur_epsilon : 0.002
# episode : 20409, done reward : 9.736645692604464, total_step : 2589309, cur_epsilon : 0.002
# episode : 20410, done reward : 4.827401869868564, total_step : 2589684, cur_epsilon : 0.002
# episode : 20411, done reward : 7.69309312643645, total_step : 2590371, cur_epsilon : 0.002
# episode : 20412, done reward : 5.022681646490799, total_step : 2590919, cur_epsilon : 0.002
# episode : 20413, done reward : 13.376679555546778, total_step : 2591919, cur_epsilon : 0.002
# episode : 20414, done reward : 2.5524688543426715, total_step : 2592187, cur_epsilon : 0.002
# episode : 20415, done reward : 0.017661383772198648, total_step : 2592260, cur_epsilon : 0.002
# episode : 20416, done reward : 13.171962992362197, total_step : 2593260, cur_epsilon : 0.002
# episode : 20417, done reward : 3.768457417966356, total_step : 2593547, cur_epsilon : 0.002
# episode : 20418, done reward : 9.014629111186355, total_step : 2594259, cur_epsilon : 0.002
# episode : 20419, done reward : 1.4567478805427392, total_step : 2594433, cur_epsilon : 0.002
# episode : 20420, done reward : 6.626723484586452, total_step : 2594987, cur_epsilon : 0.002
# episode : 20421, done reward : 10.212526101858774, total_step : 2595987, cur_epsilon : 0.002
# episode : 20422, done reward : 0.26417903775324036, total_step : 2596037, cur_epsilon : 0.002
# episode : 20423, done reward : 0.3793656215618451, total_step : 2596104, cur_epsilon : 0.002
# episode : 20424, done reward : 0.3383938298769501, total_step : 2596160, cur_epsilon : 0.002
# episode : 20425, done reward : 4.0582866695303235, total_step : 2596463, cur_epsilon : 0.002
# episode : 20426, done reward : 0.3052222930351402, total_step : 2596521, cur_epsilon : 0.002
# episode : 20427, done reward : 0.273163765562858, total_step : 2596576, cur_epsilon : 0.002
# episode : 20428, done reward : 4.99279543964349, total_step : 2597097, cur_epsilon : 0.002
# episode : 20429, done reward : 4.966115698216461, total_step : 2597478, cur_epsilon : 0.002
# episode : 20430, done reward : 2.8898817708728655, total_step : 2597726, cur_epsilon : 0.002
# episode : 20431, done reward : 10.894444506199903, total_step : 2598726, cur_epsilon : 0.002
# episode : 20432, done reward : 8.341686001659692, total_step : 2599406, cur_epsilon : 0.002
# episode : 20433, done reward : 13.27838670504569, total_step : 2600406, cur_epsilon : 0.002
# episode : 20434, done reward : 3.8214636900289505, total_step : 2600709, cur_epsilon : 0.002
# episode : 20435, done reward : 0.13590994872865886, total_step : 2600751, cur_epsilon : 0.002
# episode : 20436, done reward : 0.25224511383350207, total_step : 2600804, cur_epsilon : 0.002
# episode : 20437, done reward : 0.2295424952867513, total_step : 2600856, cur_epsilon : 0.002
# episode : 20438, done reward : 0.23475872941489812, total_step : 2600951, cur_epsilon : 0.002
# episode : 20439, done reward : 9.124002719422874, total_step : 2601636, cur_epsilon : 0.002
# episode : 20440, done reward : 0.979984257800458, total_step : 2601835, cur_epsilon : 0.002
# episode : 20441, done reward : 3.5240744549845515, total_step : 2602176, cur_epsilon : 0.002
# episode : 20442, done reward : 0.13463129305163263, total_step : 2602302, cur_epsilon : 0.002
# episode : 20443, done reward : 2.0506291060951387, total_step : 2602528, cur_epsilon : 0.002
# episode : 20444, done reward : 11.881694733657888, total_step : 2603382, cur_epsilon : 0.002
# episode : 20445, done reward : 7.6815907884857335, total_step : 2604109, cur_epsilon : 0.002
# episode : 20446, done reward : 0.382119157707337, total_step : 2604172, cur_epsilon : 0.002
# episode : 20447, done reward : 0.3700194313574748, total_step : 2604245, cur_epsilon : 0.002
# episode : 20448, done reward : 0.4948395824755331, total_step : 2604323, cur_epsilon : 0.002
# episode : 20449, done reward : 0.21070860225464294, total_step : 2604376, cur_epsilon : 0.002
# episode : 20450, done reward : 0.32694558484628217, total_step : 2604498, cur_epsilon : 0.002
# episode : 20451, done reward : 0.25010658759484505, total_step : 2604552, cur_epsilon : 0.002
# episode : 20452, done reward : 0.11439097609986022, total_step : 2604594, cur_epsilon : 0.002
# episode : 20453, done reward : 0.025019530559114808, total_step : 2604679, cur_epsilon : 0.002
# episode : 20454, done reward : 0.14202784661590204, total_step : 2604723, cur_epsilon : 0.002
# episode : 20455, done reward : 0.13938807266126443, total_step : 2604767, cur_epsilon : 0.002
# episode : 20456, done reward : 0.1393179014039239, total_step : 2604811, cur_epsilon : 0.002
# episode : 20457, done reward : 0.2948466714578289, total_step : 2604921, cur_epsilon : 0.002
# episode : 20458, done reward : 9.128645146273698, total_step : 2605630, cur_epsilon : 0.002
# episode : 20459, done reward : 9.584322703913132, total_step : 2606630, cur_epsilon : 0.002
# episode : 20460, done reward : 3.807946959086208, total_step : 2607001, cur_epsilon : 0.002
# episode : 20461, done reward : 3.0019812807941717, total_step : 2607282, cur_epsilon : 0.002
# episode : 20462, done reward : 11.54057738118582, total_step : 2608282, cur_epsilon : 0.002
# episode : 20463, done reward : 3.5114209226334516, total_step : 2608599, cur_epsilon : 0.002
# episode : 20464, done reward : 3.7484778681579383, total_step : 2608950, cur_epsilon : 0.002
# episode : 20465, done reward : 4.774334366247103, total_step : 2609388, cur_epsilon : 0.002
# episode : 20466, done reward : 2.78862405816638, total_step : 2609686, cur_epsilon : 0.002
# episode : 20467, done reward : 11.045874591842257, total_step : 2610686, cur_epsilon : 0.002
# episode : 20468, done reward : 3.1307036350565967, total_step : 2611021, cur_epsilon : 0.002
# episode : 20469, done reward : 6.615406907220482, total_step : 2611655, cur_epsilon : 0.002
# episode : 20470, done reward : 0.14341080871057812, total_step : 2611698, cur_epsilon : 0.002
# episode : 20471, done reward : 0.16138727890900212, total_step : 2611746, cur_epsilon : 0.002
# episode : 20472, done reward : 4.594816877264115, total_step : 2612122, cur_epsilon : 0.002
# episode : 20473, done reward : 12.35868524633097, total_step : 2613122, cur_epsilon : 0.002
# episode : 20474, done reward : 7.943268362350709, total_step : 2613834, cur_epsilon : 0.002
# episode : 20475, done reward : 3.6983772150572154, total_step : 2614189, cur_epsilon : 0.002
# episode : 20476, done reward : 7.835770978101287, total_step : 2614871, cur_epsilon : 0.002
# episode : 20477, done reward : 7.247830041507587, total_step : 2615558, cur_epsilon : 0.002
# episode : 20478, done reward : 10.17106443504895, total_step : 2616558, cur_epsilon : 0.002
# episode : 20479, done reward : 4.0656036408806475, total_step : 2616904, cur_epsilon : 0.002
# episode : 20480, done reward : 0.30529003186147663, total_step : 2616964, cur_epsilon : 0.002
# episode : 20481, done reward : 9.549295806810276, total_step : 2617881, cur_epsilon : 0.002
# episode : 20482, done reward : 1.085901633141905, total_step : 2618127, cur_epsilon : 0.002
# episode : 20483, done reward : 0.16571926546200233, total_step : 2618175, cur_epsilon : 0.002
# episode : 20484, done reward : 2.5516477451777058, total_step : 2618391, cur_epsilon : 0.002
# episode : 20485, done reward : 1.9921609340661266, total_step : 2618609, cur_epsilon : 0.002
# episode : 20486, done reward : 1.3361458574030831, total_step : 2618772, cur_epsilon : 0.002
# episode : 20487, done reward : 3.2369252073171, total_step : 2619063, cur_epsilon : 0.002
# episode : 20488, done reward : 2.5103685178784922, total_step : 2619333, cur_epsilon : 0.002
# episode : 20489, done reward : 2.3489253957068024, total_step : 2619627, cur_epsilon : 0.002
# episode : 20490, done reward : 9.05991087904807, total_step : 2620627, cur_epsilon : 0.002
