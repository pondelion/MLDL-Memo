# %%
from mlagents_envs.envs.unity_gym_env import UnityToGymWrapper
from mlagents_envs.environment import ActionTuple, UnityEnvironment
from mlagents_envs.side_channel.engine_configuration_channel import \
    EngineConfigurationChannel
from mlagents_envs.exception import (
    UnityEnvironmentException,
    UnityCommunicationException,
    UnityCommunicatorStoppedException,
)
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
import collections
from typing import Union
import math
import random
from copy import deepcopy
from typing import Optional

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from fastprogress import progress_bar as pb
import matplotlib.pyplot as plt

# %%
class NStepPriorityReplayBuffer:

    def __init__(
        self,
        max_size: int,
        prob_alpha: float = 0.6,
        beta_start: float = 0.4,
        beta_frames: float = 100000,
        n_step: int = 4,
        gamma: float = 0.99,
    ):
        self._prob_alpha = prob_alpha
        self._max_size = max_size
        self._pos = 0
        self._buf = []
        self._priorities = np.zeros((max_size,), dtype=np.float32)
        self._beta_start = beta_start
        self._beta = beta_start
        self._beta_frames = beta_frames
        self._n_step = n_step
        self._gamma = gamma
        self._total_discounted_rewards = np.array([np.nan]*max_size)
        self._last_states = [np.nan]*max_size
        self._first_episode = True

    def update_bata(self, idx) -> None:
        beta = self._beta_start + idx * (1.0 - self._beta_start) / self._beta_frames
        self._beta = min(1.0, beta)
        return self._beta

    def __len__(self):
        return len(self._buf)

    def append(
        self,
        state: np.ndarray,
        action: int,
        reward: Union[int, float],
        done: bool,
        next_state: np.ndarray,
        total_reward: Union[int, float],
    ) -> None:
        max_prio = self._priorities.max() if self._buf else 1.0
        if len(self._buf) < self._max_size:
            self._buf.append(
                [state, action, reward, done, next_state]
            )
        else:
            self._buf[self._pos] = [state, action, reward, done, next_state]
        self._priorities[self._pos] = max_prio

        if len(self._buf) >= self._n_step:
            dis_r = 0.0
            last_state = self._buf[self._pos][0]
            for i in range(self._n_step):
                state, _, r, done, _ = self._buf[self._pos - i]
                dis_r = r + self._gamma * dis_r
                if done:
                    last_state = state
                    dis_r = r  # ※
                self._total_discounted_rewards[self._pos - i] = dis_r
                self._last_states[self._pos - i] = last_state
            
            for i in range(self._n_step-1):
                done = self._buf[self._pos - i][3]
                if done:
                    break
                self._total_discounted_rewards[self._pos - i] = np.nan
                self._last_states[self._pos - i] = np.nan

        if done:
            if self._first_episode:
                self._total_discounted_rewards[0:self._pos] = total_reward
                for i in range(self._pos):
#                     exp = self._buf[self._pos]
#                     exp[2] = total_reward
#                     self._buf[self._pos] = exp
                    self._buf[i][2] = total_reward
                self._first_episode = False
            else:
                idx = self._pos
                while True:
                    self._total_discounted_rewards[idx] = total_reward
#                     exp = self._buf[idx]
#                     exp[2] = total_reward
#                     self._buf[self._pos] = exp
                    self._buf[idx][2] = total_reward
                    idx -= 1
                    next_done = self._buf[idx][3]
                    if next_done:
                        break
 
        self._pos = (self._pos + 1) % self._max_size

    def sample(self, size: int):
        sample_target_indices = np.where(~np.isnan(self._total_discounted_rewards[:len(self._buf)]))[0]
        # prios = self._priorities[sample_target_indices]  #self._priorities if len(self._buf) == self._max_size else self._priorities[:self._pos]
        prios = self._priorities
        probs = prios * self._prob_alpha
        # probs /= np.nan_to_num(probs, 0.0).sum()
        probs /= probs[sample_target_indices].sum()
        sampled_indices = np.random.choice(
            sample_target_indices,
            # np.where(~np.isnan(self._total_discounted_rewards[:len(self._buf)]))[0],
            size, p=probs[sample_target_indices]
        )
        states, actions, rewards, dones, next_states = zip(*[self._buf[idx] for idx in sampled_indices])
        states = np.array(states)
        actions = np.array(actions)
        rewards = np.array(rewards)
        dones = np.array(dones)
        next_states = np.array(next_states)
        total_discounted_rewards = self._total_discounted_rewards[sampled_indices]
        last_states = np.stack([self._last_states[idx] for idx in sampled_indices])
        total = len(self._buf)
        weights = np.array((total * probs[sampled_indices]) ** (-self._beta), dtype=np.float32)
        # weights = np.array((total * probs) ** (-self._beta), dtype=np.float32)
        weights /= weights.max()
        return states, actions, rewards, dones, total_discounted_rewards, last_states, sampled_indices, weights

    def update_priorities(self, sample_indices: np.ndarray, sample_priorities: np.ndarray) -> None:
        self._priorities[sample_indices] = sample_priorities

    @property
    def gamma(self) -> float:
        return self._gamma

    @property
    def n_step(self) -> float:
        return self._n_step

# %%
class NoisyLinear(nn.Linear):

    def __init__(self, in_features, out_features, sigma_init=0.017, bias=True):
        super(NoisyLinear, self).__init__(in_features, out_features, bias=bias)
        w = torch.full((out_features, in_features), sigma_init)
        self._sigma_weight = nn.Parameter(w)
        z = torch.zeros(out_features, in_features)
        self.register_buffer("epsilon_weight", z)
        if bias:
            w = torch.full((out_features,), sigma_init)
            self._sigma_bias = nn.Parameter(w)
            z = torch.zeros(out_features)
            self.register_buffer("epsilon_bias", z)
        self.reset_parameters()

    def reset_parameters(self):
        std = math.sqrt(3 / self.in_features)
        self.weight.data.uniform_(-std, std)
        self.bias.data.uniform_(-std, std)

    def forward(self, input):
        self.epsilon_weight.normal_()
        bias = self.bias
        if bias is not None:
            self.epsilon_bias.normal_()
            bias = bias + self._sigma_bias * \
                   self.epsilon_bias.data
        v = self._sigma_weight * self.epsilon_weight.data + \
            self.weight
        return F.linear(input, v, bias)

# %%
class DDPGCritic(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGCritic, self).__init__()

        self.obs_net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
        )

        self.out_net = nn.Sequential(
            nn.Linear(400 + act_size, 300),
            nn.ReLU(),
            nn.Linear(300, 1)
        )

    def forward(self, x, a):
        obs = self.obs_net(x)
        return self.out_net(torch.cat([obs, a], dim=1))

# %%
class DDPGActor(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGActor, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, act_size),
            nn.Tanh()
        )

    def forward(self, x):
        return self.net(x)

# %%
class Agent:

    def __init__(
        self,
        env,
        exp_buffer: NStepPriorityReplayBuffer,
        act_net: nn.Module,
        crt_net: nn.Module,
        epsilon_start: float = 1.0,
        epsilon_final: float = 0.01,
        epsilon_decay_last_step: int = 200000,
        tgt_sync_steps: int = 10000,
        learning_rate: float = 1e-4,
        adam_eps: float = None,
        device: str = 'cuda' if torch.cuda.is_available() else 'cpu',
        bonus_reward_factor: float = 0.0
    ):
        self._env = env
        self._exp_buffer = exp_buffer
        self._act_net = act_net
        self._crt_net = crt_net
        self._tgt_act_net = deepcopy(act_net)
        self._tgt_crt_net = deepcopy(crt_net)
        for p in self._tgt_act_net.parameters():
            p.requires_grad = False
        for p in self._tgt_crt_net.parameters():
            p.requires_grad = False
        self._epsilon_start = epsilon_start
        self._epsilon_final = epsilon_final
        self._epsilon_decay_last_step = epsilon_decay_last_step
        self._epsilon = epsilon_start
        self._device = device
        self._total_step = 0
        self._total_trained_samples = 0
        self._tgt_sync_steps = tgt_sync_steps
        adam_kwargs = {}
        if adam_eps is not None:
            adam_kwargs['eps'] = adam_eps
        self._crt_optimizer = torch.optim.Adam(self._crt_net.parameters(), lr=learning_rate, **adam_kwargs)
        self._act_optimizer = torch.optim.Adam(self._act_net.parameters(), lr=learning_rate, **adam_kwargs)
        self._n_episodes = 0
        self._episode_steps = 0
        self._bonus_reward_factor = bonus_reward_factor
        self._reset_episode()

    def _reset_episode(self):
        self._state = self._env.reset()
        self._total_reward = 0.0
        self._episode_steps = 0
        self._n_episodes += 1

    @torch.no_grad()
    def play_step(self, epsilon: Optional[float] = None, sync_target: bool = True):
        if epsilon is None:
            epsilon = self._epsilon
        done_reward = None

        if np.random.random() < epsilon:
            action = self._env.action_space.sample()
        else:
            state_a = np.array([self._state], copy=False)
            state_v = torch.tensor(state_a).float().to(self._device)
            mu_v = self._act_net(state_v)
            action = mu_v.squeeze(dim=0).data.cpu().numpy()
            action = np.clip(action, -1, 1)

        next_state, reward, is_done, _ = self._env.step(action)
        self._total_reward += reward

        bonus_reward = self._bonus_reward_factor * self._episode_steps

        self._exp_buffer.append(
            self._state, action, reward + bonus_reward, is_done, next_state, self._total_reward
        )
#         self._exp_buffer.append(
#             self._state, action, self._total_reward + bonus_reward, is_done, next_state
#         )
        self._state = next_state
        if is_done:
            done_reward = self._total_reward
            self._reset_episode()

        self._total_step += 1
        self._episode_steps += 1
        self._update_epsilon(self._total_step)
        self._exp_buffer.update_bata(self._total_step)

        # if self._total_step % self._tgt_sync_steps == 0 and sync_target:
        #     self._alpha_sync(self._act_net, self._tgt_act_net, alpha=1 - 1e-3)
        #     self._alpha_sync(self._crt_net, self._tgt_crt_net, alpha=1 - 1e-3)
        #     print(f'synced target net')

        return done_reward

    def train(self, n_iter: int = 1, batch_size: int = 32) -> None:
        n_step_gamma = self._exp_buffer.gamma ** self._exp_buffer.n_step
        for i in range(n_iter):
            states, actions, rewards, dones, total_discounted_rewards, \
                last_states, sampled_indices, weights = self._exp_buffer.sample(batch_size)
            states_v = torch.tensor(states).float().to(self._device)
            actions_v = torch.tensor(actions).to(self._device)
            discounted_rewards_v = torch.tensor(total_discounted_rewards).to(self._device)
            done_mask = torch.BoolTensor(dones).to(self._device)
            weights_v = torch.tensor(weights).to(self._device)
            last_states_v = torch.tensor(last_states).float().to(self._device)

            # train critic
            self._crt_optimizer.zero_grad()
            q_v = self._crt_net(states_v, actions_v)
            last_act_v = self._tgt_act_net(last_states_v)
            q_last_v = self._tgt_crt_net(last_states_v, last_act_v)
            q_last_v[done_mask] = 0.0
            q_ref_v = discounted_rewards_v.unsqueeze(dim=-1) + \
                        q_last_v * n_step_gamma
            # q_ref_v = discounted_rewards_v + q_last_v * n_step_gamma
            critic_loss_v = F.mse_loss(q_v.float(), q_ref_v.float().detach())
            critic_loss_v.backward()
            self._crt_optimizer.step()

            # train actor
            self._act_optimizer.zero_grad()
            cur_actions_v = self._act_net(states_v)
            actor_loss_v = -self._crt_net(states_v, cur_actions_v)
            actor_loss_v = actor_loss_v.mean()
            actor_loss_v.backward()
            self._act_optimizer.step()

            self._alpha_sync(self._act_net, self._tgt_act_net, alpha=1 - 1e-3)
            self._alpha_sync(self._crt_net, self._tgt_crt_net, alpha=1 - 1e-3)

            # self._exp_buffer.update_priorities(sampled_indices, prios)
            self._total_trained_samples += batch_size

    def initial_exploration(self, n_steps: int = 10000, epsilon: float = 1.0) -> None:
        eps_bak = self._epsilon
        n_episodes_bak = self._n_episodes
        try:
            for i in pb(range(n_steps)):
                self._epsilon = epsilon
                self.play_step(sync_target=False)
        finally:
            self._total_step = 0
            self._epsilon = eps_bak
        self._n_episodes = n_episodes_bak

    def _update_epsilon(self, step_index: int) -> None:
        self._epsilon = max(
            self._epsilon_final,
            self._epsilon_start - step_index / self._epsilon_decay_last_step
        )

    def _sync(self, net, tgt_net):
        tgt_net.load_state_dict(net.state_dict())

    def _alpha_sync(self, net, tgt_net, alpha):
        assert isinstance(alpha, float)
        assert 0.0 < alpha <= 1.0
        state = net.state_dict()
        tgt_state = tgt_net.state_dict()
        for k, v in state.items():
            tgt_state[k] = tgt_state[k] * alpha + (1 - alpha) * v
        tgt_net.load_state_dict(tgt_state)

# %%
class UnityToGymNumpyWrapper(UnityToGymWrapper):
    def __init__(self, *args, **kwargs):
        super(UnityToGymNumpyWrapper, self).__init__(*args, **kwargs)

    def reset(self, *args, **kwargs):
        state = super().reset(*args, **kwargs)
        return np.array(state[0])

    def step(self, *args, **kwargs):
        next_state, reward, is_done, info = super().step(*args, **kwargs)
        return np.array(next_state[0]), reward, is_done, info

# %%
try:
    unity_env.close()
except Exception:
    pass

unity_env = UnityEnvironment(file_name=None)

# %%
unity_env.reset()

# %%
# env = UnityToGymWrapper(unity_env, allow_multiple_obs=True)
env = UnityToGymNumpyWrapper(unity_env, allow_multiple_obs=True)

# %%
# Unity環境のリセット
unity_env.reset()

# BehaviorNameのリストの取得
behavior_names = list(unity_env.behavior_specs.keys())
print('behavior_names:', behavior_names)

# BehaviorSpecの取得
behavior_spec = unity_env.behavior_specs[behavior_names[0]]

# BehaviorSpecの情報の確認
print('\n== BehaviorSpecの情報の確認 ==')
print('observation_specs:', behavior_spec.observation_specs)
print('action_spec:', behavior_spec.action_spec)
# Out:
# behavior_names: ['3DBall?team=0']
#
# == BehaviorSpecの情報の確認 ==
# observation_specs: [ObservationSpec(shape=(8,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='VectorSensor_size8')]
# action_spec: Continuous: 2, Discrete: ()

# %%
behavior_spec
# Out:
# BehaviorSpec(observation_specs=[ObservationSpec(shape=(8,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='VectorSensor_size8')], action_spec=ActionSpec(continuous_size=2, discrete_branches=()))

# %%
# 現在のステップの情報の取得
decision_steps, terminal_steps = unity_env.get_steps(behavior_names[0])

# DecisionStepsの情報の確認
print('\n== DecisionStepsの情報の確認 ==')
print('obj:', decision_steps.obs)
print('reward:', decision_steps.reward)
print('agent_id:', decision_steps.agent_id)
print('action_mask:', decision_steps.action_mask)

# TerminalStepsの情報の確認
print('\n== TerminalStepsの情報の確認 ==')
print('obs:', terminal_steps.obs)
print('reward:', terminal_steps.reward)
print('agent_id:', terminal_steps.agent_id)
print('interrupted:', terminal_steps.interrupted)
# Out:
# == DecisionStepsの情報の確認 ==
# obj: [array([[ 0.06363224,  0.03799658, -1.1360741 ,  3.996076  , -0.4150591 ,
#          0.        , -0.1962    ,  0.        ]], dtype=float32)]
# reward: [0.1]
# agent_id: [0]
# action_mask: None
#
# == TerminalStepsの情報の確認 ==
# obs: [array([], shape=(0, 8), dtype=float32)]
# reward: []
# agent_id: []
# interrupted: []

# %%
len(decision_steps.obs)
# Out:
# 1

# %%
decision_steps.obs[0].shape
# Out:
# (1, 8)

# %%
N_AGENTS, OBS_DIM = decision_steps.obs[0].shape

# %%
N_ACTIONS = behavior_spec.action_spec.continuous_size

# %%
N_ACTIONS
# Out:
# 2

# %%
env.action_space
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
env.action_space.sample()
# Out:
# array([0.464371  , 0.97866565], dtype=float32)

# %%
env.observation_space
# Out:
# Tuple(Box(-inf, inf, (8,), float32))

# %%
state = env.reset()

# %%
state
# Out:
# array([-0.04687161, -0.03916143, -0.61104035,  3.996076  ,  0.56867313,
#         0.        , -0.1962    ,  0.        ], dtype=float32)

# %%
state.shape
# Out:
# (8,)

# %%
torch.tensor(state).unsqueeze(0).shape
# Out:
# torch.Size([1, 8])

# %%
next_state, reward, is_done, _ = env.step(env.action_space.sample())

# %%
next_state
# Out:
# array([ 0.00733691, -0.00922427, -0.61104035,  3.917596  ,  0.56867313,
#         0.        , -1.1772    ,  0.        ], dtype=float32)

# %%
reward
# Out:
# 0.1

# %%
is_done
# Out:
# False

# %%
SEED = 77

# %%
random.seed(SEED)
torch.manual_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
act_net = DDPGActor(
    OBS_DIM,
    N_ACTIONS,
).to(device)
crt_net = DDPGCritic(
    OBS_DIM,
    N_ACTIONS,
).to(device)

# %%
act = act_net(torch.tensor(state).unsqueeze(0).to(device))

# %%
act.shape
# Out:
# torch.Size([1, 2])

# %%
v = crt_net(torch.tensor(state).unsqueeze(0).to(device), act)

# %%
v.shape
# Out:
# torch.Size([1, 1])

# %%
exp_buffer = NStepPriorityReplayBuffer(
    max_size=30000,
    prob_alpha=0.6,
    beta_start=0.4,
    beta_frames=30000, #100000,
    n_step=2,
    gamma=0.99,
)
agent = Agent(
    env=env,
    exp_buffer=exp_buffer,
    crt_net=crt_net,
    act_net=act_net,
    epsilon_start=0.6,
    epsilon_final=0.002,
    epsilon_decay_last_step=30000, #200000,
    tgt_sync_steps=1000,
    learning_rate=1e-4,
    device=device
)

# %%
agent.initial_exploration(n_steps=10000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 16:15&lt;00:00]
#     </div>

# %%
states, actions, rewards, dones, next_states = zip(*agent._exp_buffer._buf)

# %%
plt.figure(figsize=(16, 6))
plt.plot(rewards[:300])
plt.plot(agent._exp_buffer._total_discounted_rewards[:300])

# %%
plt.figure(figsize=(16, 6))
plt.plot(dones)

# %%
episode = 0
reward_history = []
spisode_steps_history = []
spisode_start_steps = 0

env.reset()

while True:

    for stp in range(20):
        done_reward = agent.play_step()
        if done_reward is not None:
            print(f'episode : {episode}, done reward : {done_reward}, total_step : {agent._total_step}, cur_epsilon : {agent._epsilon}')
            episode += 1
            reward_history.append(done_reward)
            spisode_steps_history.append(agent._total_step-spisode_start_steps)
            spisode_start_steps = agent._total_step

    agent.train(n_iter=20, batch_size=32)
# Out:
# episode : 0, done reward : 2.7000000551342964, total_step : 24, cur_epsilon : 0.5992
# episode : 1, done reward : 1.0000000298023224, total_step : 45, cur_epsilon : 0.5985
# episode : 2, done reward : 1.2000000327825546, total_step : 68, cur_epsilon : 0.5977333333333333
# episode : 3, done reward : 1.3000000342726707, total_step : 92, cur_epsilon : 0.5969333333333333
# episode : 4, done reward : 0.8000000268220901, total_step : 111, cur_epsilon : 0.5962999999999999
# episode : 5, done reward : 0.8000000268220901, total_step : 130, cur_epsilon : 0.5956666666666667
# episode : 6, done reward : 0.6000000238418579, total_step : 147, cur_epsilon : 0.5951
# episode : 7, done reward : 0.6000000238418579, total_step : 164, cur_epsilon : 0.5945333333333334
# episode : 8, done reward : 1.0000000298023224, total_step : 185, cur_epsilon : 0.5938333333333333
# episode : 9, done reward : 1.3000000342726707, total_step : 209, cur_epsilon : 0.5930333333333333
# episode : 10, done reward : 2.400000050663948, total_step : 244, cur_epsilon : 0.5918666666666667
# episode : 11, done reward : 0.8000000268220901, total_step : 263, cur_epsilon : 0.5912333333333333
# episode : 12, done reward : 1.2000000327825546, total_step : 286, cur_epsilon : 0.5904666666666667
# episode : 13, done reward : 0.5000000223517418, total_step : 302, cur_epsilon : 0.5899333333333333
# episode : 14, done reward : 1.1000000312924385, total_step : 324, cur_epsilon : 0.5892
# episode : 15, done reward : 1.0000000298023224, total_step : 345, cur_epsilon : 0.5885
# episode : 16, done reward : 2.6000000536441803, total_step : 382, cur_epsilon : 0.5872666666666666
# episode : 17, done reward : 1.1000000312924385, total_step : 404, cur_epsilon : 0.5865333333333334
# episode : 18, done reward : 1.1000000312924385, total_step : 426, cur_epsilon : 0.5858
# episode : 19, done reward : 0.9000000283122063, total_step : 446, cur_epsilon : 0.5851333333333333
# episode : 20, done reward : 1.500000037252903, total_step : 472, cur_epsilon : 0.5842666666666666
# episode : 21, done reward : 0.9000000283122063, total_step : 492, cur_epsilon : 0.5836
# episode : 22, done reward : 0.700000025331974, total_step : 510, cur_epsilon : 0.583
# episode : 23, done reward : 1.1000000312924385, total_step : 532, cur_epsilon : 0.5822666666666666
# episode : 24, done reward : 0.700000025331974, total_step : 550, cur_epsilon : 0.5816666666666667
# episode : 25, done reward : 0.5000000223517418, total_step : 566, cur_epsilon : 0.5811333333333333
# episode : 26, done reward : 1.0000000298023224, total_step : 587, cur_epsilon : 0.5804333333333334
# episode : 27, done reward : 0.700000025331974, total_step : 605, cur_epsilon : 0.5798333333333333
# episode : 28, done reward : 0.6000000238418579, total_step : 622, cur_epsilon : 0.5792666666666666
# episode : 29, done reward : 0.8000000268220901, total_step : 641, cur_epsilon : 0.5786333333333333
# episode : 30, done reward : 0.8000000268220901, total_step : 660, cur_epsilon : 0.578
# episode : 31, done reward : 0.6000000238418579, total_step : 677, cur_epsilon : 0.5774333333333334
# episode : 32, done reward : 0.5000000223517418, total_step : 693, cur_epsilon : 0.5769
# episode : 33, done reward : 0.700000025331974, total_step : 711, cur_epsilon : 0.5763
# episode : 34, done reward : 0.40000002086162567, total_step : 726, cur_epsilon : 0.5758
# episode : 35, done reward : 0.8000000268220901, total_step : 745, cur_epsilon : 0.5751666666666666
# episode : 36, done reward : 0.40000002086162567, total_step : 760, cur_epsilon : 0.5746666666666667
# episode : 37, done reward : 0.6000000238418579, total_step : 777, cur_epsilon : 0.5740999999999999
# episode : 38, done reward : 0.8000000268220901, total_step : 796, cur_epsilon : 0.5734666666666667
# episode : 39, done reward : 0.9000000283122063, total_step : 816, cur_epsilon : 0.5728
# episode : 40, done reward : 0.8000000268220901, total_step : 835, cur_epsilon : 0.5721666666666666
# episode : 41, done reward : 0.8000000268220901, total_step : 854, cur_epsilon : 0.5715333333333333
# episode : 42, done reward : 1.2000000327825546, total_step : 877, cur_epsilon : 0.5707666666666666
# episode : 43, done reward : 0.40000002086162567, total_step : 892, cur_epsilon : 0.5702666666666667
# episode : 44, done reward : 1.500000037252903, total_step : 918, cur_epsilon : 0.5694
# episode : 45, done reward : 0.6000000238418579, total_step : 935, cur_epsilon : 0.5688333333333333
# episode : 46, done reward : 0.8000000268220901, total_step : 954, cur_epsilon : 0.5681999999999999
# episode : 47, done reward : 2.1000000461935997, total_step : 986, cur_epsilon : 0.5671333333333333
# episode : 48, done reward : 0.700000025331974, total_step : 1004, cur_epsilon : 0.5665333333333333
# episode : 49, done reward : 1.600000038743019, total_step : 1031, cur_epsilon : 0.5656333333333333
# episode : 50, done reward : 1.3000000342726707, total_step : 1055, cur_epsilon : 0.5648333333333333
# episode : 51, done reward : 1.0000000298023224, total_step : 1076, cur_epsilon : 0.5641333333333333
# episode : 52, done reward : 0.700000025331974, total_step : 1094, cur_epsilon : 0.5635333333333333
# episode : 53, done reward : 0.6000000238418579, total_step : 1111, cur_epsilon : 0.5629666666666666
# episode : 54, done reward : 0.700000025331974, total_step : 1129, cur_epsilon : 0.5623666666666667
# episode : 55, done reward : 1.2000000327825546, total_step : 1152, cur_epsilon : 0.5616
# episode : 56, done reward : 0.8000000268220901, total_step : 1171, cur_epsilon : 0.5609666666666666
# episode : 57, done reward : 0.8000000268220901, total_step : 1190, cur_epsilon : 0.5603333333333333
# episode : 58, done reward : 1.600000038743019, total_step : 1217, cur_epsilon : 0.5594333333333333
# episode : 59, done reward : 1.2000000327825546, total_step : 1240, cur_epsilon : 0.5586666666666666
# episode : 60, done reward : 1.1000000312924385, total_step : 1262, cur_epsilon : 0.5579333333333333
# episode : 61, done reward : 0.6000000238418579, total_step : 1279, cur_epsilon : 0.5573666666666667
# episode : 62, done reward : 1.0000000298023224, total_step : 1300, cur_epsilon : 0.5566666666666666
# episode : 63, done reward : 0.5000000223517418, total_step : 1316, cur_epsilon : 0.5561333333333334
# episode : 64, done reward : 1.500000037252903, total_step : 1342, cur_epsilon : 0.5552666666666667
# episode : 65, done reward : 3.0000000596046448, total_step : 1383, cur_epsilon : 0.5539
# episode : 66, done reward : 1.2000000327825546, total_step : 1406, cur_epsilon : 0.5531333333333333
# episode : 67, done reward : 1.0000000298023224, total_step : 1427, cur_epsilon : 0.5524333333333333
# episode : 68, done reward : 0.9000000283122063, total_step : 1447, cur_epsilon : 0.5517666666666666
# episode : 69, done reward : 0.6000000238418579, total_step : 1464, cur_epsilon : 0.5512
# episode : 70, done reward : 1.2000000327825546, total_step : 1487, cur_epsilon : 0.5504333333333333
# episode : 71, done reward : 0.9000000283122063, total_step : 1507, cur_epsilon : 0.5497666666666666
# episode : 72, done reward : 0.9000000283122063, total_step : 1527, cur_epsilon : 0.5490999999999999
# episode : 73, done reward : 1.3000000342726707, total_step : 1551, cur_epsilon : 0.5483
# episode : 74, done reward : 0.8000000268220901, total_step : 1570, cur_epsilon : 0.5476666666666666
# episode : 75, done reward : 0.6000000238418579, total_step : 1587, cur_epsilon : 0.5470999999999999
# episode : 76, done reward : 0.40000002086162567, total_step : 1602, cur_epsilon : 0.5466
# episode : 77, done reward : 1.500000037252903, total_step : 1628, cur_epsilon : 0.5457333333333333
# episode : 78, done reward : 0.700000025331974, total_step : 1646, cur_epsilon : 0.5451333333333334
# episode : 79, done reward : 1.1000000312924385, total_step : 1668, cur_epsilon : 0.5444
# episode : 80, done reward : 0.40000002086162567, total_step : 1683, cur_epsilon : 0.5438999999999999
# episode : 81, done reward : 1.0000000298023224, total_step : 1704, cur_epsilon : 0.5432
# episode : 82, done reward : 0.8000000268220901, total_step : 1723, cur_epsilon : 0.5425666666666666
# episode : 83, done reward : 0.9000000283122063, total_step : 1743, cur_epsilon : 0.5418999999999999
# episode : 84, done reward : 1.1000000312924385, total_step : 1765, cur_epsilon : 0.5411666666666667
# episode : 85, done reward : 1.1000000312924385, total_step : 1787, cur_epsilon : 0.5404333333333333
# episode : 86, done reward : 0.5000000223517418, total_step : 1803, cur_epsilon : 0.5398999999999999
# episode : 87, done reward : 0.6000000238418579, total_step : 1820, cur_epsilon : 0.5393333333333333
# episode : 88, done reward : 0.40000002086162567, total_step : 1835, cur_epsilon : 0.5388333333333333
# episode : 89, done reward : 0.700000025331974, total_step : 1853, cur_epsilon : 0.5382333333333333
# episode : 90, done reward : 1.1000000312924385, total_step : 1875, cur_epsilon : 0.5375
# episode : 91, done reward : 0.6000000238418579, total_step : 1892, cur_epsilon : 0.5369333333333333
# episode : 92, done reward : 0.8000000268220901, total_step : 1911, cur_epsilon : 0.5363
# episode : 93, done reward : 0.9000000283122063, total_step : 1931, cur_epsilon : 0.5356333333333333
# episode : 94, done reward : 1.1000000312924385, total_step : 1953, cur_epsilon : 0.5348999999999999
# episode : 95, done reward : 1.1000000312924385, total_step : 1975, cur_epsilon : 0.5341666666666667
# episode : 96, done reward : 1.0000000298023224, total_step : 1996, cur_epsilon : 0.5334666666666666
# episode : 97, done reward : 0.8000000268220901, total_step : 2015, cur_epsilon : 0.5328333333333333
# episode : 98, done reward : 0.9000000283122063, total_step : 2035, cur_epsilon : 0.5321666666666667
# episode : 99, done reward : 0.700000025331974, total_step : 2053, cur_epsilon : 0.5315666666666666
# episode : 100, done reward : 1.0000000298023224, total_step : 2074, cur_epsilon : 0.5308666666666666
# episode : 101, done reward : 0.9000000283122063, total_step : 2094, cur_epsilon : 0.5302
# episode : 102, done reward : 0.9000000283122063, total_step : 2114, cur_epsilon : 0.5295333333333333
# episode : 103, done reward : 1.0000000298023224, total_step : 2135, cur_epsilon : 0.5288333333333333
# episode : 104, done reward : 1.0000000298023224, total_step : 2156, cur_epsilon : 0.5281333333333333
# episode : 105, done reward : 1.500000037252903, total_step : 2182, cur_epsilon : 0.5272666666666667
# episode : 106, done reward : 0.5000000223517418, total_step : 2198, cur_epsilon : 0.5267333333333333
# episode : 107, done reward : 0.40000002086162567, total_step : 2213, cur_epsilon : 0.5262333333333333
# episode : 108, done reward : 0.5000000223517418, total_step : 2229, cur_epsilon : 0.5257
# episode : 109, done reward : 1.3000000342726707, total_step : 2253, cur_epsilon : 0.5248999999999999
# episode : 110, done reward : 0.9000000283122063, total_step : 2273, cur_epsilon : 0.5242333333333333
# episode : 111, done reward : 0.5000000223517418, total_step : 2289, cur_epsilon : 0.5236999999999999
# episode : 112, done reward : 1.1000000312924385, total_step : 2311, cur_epsilon : 0.5229666666666667
# episode : 113, done reward : 0.9000000283122063, total_step : 2331, cur_epsilon : 0.5223
# episode : 114, done reward : 0.5000000223517418, total_step : 2347, cur_epsilon : 0.5217666666666666
# episode : 115, done reward : 1.0000000298023224, total_step : 2368, cur_epsilon : 0.5210666666666667
# episode : 116, done reward : 2.400000050663948, total_step : 2403, cur_epsilon : 0.5199
# episode : 117, done reward : 0.6000000238418579, total_step : 2420, cur_epsilon : 0.5193333333333333
# episode : 118, done reward : 1.2000000327825546, total_step : 2443, cur_epsilon : 0.5185666666666666
# episode : 119, done reward : 1.1000000312924385, total_step : 2465, cur_epsilon : 0.5178333333333334
# episode : 120, done reward : 0.5000000223517418, total_step : 2481, cur_epsilon : 0.5173
# episode : 121, done reward : 0.8000000268220901, total_step : 2500, cur_epsilon : 0.5166666666666666
# episode : 122, done reward : 1.1000000312924385, total_step : 2522, cur_epsilon : 0.5159333333333334
# episode : 123, done reward : 0.700000025331974, total_step : 2540, cur_epsilon : 0.5153333333333333
# episode : 124, done reward : 0.9000000283122063, total_step : 2560, cur_epsilon : 0.5146666666666666
# episode : 125, done reward : 0.6000000238418579, total_step : 2577, cur_epsilon : 0.5141
# episode : 126, done reward : 0.8000000268220901, total_step : 2596, cur_epsilon : 0.5134666666666666
# episode : 127, done reward : 1.1000000312924385, total_step : 2618, cur_epsilon : 0.5127333333333333
# episode : 128, done reward : 1.7000000402331352, total_step : 2646, cur_epsilon : 0.5118
# episode : 129, done reward : 1.3000000342726707, total_step : 2670, cur_epsilon : 0.511
# episode : 130, done reward : 0.700000025331974, total_step : 2688, cur_epsilon : 0.5104
# episode : 131, done reward : 1.2000000327825546, total_step : 2711, cur_epsilon : 0.5096333333333333
# episode : 132, done reward : 1.4000000357627869, total_step : 2736, cur_epsilon : 0.5087999999999999
# episode : 133, done reward : 0.5000000223517418, total_step : 2752, cur_epsilon : 0.5082666666666666
# episode : 134, done reward : 0.700000025331974, total_step : 2770, cur_epsilon : 0.5076666666666666
# episode : 135, done reward : 0.6000000238418579, total_step : 2787, cur_epsilon : 0.5071
# episode : 136, done reward : 0.5000000223517418, total_step : 2803, cur_epsilon : 0.5065666666666666
# episode : 137, done reward : 1.1000000312924385, total_step : 2825, cur_epsilon : 0.5058333333333334
# episode : 138, done reward : 0.8000000268220901, total_step : 2844, cur_epsilon : 0.5052
# episode : 139, done reward : 0.5000000223517418, total_step : 2860, cur_epsilon : 0.5046666666666666
# episode : 140, done reward : 1.2000000327825546, total_step : 2883, cur_epsilon : 0.5039
# episode : 141, done reward : 1.0000000298023224, total_step : 2904, cur_epsilon : 0.5032
# episode : 142, done reward : 1.1000000312924385, total_step : 2926, cur_epsilon : 0.5024666666666666
# episode : 143, done reward : 0.5000000223517418, total_step : 2942, cur_epsilon : 0.5019333333333333
# episode : 144, done reward : 1.3000000342726707, total_step : 2966, cur_epsilon : 0.5011333333333333
# episode : 145, done reward : 0.5000000223517418, total_step : 2982, cur_epsilon : 0.5005999999999999
# episode : 146, done reward : 1.3000000342726707, total_step : 3006, cur_epsilon : 0.49979999999999997
# episode : 147, done reward : 0.700000025331974, total_step : 3024, cur_epsilon : 0.4992
# episode : 148, done reward : 1.0000000298023224, total_step : 3045, cur_epsilon : 0.49849999999999994
# episode : 149, done reward : 0.9000000283122063, total_step : 3065, cur_epsilon : 0.4978333333333333
# episode : 150, done reward : 0.8000000268220901, total_step : 3084, cur_epsilon : 0.4972
# episode : 151, done reward : 0.700000025331974, total_step : 3102, cur_epsilon : 0.4966
# episode : 152, done reward : 0.9000000283122063, total_step : 3122, cur_epsilon : 0.49593333333333334
# episode : 153, done reward : 1.0000000298023224, total_step : 3143, cur_epsilon : 0.4952333333333333
# episode : 154, done reward : 0.8000000268220901, total_step : 3162, cur_epsilon : 0.4946
# episode : 155, done reward : 0.6000000238418579, total_step : 3179, cur_epsilon : 0.4940333333333333
# episode : 156, done reward : 1.2000000327825546, total_step : 3202, cur_epsilon : 0.49326666666666663
# episode : 157, done reward : 0.700000025331974, total_step : 3220, cur_epsilon : 0.49266666666666664
# episode : 158, done reward : 1.1000000312924385, total_step : 3242, cur_epsilon : 0.49193333333333333
# episode : 159, done reward : 1.2000000327825546, total_step : 3265, cur_epsilon : 0.49116666666666664
# episode : 160, done reward : 1.0000000298023224, total_step : 3286, cur_epsilon : 0.49046666666666666
# episode : 161, done reward : 1.9000000432133675, total_step : 3316, cur_epsilon : 0.48946666666666666
# episode : 162, done reward : 2.0000000447034836, total_step : 3347, cur_epsilon : 0.48843333333333333
# episode : 163, done reward : 1.3000000342726707, total_step : 3371, cur_epsilon : 0.4876333333333333
# episode : 164, done reward : 1.2000000327825546, total_step : 3394, cur_epsilon : 0.48686666666666667
# episode : 165, done reward : 1.3000000342726707, total_step : 3418, cur_epsilon : 0.48606666666666665
# episode : 166, done reward : 0.9000000283122063, total_step : 3438, cur_epsilon : 0.4854
# episode : 167, done reward : 1.4000000357627869, total_step : 3463, cur_epsilon : 0.48456666666666665
# episode : 168, done reward : 0.9000000283122063, total_step : 3483, cur_epsilon : 0.4839
# episode : 169, done reward : 1.0000000298023224, total_step : 3504, cur_epsilon : 0.48319999999999996
# episode : 170, done reward : 1.0000000298023224, total_step : 3525, cur_epsilon : 0.4825
# episode : 171, done reward : 0.8000000268220901, total_step : 3544, cur_epsilon : 0.48186666666666667
# episode : 172, done reward : 3.100000061094761, total_step : 3586, cur_epsilon : 0.48046666666666665
# episode : 173, done reward : 1.0000000298023224, total_step : 3607, cur_epsilon : 0.4797666666666667
# episode : 174, done reward : 1.4000000357627869, total_step : 3632, cur_epsilon : 0.4789333333333333
# episode : 175, done reward : 1.1000000312924385, total_step : 3654, cur_epsilon : 0.47819999999999996
# episode : 176, done reward : 1.7000000402331352, total_step : 3682, cur_epsilon : 0.4772666666666666
# episode : 177, done reward : 1.0000000298023224, total_step : 3703, cur_epsilon : 0.47656666666666664
# episode : 178, done reward : 1.1000000312924385, total_step : 3725, cur_epsilon : 0.47583333333333333
# episode : 179, done reward : 1.9000000432133675, total_step : 3755, cur_epsilon : 0.47483333333333333
# episode : 180, done reward : 1.7000000402331352, total_step : 3783, cur_epsilon : 0.4739
# episode : 181, done reward : 1.9000000432133675, total_step : 3813, cur_epsilon : 0.4729
# episode : 182, done reward : 1.0000000298023224, total_step : 3834, cur_epsilon : 0.47219999999999995
# episode : 183, done reward : 1.4000000357627869, total_step : 3859, cur_epsilon : 0.47136666666666666
# episode : 184, done reward : 0.9000000283122063, total_step : 3879, cur_epsilon : 0.4707
# episode : 185, done reward : 1.2000000327825546, total_step : 3902, cur_epsilon : 0.4699333333333333
# episode : 186, done reward : 0.9000000283122063, total_step : 3922, cur_epsilon : 0.4692666666666666
# episode : 187, done reward : 1.3000000342726707, total_step : 3946, cur_epsilon : 0.46846666666666664
# episode : 188, done reward : 1.4000000357627869, total_step : 3971, cur_epsilon : 0.46763333333333335
# episode : 189, done reward : 1.0000000298023224, total_step : 3992, cur_epsilon : 0.4669333333333333
# episode : 190, done reward : 0.5000000223517418, total_step : 4008, cur_epsilon : 0.4664
# episode : 191, done reward : 1.3000000342726707, total_step : 4032, cur_epsilon : 0.4656
# episode : 192, done reward : 1.2000000327825546, total_step : 4055, cur_epsilon : 0.4648333333333333
# episode : 193, done reward : 1.8000000417232513, total_step : 4084, cur_epsilon : 0.46386666666666665
# episode : 194, done reward : 2.0000000447034836, total_step : 4115, cur_epsilon : 0.4628333333333333
# episode : 195, done reward : 1.2000000327825546, total_step : 4138, cur_epsilon : 0.4620666666666666
# episode : 196, done reward : 1.0000000298023224, total_step : 4159, cur_epsilon : 0.46136666666666665
# episode : 197, done reward : 1.2000000327825546, total_step : 4182, cur_epsilon : 0.4606
# episode : 198, done reward : 0.8000000268220901, total_step : 4201, cur_epsilon : 0.45996666666666663
# episode : 199, done reward : 1.3000000342726707, total_step : 4225, cur_epsilon : 0.4591666666666666
# episode : 200, done reward : 0.700000025331974, total_step : 4243, cur_epsilon : 0.4585666666666667
# episode : 201, done reward : 0.700000025331974, total_step : 4261, cur_epsilon : 0.45796666666666663
# episode : 202, done reward : 1.9000000432133675, total_step : 4291, cur_epsilon : 0.45696666666666663
# episode : 203, done reward : 1.7000000402331352, total_step : 4319, cur_epsilon : 0.4560333333333333
# episode : 204, done reward : 0.40000002086162567, total_step : 4334, cur_epsilon : 0.45553333333333335
# episode : 205, done reward : 1.1000000312924385, total_step : 4356, cur_epsilon : 0.4548
# episode : 206, done reward : 0.9000000283122063, total_step : 4376, cur_epsilon : 0.4541333333333333
# episode : 207, done reward : 1.0000000298023224, total_step : 4397, cur_epsilon : 0.4534333333333333
# episode : 208, done reward : 0.700000025331974, total_step : 4415, cur_epsilon : 0.4528333333333333
# episode : 209, done reward : 1.2000000327825546, total_step : 4438, cur_epsilon : 0.4520666666666666
# episode : 210, done reward : 1.0000000298023224, total_step : 4459, cur_epsilon : 0.45136666666666664
# episode : 211, done reward : 0.700000025331974, total_step : 4477, cur_epsilon : 0.45076666666666665
# episode : 212, done reward : 2.0000000447034836, total_step : 4508, cur_epsilon : 0.4497333333333333
# episode : 213, done reward : 1.1000000312924385, total_step : 4530, cur_epsilon : 0.44899999999999995
# episode : 214, done reward : 1.0000000298023224, total_step : 4551, cur_epsilon : 0.4483
# episode : 215, done reward : 1.600000038743019, total_step : 4578, cur_epsilon : 0.44739999999999996
# episode : 216, done reward : 0.8000000268220901, total_step : 4597, cur_epsilon : 0.44676666666666665
# episode : 217, done reward : 1.500000037252903, total_step : 4623, cur_epsilon : 0.44589999999999996
# episode : 218, done reward : 1.3000000342726707, total_step : 4647, cur_epsilon : 0.44509999999999994
# episode : 219, done reward : 1.4000000357627869, total_step : 4672, cur_epsilon : 0.44426666666666664
# episode : 220, done reward : 0.5000000223517418, total_step : 4688, cur_epsilon : 0.4437333333333333
# episode : 221, done reward : 1.500000037252903, total_step : 4714, cur_epsilon : 0.44286666666666663
# episode : 222, done reward : 1.8000000417232513, total_step : 4743, cur_epsilon : 0.44189999999999996
# episode : 223, done reward : 1.4000000357627869, total_step : 4768, cur_epsilon : 0.4410666666666666
# episode : 224, done reward : 1.2000000327825546, total_step : 4791, cur_epsilon : 0.44029999999999997
# episode : 225, done reward : 1.1000000312924385, total_step : 4813, cur_epsilon : 0.43956666666666666
# episode : 226, done reward : 0.700000025331974, total_step : 4831, cur_epsilon : 0.4389666666666666
# episode : 227, done reward : 0.9000000283122063, total_step : 4851, cur_epsilon : 0.43829999999999997
# episode : 228, done reward : 1.3000000342726707, total_step : 4875, cur_epsilon : 0.4375
# episode : 229, done reward : 1.2000000327825546, total_step : 4898, cur_epsilon : 0.4367333333333333
# episode : 230, done reward : 1.4000000357627869, total_step : 4923, cur_epsilon : 0.43589999999999995
# episode : 231, done reward : 1.2000000327825546, total_step : 4946, cur_epsilon : 0.4351333333333333
# episode : 232, done reward : 0.5000000223517418, total_step : 4962, cur_epsilon : 0.4346
# episode : 233, done reward : 0.700000025331974, total_step : 4980, cur_epsilon : 0.43399999999999994
# episode : 234, done reward : 0.700000025331974, total_step : 4998, cur_epsilon : 0.4334
# episode : 235, done reward : 0.8000000268220901, total_step : 5017, cur_epsilon : 0.43276666666666663
# episode : 236, done reward : 0.9000000283122063, total_step : 5037, cur_epsilon : 0.4321
# episode : 237, done reward : 1.3000000342726707, total_step : 5061, cur_epsilon : 0.4313
# episode : 238, done reward : 0.8000000268220901, total_step : 5080, cur_epsilon : 0.43066666666666664
# episode : 239, done reward : 0.8000000268220901, total_step : 5099, cur_epsilon : 0.4300333333333333
# episode : 240, done reward : 1.2000000327825546, total_step : 5122, cur_epsilon : 0.4292666666666667
# episode : 241, done reward : 1.3000000342726707, total_step : 5146, cur_epsilon : 0.42846666666666666
# episode : 242, done reward : 1.9000000432133675, total_step : 5176, cur_epsilon : 0.42746666666666666
# episode : 243, done reward : 1.1000000312924385, total_step : 5198, cur_epsilon : 0.4267333333333333
# episode : 244, done reward : 1.4000000357627869, total_step : 5223, cur_epsilon : 0.42589999999999995
# episode : 245, done reward : 0.8000000268220901, total_step : 5242, cur_epsilon : 0.4252666666666667
# episode : 246, done reward : 0.8000000268220901, total_step : 5261, cur_epsilon : 0.4246333333333333
# episode : 247, done reward : 1.1000000312924385, total_step : 5283, cur_epsilon : 0.42389999999999994
# episode : 248, done reward : 0.9000000283122063, total_step : 5303, cur_epsilon : 0.42323333333333335
# episode : 249, done reward : 0.40000002086162567, total_step : 5318, cur_epsilon : 0.4227333333333333
# episode : 250, done reward : 0.40000002086162567, total_step : 5333, cur_epsilon : 0.42223333333333335
# episode : 251, done reward : 1.0000000298023224, total_step : 5354, cur_epsilon : 0.4215333333333333
# episode : 252, done reward : 1.0000000298023224, total_step : 5375, cur_epsilon : 0.4208333333333333
# episode : 253, done reward : 0.9000000283122063, total_step : 5395, cur_epsilon : 0.42016666666666663
# episode : 254, done reward : 0.6000000238418579, total_step : 5412, cur_epsilon : 0.4196
# episode : 255, done reward : 1.0000000298023224, total_step : 5433, cur_epsilon : 0.41889999999999994
# episode : 256, done reward : 1.3000000342726707, total_step : 5457, cur_epsilon : 0.41809999999999997
# episode : 257, done reward : 1.0000000298023224, total_step : 5478, cur_epsilon : 0.4174
# episode : 258, done reward : 1.1000000312924385, total_step : 5500, cur_epsilon : 0.41666666666666663
# episode : 259, done reward : 0.6000000238418579, total_step : 5517, cur_epsilon : 0.41609999999999997
# episode : 260, done reward : 0.9000000283122063, total_step : 5537, cur_epsilon : 0.4154333333333333
# episode : 261, done reward : 1.1000000312924385, total_step : 5559, cur_epsilon : 0.41469999999999996
# episode : 262, done reward : 0.8000000268220901, total_step : 5578, cur_epsilon : 0.41406666666666664
# episode : 263, done reward : 0.6000000238418579, total_step : 5595, cur_epsilon : 0.4135
# episode : 264, done reward : 0.9000000283122063, total_step : 5615, cur_epsilon : 0.4128333333333333
# episode : 265, done reward : 0.8000000268220901, total_step : 5634, cur_epsilon : 0.4122
# episode : 266, done reward : 0.6000000238418579, total_step : 5651, cur_epsilon : 0.4116333333333333
# episode : 267, done reward : 0.40000002086162567, total_step : 5666, cur_epsilon : 0.41113333333333335
# episode : 268, done reward : 1.0000000298023224, total_step : 5687, cur_epsilon : 0.4104333333333333
# episode : 269, done reward : 0.6000000238418579, total_step : 5704, cur_epsilon : 0.40986666666666666
# episode : 270, done reward : 1.1000000312924385, total_step : 5726, cur_epsilon : 0.40913333333333335
# episode : 271, done reward : 0.40000002086162567, total_step : 5741, cur_epsilon : 0.4086333333333333
# episode : 272, done reward : 1.0000000298023224, total_step : 5762, cur_epsilon : 0.4079333333333333
# episode : 273, done reward : 0.700000025331974, total_step : 5780, cur_epsilon : 0.4073333333333333
# episode : 274, done reward : 0.700000025331974, total_step : 5798, cur_epsilon : 0.4067333333333333
# episode : 275, done reward : 0.40000002086162567, total_step : 5813, cur_epsilon : 0.40623333333333334
# episode : 276, done reward : 0.8000000268220901, total_step : 5832, cur_epsilon : 0.40559999999999996
# episode : 277, done reward : 1.1000000312924385, total_step : 5854, cur_epsilon : 0.40486666666666665
# episode : 278, done reward : 1.0000000298023224, total_step : 5875, cur_epsilon : 0.4041666666666667
# episode : 279, done reward : 0.8000000268220901, total_step : 5894, cur_epsilon : 0.4035333333333333
# episode : 280, done reward : 0.9000000283122063, total_step : 5914, cur_epsilon : 0.40286666666666665
# episode : 281, done reward : 0.9000000283122063, total_step : 5934, cur_epsilon : 0.4022
# episode : 282, done reward : 1.500000037252903, total_step : 5960, cur_epsilon : 0.4013333333333333
# episode : 283, done reward : 0.5000000223517418, total_step : 5976, cur_epsilon : 0.4008
# episode : 284, done reward : 1.2000000327825546, total_step : 5999, cur_epsilon : 0.40003333333333335
# episode : 285, done reward : 0.9000000283122063, total_step : 6019, cur_epsilon : 0.39936666666666665
# episode : 286, done reward : 1.1000000312924385, total_step : 6041, cur_epsilon : 0.3986333333333333
# episode : 287, done reward : 0.8000000268220901, total_step : 6060, cur_epsilon : 0.39799999999999996
# episode : 288, done reward : 0.9000000283122063, total_step : 6080, cur_epsilon : 0.3973333333333333
# episode : 289, done reward : 0.8000000268220901, total_step : 6099, cur_epsilon : 0.39669999999999994
# episode : 290, done reward : 0.700000025331974, total_step : 6117, cur_epsilon : 0.3961
# episode : 291, done reward : 0.6000000238418579, total_step : 6134, cur_epsilon : 0.3955333333333333
# episode : 292, done reward : 0.8000000268220901, total_step : 6153, cur_epsilon : 0.3949
# episode : 293, done reward : 1.1000000312924385, total_step : 6175, cur_epsilon : 0.39416666666666667
# episode : 294, done reward : 0.9000000283122063, total_step : 6195, cur_epsilon : 0.39349999999999996
# episode : 295, done reward : 0.8000000268220901, total_step : 6214, cur_epsilon : 0.39286666666666664
# episode : 296, done reward : 0.40000002086162567, total_step : 6229, cur_epsilon : 0.39236666666666664
# episode : 297, done reward : 0.8000000268220901, total_step : 6248, cur_epsilon : 0.3917333333333333
# episode : 298, done reward : 1.9000000432133675, total_step : 6278, cur_epsilon : 0.3907333333333333
# episode : 299, done reward : 0.700000025331974, total_step : 6296, cur_epsilon : 0.39013333333333333
# episode : 300, done reward : 1.4000000357627869, total_step : 6321, cur_epsilon : 0.3893
# episode : 301, done reward : 0.9000000283122063, total_step : 6341, cur_epsilon : 0.3886333333333333
# episode : 302, done reward : 1.2000000327825546, total_step : 6364, cur_epsilon : 0.38786666666666664
# episode : 303, done reward : 0.8000000268220901, total_step : 6383, cur_epsilon : 0.3872333333333333
# episode : 304, done reward : 0.8000000268220901, total_step : 6402, cur_epsilon : 0.38659999999999994
# episode : 305, done reward : 1.600000038743019, total_step : 6429, cur_epsilon : 0.3857
# episode : 306, done reward : 1.0000000298023224, total_step : 6450, cur_epsilon : 0.385
# episode : 307, done reward : 1.4000000357627869, total_step : 6475, cur_epsilon : 0.38416666666666666
# episode : 308, done reward : 1.0000000298023224, total_step : 6496, cur_epsilon : 0.3834666666666666
# episode : 309, done reward : 0.9000000283122063, total_step : 6516, cur_epsilon : 0.3828
# episode : 310, done reward : 1.1000000312924385, total_step : 6538, cur_epsilon : 0.38206666666666667
# episode : 311, done reward : 0.700000025331974, total_step : 6556, cur_epsilon : 0.3814666666666666
# episode : 312, done reward : 1.2000000327825546, total_step : 6579, cur_epsilon : 0.3807
# episode : 313, done reward : 1.3000000342726707, total_step : 6603, cur_epsilon : 0.3799
# episode : 314, done reward : 1.3000000342726707, total_step : 6627, cur_epsilon : 0.3791
# episode : 315, done reward : 1.0000000298023224, total_step : 6648, cur_epsilon : 0.37839999999999996
# episode : 316, done reward : 1.3000000342726707, total_step : 6672, cur_epsilon : 0.3776
# episode : 317, done reward : 0.6000000238418579, total_step : 6689, cur_epsilon : 0.37703333333333333
# episode : 318, done reward : 0.8000000268220901, total_step : 6708, cur_epsilon : 0.37639999999999996
# episode : 319, done reward : 1.500000037252903, total_step : 6734, cur_epsilon : 0.3755333333333333
# episode : 320, done reward : 1.1000000312924385, total_step : 6756, cur_epsilon : 0.37479999999999997
# episode : 321, done reward : 1.4000000357627869, total_step : 6781, cur_epsilon : 0.37396666666666667
# episode : 322, done reward : 0.6000000238418579, total_step : 6798, cur_epsilon : 0.37339999999999995
# episode : 323, done reward : 0.8000000268220901, total_step : 6817, cur_epsilon : 0.37276666666666664
# episode : 324, done reward : 0.5000000223517418, total_step : 6833, cur_epsilon : 0.3722333333333333
# episode : 325, done reward : 0.9000000283122063, total_step : 6853, cur_epsilon : 0.37156666666666666
# episode : 326, done reward : 1.0000000298023224, total_step : 6874, cur_epsilon : 0.3708666666666667
# episode : 327, done reward : 1.600000038743019, total_step : 6901, cur_epsilon : 0.36996666666666667
# episode : 328, done reward : 1.8000000417232513, total_step : 6930, cur_epsilon : 0.369
# episode : 329, done reward : 1.8000000417232513, total_step : 6959, cur_epsilon : 0.3680333333333333
# episode : 330, done reward : 0.5000000223517418, total_step : 6975, cur_epsilon : 0.36749999999999994
# episode : 331, done reward : 1.2000000327825546, total_step : 6998, cur_epsilon : 0.3667333333333333
# episode : 332, done reward : 0.40000002086162567, total_step : 7013, cur_epsilon : 0.3662333333333333
# episode : 333, done reward : 0.6000000238418579, total_step : 7030, cur_epsilon : 0.36566666666666664
# episode : 334, done reward : 0.700000025331974, total_step : 7048, cur_epsilon : 0.36506666666666665
# episode : 335, done reward : 1.3000000342726707, total_step : 7072, cur_epsilon : 0.3642666666666666
# episode : 336, done reward : 1.600000038743019, total_step : 7099, cur_epsilon : 0.3633666666666666
# episode : 337, done reward : 1.0000000298023224, total_step : 7120, cur_epsilon : 0.36266666666666664
# episode : 338, done reward : 1.1000000312924385, total_step : 7142, cur_epsilon : 0.36193333333333333
# episode : 339, done reward : 0.700000025331974, total_step : 7160, cur_epsilon : 0.3613333333333333
# episode : 340, done reward : 1.500000037252903, total_step : 7186, cur_epsilon : 0.36046666666666666
# episode : 341, done reward : 0.5000000223517418, total_step : 7202, cur_epsilon : 0.3599333333333333
# episode : 342, done reward : 0.9000000283122063, total_step : 7222, cur_epsilon : 0.3592666666666666
# episode : 343, done reward : 1.0000000298023224, total_step : 7243, cur_epsilon : 0.35856666666666664
# episode : 344, done reward : 0.5000000223517418, total_step : 7259, cur_epsilon : 0.3580333333333333
# episode : 345, done reward : 0.6000000238418579, total_step : 7276, cur_epsilon : 0.35746666666666665
# episode : 346, done reward : 0.40000002086162567, total_step : 7291, cur_epsilon : 0.35696666666666665
# episode : 347, done reward : 1.2000000327825546, total_step : 7314, cur_epsilon : 0.35619999999999996
# episode : 348, done reward : 3.100000061094761, total_step : 7356, cur_epsilon : 0.3548
# episode : 349, done reward : 0.5000000223517418, total_step : 7372, cur_epsilon : 0.3542666666666666
# episode : 350, done reward : 1.0000000298023224, total_step : 7393, cur_epsilon : 0.35356666666666664
# episode : 351, done reward : 1.500000037252903, total_step : 7419, cur_epsilon : 0.3527
# episode : 352, done reward : 1.1000000312924385, total_step : 7441, cur_epsilon : 0.35196666666666665
# episode : 353, done reward : 0.8000000268220901, total_step : 7460, cur_epsilon : 0.3513333333333333
# episode : 354, done reward : 1.0000000298023224, total_step : 7481, cur_epsilon : 0.35063333333333335
# episode : 355, done reward : 0.6000000238418579, total_step : 7498, cur_epsilon : 0.35006666666666664
# episode : 356, done reward : 0.700000025331974, total_step : 7516, cur_epsilon : 0.34946666666666665
# episode : 357, done reward : 1.0000000298023224, total_step : 7537, cur_epsilon : 0.34876666666666667
# episode : 358, done reward : 0.5000000223517418, total_step : 7553, cur_epsilon : 0.3482333333333333
# episode : 359, done reward : 1.1000000312924385, total_step : 7575, cur_epsilon : 0.3475
# episode : 360, done reward : 1.2000000327825546, total_step : 7598, cur_epsilon : 0.34673333333333334
# episode : 361, done reward : 1.600000038743019, total_step : 7625, cur_epsilon : 0.3458333333333333
# episode : 362, done reward : 0.9000000283122063, total_step : 7645, cur_epsilon : 0.3451666666666666
# episode : 363, done reward : 1.1000000312924385, total_step : 7667, cur_epsilon : 0.3444333333333333
# episode : 364, done reward : 0.700000025331974, total_step : 7685, cur_epsilon : 0.3438333333333333
# episode : 365, done reward : 1.3000000342726707, total_step : 7709, cur_epsilon : 0.3430333333333333
# episode : 366, done reward : 0.8000000268220901, total_step : 7728, cur_epsilon : 0.3424
# episode : 367, done reward : 0.6000000238418579, total_step : 7745, cur_epsilon : 0.3418333333333333
# episode : 368, done reward : 0.9000000283122063, total_step : 7765, cur_epsilon : 0.3411666666666666
# episode : 369, done reward : 0.6000000238418579, total_step : 7782, cur_epsilon : 0.34059999999999996
# episode : 370, done reward : 0.9000000283122063, total_step : 7802, cur_epsilon : 0.3399333333333333
# episode : 371, done reward : 0.9000000283122063, total_step : 7822, cur_epsilon : 0.33926666666666666
# episode : 372, done reward : 1.2000000327825546, total_step : 7845, cur_epsilon : 0.33849999999999997
# episode : 373, done reward : 0.9000000283122063, total_step : 7865, cur_epsilon : 0.3378333333333333
# episode : 374, done reward : 1.500000037252903, total_step : 7891, cur_epsilon : 0.33696666666666664
# episode : 375, done reward : 0.40000002086162567, total_step : 7906, cur_epsilon : 0.33646666666666664
# episode : 376, done reward : 1.3000000342726707, total_step : 7930, cur_epsilon : 0.33566666666666667
# episode : 377, done reward : 1.2000000327825546, total_step : 7953, cur_epsilon : 0.3349
# episode : 378, done reward : 1.600000038743019, total_step : 7980, cur_epsilon : 0.33399999999999996
# episode : 379, done reward : 1.4000000357627869, total_step : 8005, cur_epsilon : 0.33316666666666667
# episode : 380, done reward : 1.0000000298023224, total_step : 8026, cur_epsilon : 0.33246666666666663
# episode : 381, done reward : 0.6000000238418579, total_step : 8043, cur_epsilon : 0.3319
# episode : 382, done reward : 0.8000000268220901, total_step : 8062, cur_epsilon : 0.33126666666666665
# episode : 383, done reward : 0.8000000268220901, total_step : 8081, cur_epsilon : 0.33063333333333333
# episode : 384, done reward : 1.3000000342726707, total_step : 8105, cur_epsilon : 0.3298333333333333
# episode : 385, done reward : 1.1000000312924385, total_step : 8127, cur_epsilon : 0.3291
# episode : 386, done reward : 1.4000000357627869, total_step : 8152, cur_epsilon : 0.32826666666666665
# episode : 387, done reward : 1.3000000342726707, total_step : 8176, cur_epsilon : 0.32746666666666663
# episode : 388, done reward : 1.0000000298023224, total_step : 8197, cur_epsilon : 0.32676666666666665
# episode : 389, done reward : 0.9000000283122063, total_step : 8217, cur_epsilon : 0.3261
# episode : 390, done reward : 0.5000000223517418, total_step : 8233, cur_epsilon : 0.32556666666666667
# episode : 391, done reward : 1.3000000342726707, total_step : 8257, cur_epsilon : 0.32476666666666665
# episode : 392, done reward : 0.8000000268220901, total_step : 8276, cur_epsilon : 0.32413333333333333
# episode : 393, done reward : 1.0000000298023224, total_step : 8297, cur_epsilon : 0.3234333333333333
# episode : 394, done reward : 2.1000000461935997, total_step : 8329, cur_epsilon : 0.32236666666666663
# episode : 395, done reward : 1.3000000342726707, total_step : 8353, cur_epsilon : 0.32156666666666667
# episode : 396, done reward : 0.9000000283122063, total_step : 8373, cur_epsilon : 0.32089999999999996
# episode : 397, done reward : 0.9000000283122063, total_step : 8393, cur_epsilon : 0.3202333333333333
# episode : 398, done reward : 1.0000000298023224, total_step : 8414, cur_epsilon : 0.31953333333333334
# episode : 399, done reward : 2.7000000551342964, total_step : 8452, cur_epsilon : 0.31826666666666664
# episode : 400, done reward : 1.4000000357627869, total_step : 8477, cur_epsilon : 0.3174333333333333
# episode : 401, done reward : 1.7000000402331352, total_step : 8505, cur_epsilon : 0.3165
# episode : 402, done reward : 0.8000000268220901, total_step : 8524, cur_epsilon : 0.31586666666666663
# episode : 403, done reward : 0.40000002086162567, total_step : 8539, cur_epsilon : 0.31536666666666663
# episode : 404, done reward : 1.2000000327825546, total_step : 8562, cur_epsilon : 0.3146
# episode : 405, done reward : 0.5000000223517418, total_step : 8578, cur_epsilon : 0.31406666666666666
# episode : 406, done reward : 1.500000037252903, total_step : 8604, cur_epsilon : 0.3132
# episode : 407, done reward : 0.8000000268220901, total_step : 8623, cur_epsilon : 0.31256666666666666
# episode : 408, done reward : 0.8000000268220901, total_step : 8642, cur_epsilon : 0.3119333333333333
# episode : 409, done reward : 0.9000000283122063, total_step : 8662, cur_epsilon : 0.31126666666666664
# episode : 410, done reward : 0.6000000238418579, total_step : 8679, cur_epsilon : 0.3107
# episode : 411, done reward : 1.9000000432133675, total_step : 8709, cur_epsilon : 0.3097
# episode : 412, done reward : 0.9000000283122063, total_step : 8729, cur_epsilon : 0.3090333333333333
# episode : 413, done reward : 0.5000000223517418, total_step : 8745, cur_epsilon : 0.3085
# episode : 414, done reward : 0.700000025331974, total_step : 8763, cur_epsilon : 0.30789999999999995
# episode : 415, done reward : 1.1000000312924385, total_step : 8785, cur_epsilon : 0.30716666666666664
# episode : 416, done reward : 0.9000000283122063, total_step : 8805, cur_epsilon : 0.3065
# episode : 417, done reward : 0.6000000238418579, total_step : 8822, cur_epsilon : 0.30593333333333333
# episode : 418, done reward : 1.8000000417232513, total_step : 8851, cur_epsilon : 0.30496666666666666
# episode : 419, done reward : 0.5000000223517418, total_step : 8867, cur_epsilon : 0.30443333333333333
# episode : 420, done reward : 1.4000000357627869, total_step : 8892, cur_epsilon : 0.3036
# episode : 421, done reward : 0.5000000223517418, total_step : 8908, cur_epsilon : 0.30306666666666665
# episode : 422, done reward : 1.2000000327825546, total_step : 8931, cur_epsilon : 0.30229999999999996
# episode : 423, done reward : 1.3000000342726707, total_step : 8955, cur_epsilon : 0.3015
# episode : 424, done reward : 1.1000000312924385, total_step : 8977, cur_epsilon : 0.3007666666666666
# episode : 425, done reward : 1.9000000432133675, total_step : 9007, cur_epsilon : 0.2997666666666666
# episode : 426, done reward : 1.7000000402331352, total_step : 9035, cur_epsilon : 0.2988333333333333
# episode : 427, done reward : 0.700000025331974, total_step : 9053, cur_epsilon : 0.2982333333333333
# episode : 428, done reward : 1.0000000298023224, total_step : 9074, cur_epsilon : 0.2975333333333333
# episode : 429, done reward : 0.700000025331974, total_step : 9092, cur_epsilon : 0.2969333333333333
# episode : 430, done reward : 0.5000000223517418, total_step : 9108, cur_epsilon : 0.2964
# episode : 431, done reward : 1.0000000298023224, total_step : 9129, cur_epsilon : 0.29569999999999996
# episode : 432, done reward : 1.600000038743019, total_step : 9156, cur_epsilon : 0.29479999999999995
# episode : 433, done reward : 0.700000025331974, total_step : 9174, cur_epsilon : 0.29419999999999996
# episode : 434, done reward : 0.5000000223517418, total_step : 9190, cur_epsilon : 0.29366666666666663
# episode : 435, done reward : 0.5000000223517418, total_step : 9206, cur_epsilon : 0.2931333333333333
# episode : 436, done reward : 3.0000000596046448, total_step : 9247, cur_epsilon : 0.2917666666666666
# episode : 437, done reward : 1.3000000342726707, total_step : 9271, cur_epsilon : 0.29096666666666665
# episode : 438, done reward : 0.9000000283122063, total_step : 9291, cur_epsilon : 0.2903
# episode : 439, done reward : 1.4000000357627869, total_step : 9316, cur_epsilon : 0.28946666666666665
# episode : 440, done reward : 1.1000000312924385, total_step : 9338, cur_epsilon : 0.2887333333333333
# episode : 441, done reward : 1.3000000342726707, total_step : 9362, cur_epsilon : 0.2879333333333333
# episode : 442, done reward : 0.8000000268220901, total_step : 9381, cur_epsilon : 0.2873
# episode : 443, done reward : 1.1000000312924385, total_step : 9403, cur_epsilon : 0.28656666666666664
# episode : 444, done reward : 1.2000000327825546, total_step : 9426, cur_epsilon : 0.2858
# episode : 445, done reward : 0.700000025331974, total_step : 9444, cur_epsilon : 0.28519999999999995
# episode : 446, done reward : 1.3000000342726707, total_step : 9468, cur_epsilon : 0.2844
# episode : 447, done reward : 1.1000000312924385, total_step : 9490, cur_epsilon : 0.2836666666666666
# episode : 448, done reward : 1.2000000327825546, total_step : 9513, cur_epsilon : 0.2829
# episode : 449, done reward : 0.700000025331974, total_step : 9531, cur_epsilon : 0.2823
# episode : 450, done reward : 0.40000002086162567, total_step : 9546, cur_epsilon : 0.2818
# episode : 451, done reward : 1.1000000312924385, total_step : 9568, cur_epsilon : 0.28106666666666663
# episode : 452, done reward : 1.500000037252903, total_step : 9594, cur_epsilon : 0.2802
# episode : 453, done reward : 0.5000000223517418, total_step : 9610, cur_epsilon : 0.2796666666666666
# episode : 454, done reward : 1.600000038743019, total_step : 9637, cur_epsilon : 0.27876666666666666
# episode : 455, done reward : 0.8000000268220901, total_step : 9656, cur_epsilon : 0.2781333333333333
# episode : 456, done reward : 1.4000000357627869, total_step : 9681, cur_epsilon : 0.2773
# episode : 457, done reward : 2.300000049173832, total_step : 9715, cur_epsilon : 0.27616666666666667
# episode : 458, done reward : 1.0000000298023224, total_step : 9736, cur_epsilon : 0.27546666666666664
# episode : 459, done reward : 1.0000000298023224, total_step : 9757, cur_epsilon : 0.27476666666666666
# episode : 460, done reward : 0.6000000238418579, total_step : 9774, cur_epsilon : 0.2742
# episode : 461, done reward : 1.0000000298023224, total_step : 9795, cur_epsilon : 0.27349999999999997
# episode : 462, done reward : 1.1000000312924385, total_step : 9817, cur_epsilon : 0.27276666666666666
# episode : 463, done reward : 0.700000025331974, total_step : 9835, cur_epsilon : 0.27216666666666667
# episode : 464, done reward : 0.9000000283122063, total_step : 9855, cur_epsilon : 0.27149999999999996
# episode : 465, done reward : 2.1000000461935997, total_step : 9887, cur_epsilon : 0.2704333333333333
# episode : 466, done reward : 0.40000002086162567, total_step : 9902, cur_epsilon : 0.2699333333333333
# episode : 467, done reward : 0.9000000283122063, total_step : 9922, cur_epsilon : 0.26926666666666665
# episode : 468, done reward : 1.1000000312924385, total_step : 9944, cur_epsilon : 0.2685333333333333
# episode : 469, done reward : 1.600000038743019, total_step : 9971, cur_epsilon : 0.26763333333333333
# episode : 470, done reward : 1.4000000357627869, total_step : 9996, cur_epsilon : 0.2668
# episode : 471, done reward : 1.4000000357627869, total_step : 10021, cur_epsilon : 0.26596666666666663
# episode : 472, done reward : 1.2000000327825546, total_step : 10044, cur_epsilon : 0.2652
# episode : 473, done reward : 1.2000000327825546, total_step : 10067, cur_epsilon : 0.2644333333333333
# episode : 474, done reward : 0.700000025331974, total_step : 10085, cur_epsilon : 0.2638333333333333
# episode : 475, done reward : 1.2000000327825546, total_step : 10108, cur_epsilon : 0.26306666666666667
# episode : 476, done reward : 0.9000000283122063, total_step : 10128, cur_epsilon : 0.26239999999999997
# episode : 477, done reward : 1.7000000402331352, total_step : 10156, cur_epsilon : 0.2614666666666666
# episode : 478, done reward : 1.4000000357627869, total_step : 10181, cur_epsilon : 0.26063333333333333
# episode : 479, done reward : 1.600000038743019, total_step : 10208, cur_epsilon : 0.2597333333333333
# episode : 480, done reward : 3.0000000596046448, total_step : 10249, cur_epsilon : 0.25836666666666663
# episode : 481, done reward : 1.500000037252903, total_step : 10275, cur_epsilon : 0.25749999999999995
# episode : 482, done reward : 1.1000000312924385, total_step : 10297, cur_epsilon : 0.25676666666666664
# episode : 483, done reward : 0.8000000268220901, total_step : 10316, cur_epsilon : 0.2561333333333333
# episode : 484, done reward : 0.8000000268220901, total_step : 10335, cur_epsilon : 0.2555
# episode : 485, done reward : 1.7000000402331352, total_step : 10363, cur_epsilon : 0.25456666666666666
# episode : 486, done reward : 1.8000000417232513, total_step : 10392, cur_epsilon : 0.2536
# episode : 487, done reward : 0.40000002086162567, total_step : 10407, cur_epsilon : 0.2531
# ...
# episode : 1275, done reward : 2.6000000536441803, total_step : 29350, cur_epsilon : 0.002
# episode : 1276, done reward : 1.500000037252903, total_step : 29376, cur_epsilon : 0.002
# episode : 1277, done reward : 1.4000000357627869, total_step : 29401, cur_epsilon : 0.002
# episode : 1278, done reward : 1.1000000312924385, total_step : 29423, cur_epsilon : 0.002
# episode : 1279, done reward : 1.600000038743019, total_step : 29450, cur_epsilon : 0.002
# episode : 1280, done reward : 3.6000000685453415, total_step : 29497, cur_epsilon : 0.002
# episode : 1281, done reward : 0.5000000223517418, total_step : 29513, cur_epsilon : 0.002
# episode : 1282, done reward : 1.9000000432133675, total_step : 29543, cur_epsilon : 0.002
# episode : 1283, done reward : 0.5000000223517418, total_step : 29559, cur_epsilon : 0.002
# episode : 1284, done reward : 0.700000025331974, total_step : 29577, cur_epsilon : 0.002
# episode : 1285, done reward : 1.500000037252903, total_step : 29603, cur_epsilon : 0.002
# episode : 1286, done reward : 0.6000000238418579, total_step : 29620, cur_epsilon : 0.002
# episode : 1287, done reward : 1.0000000298023224, total_step : 29641, cur_epsilon : 0.002
# episode : 1288, done reward : 4.500000081956387, total_step : 29697, cur_epsilon : 0.002
# episode : 1289, done reward : 0.9000000283122063, total_step : 29717, cur_epsilon : 0.002
# episode : 1290, done reward : 0.40000002086162567, total_step : 29732, cur_epsilon : 0.002
# episode : 1291, done reward : 4.000000074505806, total_step : 29783, cur_epsilon : 0.002
# episode : 1292, done reward : 1.3000000342726707, total_step : 29807, cur_epsilon : 0.002
# episode : 1293, done reward : 0.8000000268220901, total_step : 29826, cur_epsilon : 0.002
# episode : 1294, done reward : 1.3000000342726707, total_step : 29850, cur_epsilon : 0.002
# episode : 1295, done reward : 1.7000000402331352, total_step : 29878, cur_epsilon : 0.002
# episode : 1296, done reward : 0.8000000268220901, total_step : 29897, cur_epsilon : 0.002
# episode : 1297, done reward : 1.600000038743019, total_step : 29924, cur_epsilon : 0.002
# episode : 1298, done reward : 1.1000000312924385, total_step : 29946, cur_epsilon : 0.002
# episode : 1299, done reward : 1.4000000357627869, total_step : 29971, cur_epsilon : 0.002
# episode : 1300, done reward : 1.0000000298023224, total_step : 29992, cur_epsilon : 0.002
# episode : 1301, done reward : 1.2000000327825546, total_step : 30015, cur_epsilon : 0.002
# episode : 1302, done reward : 1.2000000327825546, total_step : 30038, cur_epsilon : 0.002
# episode : 1303, done reward : 0.40000002086162567, total_step : 30053, cur_epsilon : 0.002
# episode : 1304, done reward : 1.2000000327825546, total_step : 30076, cur_epsilon : 0.002
# episode : 1305, done reward : 0.700000025331974, total_step : 30094, cur_epsilon : 0.002
# episode : 1306, done reward : 0.8000000268220901, total_step : 30113, cur_epsilon : 0.002
# episode : 1307, done reward : 2.6000000536441803, total_step : 30150, cur_epsilon : 0.002
# episode : 1308, done reward : 0.8000000268220901, total_step : 30169, cur_epsilon : 0.002
# episode : 1309, done reward : 0.700000025331974, total_step : 30187, cur_epsilon : 0.002
# episode : 1310, done reward : 0.8000000268220901, total_step : 30206, cur_epsilon : 0.002
# episode : 1311, done reward : 1.1000000312924385, total_step : 30228, cur_epsilon : 0.002
# episode : 1312, done reward : 1.3000000342726707, total_step : 30252, cur_epsilon : 0.002
# episode : 1313, done reward : 1.8000000417232513, total_step : 30281, cur_epsilon : 0.002
# episode : 1314, done reward : 3.300000064074993, total_step : 30325, cur_epsilon : 0.002
# episode : 1315, done reward : 0.700000025331974, total_step : 30343, cur_epsilon : 0.002
# episode : 1316, done reward : 2.1000000461935997, total_step : 30375, cur_epsilon : 0.002
# episode : 1317, done reward : 1.4000000357627869, total_step : 30400, cur_epsilon : 0.002
# episode : 1318, done reward : 1.4000000357627869, total_step : 30425, cur_epsilon : 0.002
# episode : 1319, done reward : 0.6000000238418579, total_step : 30442, cur_epsilon : 0.002
# episode : 1320, done reward : 0.5000000223517418, total_step : 30458, cur_epsilon : 0.002
# episode : 1321, done reward : 0.6000000238418579, total_step : 30475, cur_epsilon : 0.002
# episode : 1322, done reward : 0.9000000283122063, total_step : 30495, cur_epsilon : 0.002
# episode : 1323, done reward : 0.9000000283122063, total_step : 30515, cur_epsilon : 0.002
# episode : 1324, done reward : 2.500000052154064, total_step : 30551, cur_epsilon : 0.002
# episode : 1325, done reward : 0.40000002086162567, total_step : 30566, cur_epsilon : 0.002
# episode : 1326, done reward : 1.3000000342726707, total_step : 30590, cur_epsilon : 0.002
# episode : 1327, done reward : 1.0000000298023224, total_step : 30611, cur_epsilon : 0.002
# episode : 1328, done reward : 1.1000000312924385, total_step : 30633, cur_epsilon : 0.002
# episode : 1329, done reward : 2.8000000566244125, total_step : 30672, cur_epsilon : 0.002
# episode : 1330, done reward : 1.600000038743019, total_step : 30699, cur_epsilon : 0.002
# episode : 1331, done reward : 2.400000050663948, total_step : 30734, cur_epsilon : 0.002
# episode : 1332, done reward : 1.2000000327825546, total_step : 30757, cur_epsilon : 0.002
# episode : 1333, done reward : 0.9000000283122063, total_step : 30777, cur_epsilon : 0.002
# episode : 1334, done reward : 0.8000000268220901, total_step : 30796, cur_epsilon : 0.002
# episode : 1335, done reward : 1.500000037252903, total_step : 30822, cur_epsilon : 0.002
# episode : 1336, done reward : 4.600000083446503, total_step : 30879, cur_epsilon : 0.002
# episode : 1337, done reward : 0.700000025331974, total_step : 30897, cur_epsilon : 0.002
# episode : 1338, done reward : 3.100000061094761, total_step : 30939, cur_epsilon : 0.002
# episode : 1339, done reward : 0.9000000283122063, total_step : 30959, cur_epsilon : 0.002
# episode : 1340, done reward : 1.3000000342726707, total_step : 30983, cur_epsilon : 0.002
# episode : 1341, done reward : 0.9000000283122063, total_step : 31003, cur_epsilon : 0.002
# episode : 1342, done reward : 1.2000000327825546, total_step : 31026, cur_epsilon : 0.002
# episode : 1343, done reward : 3.0000000596046448, total_step : 31067, cur_epsilon : 0.002
# episode : 1344, done reward : 1.500000037252903, total_step : 31093, cur_epsilon : 0.002
# episode : 1345, done reward : 2.200000047683716, total_step : 31126, cur_epsilon : 0.002
# episode : 1346, done reward : 1.2000000327825546, total_step : 31149, cur_epsilon : 0.002
# episode : 1347, done reward : 1.2000000327825546, total_step : 31172, cur_epsilon : 0.002
# episode : 1348, done reward : 0.9000000283122063, total_step : 31192, cur_epsilon : 0.002
# episode : 1349, done reward : 1.3000000342726707, total_step : 31216, cur_epsilon : 0.002
# episode : 1350, done reward : 0.9000000283122063, total_step : 31236, cur_epsilon : 0.002
# episode : 1351, done reward : 2.7000000551342964, total_step : 31274, cur_epsilon : 0.002
# episode : 1352, done reward : 1.1000000312924385, total_step : 31296, cur_epsilon : 0.002
# episode : 1353, done reward : 1.2000000327825546, total_step : 31319, cur_epsilon : 0.002
# episode : 1354, done reward : 1.1000000312924385, total_step : 31341, cur_epsilon : 0.002
# episode : 1355, done reward : 1.9000000432133675, total_step : 31371, cur_epsilon : 0.002
# episode : 1356, done reward : 1.2000000327825546, total_step : 31394, cur_epsilon : 0.002
# episode : 1357, done reward : 1.0000000298023224, total_step : 31415, cur_epsilon : 0.002
# episode : 1358, done reward : 1.0000000298023224, total_step : 31436, cur_epsilon : 0.002
# episode : 1359, done reward : 1.3000000342726707, total_step : 31460, cur_epsilon : 0.002
# episode : 1360, done reward : 1.2000000327825546, total_step : 31483, cur_epsilon : 0.002
# episode : 1361, done reward : 2.8000000566244125, total_step : 31522, cur_epsilon : 0.002
# episode : 1362, done reward : 0.20000001788139343, total_step : 31535, cur_epsilon : 0.002
# episode : 1363, done reward : 1.4000000357627869, total_step : 31560, cur_epsilon : 0.002
# episode : 1364, done reward : 1.7000000402331352, total_step : 31588, cur_epsilon : 0.002
# episode : 1365, done reward : 4.4000000804662704, total_step : 31643, cur_epsilon : 0.002
# episode : 1366, done reward : 0.8000000268220901, total_step : 31662, cur_epsilon : 0.002
# episode : 1367, done reward : 0.700000025331974, total_step : 31680, cur_epsilon : 0.002
# episode : 1368, done reward : 0.6000000238418579, total_step : 31697, cur_epsilon : 0.002
# episode : 1369, done reward : 1.7000000402331352, total_step : 31725, cur_epsilon : 0.002
# episode : 1370, done reward : 1.1000000312924385, total_step : 31747, cur_epsilon : 0.002
# episode : 1371, done reward : 1.3000000342726707, total_step : 31771, cur_epsilon : 0.002
# episode : 1372, done reward : 2.7000000551342964, total_step : 31809, cur_epsilon : 0.002
# episode : 1373, done reward : 0.8000000268220901, total_step : 31828, cur_epsilon : 0.002
# episode : 1374, done reward : 0.5000000223517418, total_step : 31844, cur_epsilon : 0.002
# episode : 1375, done reward : 1.3000000342726707, total_step : 31868, cur_epsilon : 0.002
# episode : 1376, done reward : 0.9000000283122063, total_step : 31888, cur_epsilon : 0.002
# episode : 1377, done reward : 0.6000000238418579, total_step : 31905, cur_epsilon : 0.002
# episode : 1378, done reward : 1.0000000298023224, total_step : 31926, cur_epsilon : 0.002
# episode : 1379, done reward : 3.200000062584877, total_step : 31969, cur_epsilon : 0.002
# episode : 1380, done reward : 0.700000025331974, total_step : 31987, cur_epsilon : 0.002
# episode : 1381, done reward : 1.3000000342726707, total_step : 32011, cur_epsilon : 0.002
# episode : 1382, done reward : 1.2000000327825546, total_step : 32034, cur_epsilon : 0.002
# episode : 1383, done reward : 0.9000000283122063, total_step : 32054, cur_epsilon : 0.002
# episode : 1384, done reward : 0.6000000238418579, total_step : 32071, cur_epsilon : 0.002
# episode : 1385, done reward : 1.3000000342726707, total_step : 32095, cur_epsilon : 0.002
# episode : 1386, done reward : 1.1000000312924385, total_step : 32117, cur_epsilon : 0.002
# episode : 1387, done reward : 0.8000000268220901, total_step : 32136, cur_epsilon : 0.002
# episode : 1388, done reward : 1.0000000298023224, total_step : 32157, cur_epsilon : 0.002
# episode : 1389, done reward : 1.2000000327825546, total_step : 32180, cur_epsilon : 0.002
# episode : 1390, done reward : 1.2000000327825546, total_step : 32203, cur_epsilon : 0.002
# episode : 1391, done reward : 0.6000000238418579, total_step : 32220, cur_epsilon : 0.002
# episode : 1392, done reward : 1.3000000342726707, total_step : 32244, cur_epsilon : 0.002
# episode : 1393, done reward : 1.2000000327825546, total_step : 32267, cur_epsilon : 0.002
# episode : 1394, done reward : 0.5000000223517418, total_step : 32283, cur_epsilon : 0.002
# episode : 1395, done reward : 1.0000000298023224, total_step : 32304, cur_epsilon : 0.002
# episode : 1396, done reward : 1.2000000327825546, total_step : 32327, cur_epsilon : 0.002
# episode : 1397, done reward : 1.600000038743019, total_step : 32354, cur_epsilon : 0.002
# episode : 1398, done reward : 0.8000000268220901, total_step : 32373, cur_epsilon : 0.002
# episode : 1399, done reward : 1.500000037252903, total_step : 32399, cur_epsilon : 0.002
# episode : 1400, done reward : 1.7000000402331352, total_step : 32427, cur_epsilon : 0.002
# episode : 1401, done reward : 1.1000000312924385, total_step : 32449, cur_epsilon : 0.002
# episode : 1402, done reward : 2.6000000536441803, total_step : 32486, cur_epsilon : 0.002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[309], line 11
#       8 while True:
#      10     for stp in range(20):
# ---> 11         done_reward = agent.play_step()
#      12         if done_reward is not None:
#      13             print(f'episode : {episode}, done reward : {done_reward}, total_step : {agent._total_step}, cur_epsilon : {agent._epsilon}')
#
# File ~/.cache/pypoetry/virtualenvs/mlagent-learn-20-test-54-2MrXv-py3.9/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[187], line 67, in Agent.play_step(self, epsilon, sync_target)
#      64     action = mu_v.squeeze(dim=0).data.cpu().numpy()
#      65     action = np.clip(action, -1, 1)
# ---> 67 next_state, reward, is_done, _ = self._env.step(action)
#      68 self._total_reward += reward
#      70 bonus_reward = self._bonus_reward_factor * self._episode_steps
#
# Cell In[188], line 10, in UnityToGymNumpyWrapper.step(self, *args, **kwargs)
#       9 def step(self, *args, **kwargs):
# ---> 10     next_state, reward, is_done, info = super().step(*args, **kwargs)
#      11     return np.array(next_state[0]), reward, is_done, info
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/envs/unity_gym_env.py:200, in UnityToGymWrapper.step(self, action)
#     197     action_tuple.add_discrete(action)
#     198 self._env.set_actions(self.name, action_tuple)
# --> 200 self._env.step()
#     201 decision_step, terminal_step = self._env.get_steps(self.name)
#     202 self._check_agents(max(len(decision_step), len(terminal_step)))
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/environment.py:348, in UnityEnvironment.step(self)
#     346 step_input = self._generate_step_input(self._env_actions)
#     347 with hierarchical_timer("communicator.exchange"):
# --> 348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
#     350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/rpc_communicator.py:142, in RpcCommunicator.exchange(self, inputs, poll_callback)
#     140 message.unity_input.CopyFrom(inputs)
#     141 self.unity_to_external.parent_conn.send(message)
# --> 142 self.poll_for_timeout(poll_callback)
#     143 output = self.unity_to_external.parent_conn.recv()
#     144 if output.header.status != 200:
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/rpc_communicator.py:106, in RpcCommunicator.poll_for_timeout(self, poll_callback)
#     104 callback_timeout_wait = self.timeout_wait // 10
#     105 while time.monotonic() < deadline:
# --> 106     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#     107         # Got an acknowledgment from the connection
#     108         return
#     109     if poll_callback:
#     110         # Fire the callback - if it detects something wrong, it should raise an exception.
#
# File /usr/lib/python3.9/multiprocessing/connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File /usr/lib/python3.9/multiprocessing/connection.py:429, in Connection._poll(self, timeout)
#     428 def _poll(self, timeout):
# --> 429     r = wait([self], timeout)
#     430     return bool(r)
#
# File /usr/lib/python3.9/multiprocessing/connection.py:936, in wait(object_list, timeout)
#     933     deadline = time.monotonic() + timeout
#     935 while True:
# --> 936     ready = selector.select(timeout)
#     937     if ready:
#     938         return [key.fileobj for (key, events) in ready]
#
# File /usr/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
# v3
plt.plot(reward_history)
plt.xlabel('episode')
plt.ylabel('episode total reward')
# Out:
# Text(0, 0.5, 'episode total reward')

# %%
# v1
plt.plot(reward_history)
plt.xlabel('episode')
plt.ylabel('episode total reward')
# Out:
# Text(0, 0.5, 'episode total reward')

# %%
# v2
plt.plot(reward_history)
plt.xlabel('episode')
plt.ylabel('episode total reward')
# Out:
# Text(0, 0.5, 'episode total reward')

# %%
env.close()
