# %%
from mlagents_envs.envs.unity_gym_env import UnityToGymWrapper
from mlagents_envs.environment import ActionTuple, UnityEnvironment
from mlagents_envs.side_channel.engine_configuration_channel import \
    EngineConfigurationChannel
from mlagents_envs.exception import (
    UnityEnvironmentException,
    UnityCommunicationException,
    UnityCommunicatorStoppedException,
)
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
import collections
from typing import Union
import math
import random
from copy import deepcopy
from typing import Optional

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from fastprogress import progress_bar as pb
import matplotlib.pyplot as plt

# %%
class NStepPriorityReplayBuffer:

    def __init__(
        self,
        max_size: int,
        prob_alpha: float = 0.6,
        beta_start: float = 0.4,
        beta_frames: float = 100000,
        n_step: int = 4,
        gamma: float = 0.99,
    ):
        self._prob_alpha = prob_alpha
        self._max_size = max_size
        self._pos = 0
        self._buf = []
        self._priorities = np.zeros((max_size,), dtype=np.float32)
        self._beta_start = beta_start
        self._beta = beta_start
        self._beta_frames = beta_frames
        self._n_step = n_step
        self._gamma = gamma
        self._total_discounted_rewards = np.array([np.nan]*max_size)
        self._last_states = [np.nan]*max_size

    def update_bata(self, idx) -> None:
        beta = self._beta_start + idx * (1.0 - self._beta_start) / self._beta_frames
        self._beta = min(1.0, beta)
        return self._beta

    def __len__(self):
        return len(self._buf)

    def append(
        self,
        state: np.ndarray,
        action: int,
        reward: Union[int, float],
        done: bool,
        next_state: np.ndarray,
    ) -> None:
        max_prio = self._priorities.max() if self._buf else 1.0
        if len(self._buf) < self._max_size:
            self._buf.append(
                (state, action, reward, done, next_state)
            )
        else:
            self._buf[self._pos] = (state, action, reward, done, next_state)
        self._priorities[self._pos] = max_prio

        if len(self._buf) >= self._n_step:
            dis_r = 0.0
            last_state = self._buf[self._pos][0]
            for i in range(self._n_step):
                state, _, r, done, _ = self._buf[self._pos - i]
                dis_r = r + self._gamma * dis_r
                if done:
                    last_state = state
                    dis_r = r  # ※
                self._total_discounted_rewards[self._pos - i] = dis_r
                self._last_states[self._pos - i] = last_state
            
            for i in range(self._n_step-1):
                done = self._buf[self._pos - i][3]
                if done:
                    break
                self._total_discounted_rewards[self._pos - i] = np.nan
                self._last_states[self._pos - i] = np.nan

        self._pos = (self._pos + 1) % self._max_size

    def sample(self, size: int):
        sample_target_indices = np.where(~np.isnan(self._total_discounted_rewards[:len(self._buf)]))[0]
        # prios = self._priorities[sample_target_indices]  #self._priorities if len(self._buf) == self._max_size else self._priorities[:self._pos]
        prios = self._priorities
        probs = prios * self._prob_alpha
        # probs /= np.nan_to_num(probs, 0.0).sum()
        probs /= probs[sample_target_indices].sum()
        sampled_indices = np.random.choice(
            sample_target_indices,
            # np.where(~np.isnan(self._total_discounted_rewards[:len(self._buf)]))[0],
            size, p=probs[sample_target_indices]
        )
        states, actions, rewards, dones, next_states = zip(*[self._buf[idx] for idx in sampled_indices])
        states = np.array(states)
        actions = np.array(actions)
        rewards = np.array(rewards)
        dones = np.array(dones)
        next_states = np.array(next_states)
        total_discounted_rewards = self._total_discounted_rewards[sampled_indices]
        last_states = np.stack([self._last_states[idx] for idx in sampled_indices])
        total = len(self._buf)
        weights = np.array((total * probs[sampled_indices]) ** (-self._beta), dtype=np.float32)
        # weights = np.array((total * probs) ** (-self._beta), dtype=np.float32)
        weights /= weights.max()
        return states, actions, rewards, dones, total_discounted_rewards, last_states, sampled_indices, weights

    def update_priorities(self, sample_indices: np.ndarray, sample_priorities: np.ndarray) -> None:
        self._priorities[sample_indices] = sample_priorities

    @property
    def gamma(self) -> float:
        return self._gamma

    @property
    def n_step(self) -> float:
        return self._n_step

# %%
class NoisyLinear(nn.Linear):

    def __init__(self, in_features, out_features, sigma_init=0.017, bias=True):
        super(NoisyLinear, self).__init__(in_features, out_features, bias=bias)
        w = torch.full((out_features, in_features), sigma_init)
        self._sigma_weight = nn.Parameter(w)
        z = torch.zeros(out_features, in_features)
        self.register_buffer("epsilon_weight", z)
        if bias:
            w = torch.full((out_features,), sigma_init)
            self._sigma_bias = nn.Parameter(w)
            z = torch.zeros(out_features)
            self.register_buffer("epsilon_bias", z)
        self.reset_parameters()

    def reset_parameters(self):
        std = math.sqrt(3 / self.in_features)
        self.weight.data.uniform_(-std, std)
        self.bias.data.uniform_(-std, std)

    def forward(self, input):
        self.epsilon_weight.normal_()
        bias = self.bias
        if bias is not None:
            self.epsilon_bias.normal_()
            bias = bias + self._sigma_bias * \
                   self.epsilon_bias.data
        v = self._sigma_weight * self.epsilon_weight.data + \
            self.weight
        return F.linear(input, v, bias)

# %%
class DDPGCritic(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGCritic, self).__init__()

        self.obs_net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
        )

        self.out_net = nn.Sequential(
            nn.Linear(400 + act_size, 300),
            nn.ReLU(),
            nn.Linear(300, 1)
        )

    def forward(self, x, a):
        obs = self.obs_net(x)
        return self.out_net(torch.cat([obs, a], dim=1))

# %%
class DDPGActor(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGActor, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, act_size),
            nn.Tanh()
        )

    def forward(self, x):
        return self.net(x)

# %%
class Agent:

    def __init__(
        self,
        env,
        exp_buffer: NStepPriorityReplayBuffer,
        act_net: nn.Module,
        crt_net: nn.Module,
        epsilon_start: float = 1.0,
        epsilon_final: float = 0.01,
        epsilon_decay_last_step: int = 200000,
        tgt_sync_steps: int = 10000,
        learning_rate: float = 1e-4,
        adam_eps: float = None,
        device: str = 'cuda' if torch.cuda.is_available() else 'cpu',
        bonus_reward_factor: float = 0.0
    ):
        self._env = env
        self._exp_buffer = exp_buffer
        self._act_net = act_net
        self._crt_net = crt_net
        self._tgt_act_net = deepcopy(act_net)
        self._tgt_crt_net = deepcopy(crt_net)
        for p in self._tgt_act_net.parameters():
            p.requires_grad = False
        for p in self._tgt_crt_net.parameters():
            p.requires_grad = False
        self._epsilon_start = epsilon_start
        self._epsilon_final = epsilon_final
        self._epsilon_decay_last_step = epsilon_decay_last_step
        self._epsilon = epsilon_start
        self._device = device
        self._total_step = 0
        self._total_trained_samples = 0
        self._tgt_sync_steps = tgt_sync_steps
        adam_kwargs = {}
        if adam_eps is not None:
            adam_kwargs['eps'] = adam_eps
        self._crt_optimizer = torch.optim.Adam(self._crt_net.parameters(), lr=learning_rate, **adam_kwargs)
        self._act_optimizer = torch.optim.Adam(self._act_net.parameters(), lr=learning_rate, **adam_kwargs)
        self._n_episodes = 0
        self._episode_steps = 0
        self._bonus_reward_factor = bonus_reward_factor
        self._reset_episode()

    def _reset_episode(self):
        self._state = self._env.reset()
        self._total_reward = 0.0
        self._episode_steps = 0
        self._n_episodes += 1

    @torch.no_grad()
    def play_step(self, epsilon: Optional[float] = None, sync_target: bool = True):
        if epsilon is None:
            epsilon = self._epsilon
        done_reward = None

        if np.random.random() < epsilon:
            action = self._env.action_space.sample()
        else:
            state_a = np.array([self._state], copy=False)
            state_v = torch.tensor(state_a).float().to(self._device)
            mu_v = self._act_net(state_v)
            action = mu_v.squeeze(dim=0).data.cpu().numpy()
            action = np.clip(action, -1, 1)

        next_state, reward, is_done, _ = self._env.step(action)
        self._total_reward += reward

        bonus_reward = self._bonus_reward_factor * self._episode_steps

#         self._exp_buffer.append(
#             self._state, action, reward + bonus_reward, is_done, next_state
#         )
        self._exp_buffer.append(
            self._state, action, self._total_reward + bonus_reward, is_done, next_state
        )
        self._state = next_state
        if is_done:
            done_reward = self._total_reward
            self._reset_episode()

        self._total_step += 1
        self._episode_steps += 1
        self._update_epsilon(self._total_step)
        self._exp_buffer.update_bata(self._total_step)

        # if self._total_step % self._tgt_sync_steps == 0 and sync_target:
        #     self._alpha_sync(self._act_net, self._tgt_act_net, alpha=1 - 1e-3)
        #     self._alpha_sync(self._crt_net, self._tgt_crt_net, alpha=1 - 1e-3)
        #     print(f'synced target net')

        return done_reward

    def train(self, n_iter: int = 1, batch_size: int = 32) -> None:
        n_step_gamma = self._exp_buffer.gamma ** self._exp_buffer.n_step
        for i in range(n_iter):
            states, actions, rewards, dones, total_discounted_rewards, \
                last_states, sampled_indices, weights = self._exp_buffer.sample(batch_size)
            states_v = torch.tensor(states).float().to(self._device)
            actions_v = torch.tensor(actions).to(self._device)
            discounted_rewards_v = torch.tensor(total_discounted_rewards).to(self._device)
            done_mask = torch.BoolTensor(dones).to(self._device)
            weights_v = torch.tensor(weights).to(self._device)
            last_states_v = torch.tensor(last_states).float().to(self._device)

            # train critic
            self._crt_optimizer.zero_grad()
            q_v = self._crt_net(states_v, actions_v)
            last_act_v = self._tgt_act_net(last_states_v)
            q_last_v = self._tgt_crt_net(last_states_v, last_act_v)
            q_last_v[done_mask] = 0.0
            q_ref_v = discounted_rewards_v.unsqueeze(dim=-1) + \
                        q_last_v * n_step_gamma
            # q_ref_v = discounted_rewards_v + q_last_v * n_step_gamma
            critic_loss_v = F.mse_loss(q_v.float(), q_ref_v.float().detach())
            critic_loss_v.backward()
            self._crt_optimizer.step()

            # train actor
            self._act_optimizer.zero_grad()
            cur_actions_v = self._act_net(states_v)
            actor_loss_v = -self._crt_net(states_v, cur_actions_v)
            actor_loss_v = actor_loss_v.mean()
            actor_loss_v.backward()
            self._act_optimizer.step()

            self._alpha_sync(self._act_net, self._tgt_act_net, alpha=1 - 1e-3)
            self._alpha_sync(self._crt_net, self._tgt_crt_net, alpha=1 - 1e-3)

            # self._exp_buffer.update_priorities(sampled_indices, prios)
            self._total_trained_samples += batch_size

    def initial_exploration(self, n_steps: int = 10000, epsilon: float = 1.0) -> None:
        eps_bak = self._epsilon
        n_episodes_bak = self._n_episodes
        try:
            for i in pb(range(n_steps)):
                self._epsilon = epsilon
                self.play_step(sync_target=False)
        finally:
            self._total_step = 0
            self._epsilon = eps_bak
        self._n_episodes = n_episodes_bak

    def _update_epsilon(self, step_index: int) -> None:
        self._epsilon = max(
            self._epsilon_final,
            self._epsilon_start - step_index / self._epsilon_decay_last_step
        )

    def _sync(self, net, tgt_net):
        tgt_net.load_state_dict(net.state_dict())

    def _alpha_sync(self, net, tgt_net, alpha):
        assert isinstance(alpha, float)
        assert 0.0 < alpha <= 1.0
        state = net.state_dict()
        tgt_state = tgt_net.state_dict()
        for k, v in state.items():
            tgt_state[k] = tgt_state[k] * alpha + (1 - alpha) * v
        tgt_net.load_state_dict(tgt_state)

# %%
class UnityToGymNumpyWrapper(UnityToGymWrapper):
    def __init__(self, *args, **kwargs):
        super(UnityToGymNumpyWrapper, self).__init__(*args, **kwargs)

    def reset(self, *args, **kwargs):
        state = super().reset(*args, **kwargs)
        return np.array(state[0])

    def step(self, *args, **kwargs):
        next_state, reward, is_done, info = super().step(*args, **kwargs)
        return np.array(next_state[0]), reward, is_done, info

# %%
try:
    unity_env.close()
except Exception:
    pass

unity_env = UnityEnvironment(file_name=None)

# %%
unity_env.reset()

# %%
# env = UnityToGymWrapper(unity_env, allow_multiple_obs=True)
env = UnityToGymNumpyWrapper(unity_env, allow_multiple_obs=True)

# %%
# Unity環境のリセット
unity_env.reset()

# BehaviorNameのリストの取得
behavior_names = list(unity_env.behavior_specs.keys())
print('behavior_names:', behavior_names)

# BehaviorSpecの取得
behavior_spec = unity_env.behavior_specs[behavior_names[0]]

# BehaviorSpecの情報の確認
print('\n== BehaviorSpecの情報の確認 ==')
print('observation_specs:', behavior_spec.observation_specs)
print('action_spec:', behavior_spec.action_spec)
# Out:
# behavior_names: ['3DBall?team=0']
#
# == BehaviorSpecの情報の確認 ==
# observation_specs: [ObservationSpec(shape=(8,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='VectorSensor_size8')]
# action_spec: Continuous: 2, Discrete: ()

# %%
behavior_spec
# Out:
# BehaviorSpec(observation_specs=[ObservationSpec(shape=(8,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='VectorSensor_size8')], action_spec=ActionSpec(continuous_size=2, discrete_branches=()))

# %%
# 現在のステップの情報の取得
decision_steps, terminal_steps = unity_env.get_steps(behavior_names[0])

# DecisionStepsの情報の確認
print('\n== DecisionStepsの情報の確認 ==')
print('obj:', decision_steps.obs)
print('reward:', decision_steps.reward)
print('agent_id:', decision_steps.agent_id)
print('action_mask:', decision_steps.action_mask)

# TerminalStepsの情報の確認
print('\n== TerminalStepsの情報の確認 ==')
print('obs:', terminal_steps.obs)
print('reward:', terminal_steps.reward)
print('agent_id:', terminal_steps.agent_id)
print('interrupted:', terminal_steps.interrupted)
# Out:
# == DecisionStepsの情報の確認 ==
# obj: [array([[ 0.06363224,  0.03799658, -1.1360741 ,  3.996076  , -0.4150591 ,
#          0.        , -0.1962    ,  0.        ]], dtype=float32)]
# reward: [0.1]
# agent_id: [0]
# action_mask: None
#
# == TerminalStepsの情報の確認 ==
# obs: [array([], shape=(0, 8), dtype=float32)]
# reward: []
# agent_id: []
# interrupted: []

# %%
len(decision_steps.obs)
# Out:
# 1

# %%
decision_steps.obs[0].shape
# Out:
# (1, 8)

# %%
N_AGENTS, OBS_DIM = decision_steps.obs[0].shape

# %%
N_ACTIONS = behavior_spec.action_spec.continuous_size

# %%
N_ACTIONS
# Out:
# 2

# %%
env.action_space
# Out:
# Box(-1.0, 1.0, (2,), float32)

# %%
env.action_space.sample()
# Out:
# array([ 0.52669793, -0.29101717], dtype=float32)

# %%
env.observation_space
# Out:
# Tuple(Box(-inf, inf, (8,), float32))

# %%
state = env.reset()

# %%
state
# Out:
# array([-0.04687161, -0.03916143, -0.61104035,  3.996076  ,  0.56867313,
#         0.        , -0.1962    ,  0.        ], dtype=float32)

# %%
state.shape
# Out:
# (8,)

# %%
torch.tensor(state).unsqueeze(0).shape
# Out:
# torch.Size([1, 8])

# %%
next_state, reward, is_done, _ = env.step(env.action_space.sample())

# %%
next_state
# Out:
# array([-0.0582418 , -0.10417491, -0.61104035,  3.917596  ,  0.56867313,
#         0.        , -1.1772    ,  0.        ], dtype=float32)

# %%
reward
# Out:
# 0.1

# %%
is_done
# Out:
# False

# %%
SEED = 77

# %%
random.seed(SEED)
torch.manual_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
act_net = DDPGActor(
    OBS_DIM,
    N_ACTIONS,
).to(device)
crt_net = DDPGCritic(
    OBS_DIM,
    N_ACTIONS,
).to(device)

# %%
act = act_net(torch.tensor(state).unsqueeze(0).to(device))

# %%
act.shape
# Out:
# torch.Size([1, 2])

# %%
v = crt_net(torch.tensor(state).unsqueeze(0).to(device), act)

# %%
v.shape
# Out:
# torch.Size([1, 1])

# %%
exp_buffer = NStepPriorityReplayBuffer(
    max_size=30000,
    prob_alpha=0.6,
    beta_start=0.4,
    beta_frames=30000, #100000,
    n_step=2,
    gamma=0.99,
)
agent = Agent(
    env=env,
    exp_buffer=exp_buffer,
    crt_net=crt_net,
    act_net=act_net,
    epsilon_start=0.6,
    epsilon_final=0.002,
    epsilon_decay_last_step=30000, #200000,
    tgt_sync_steps=1000,
    learning_rate=1e-4,
    device=device
)

# %%
agent.initial_exploration(n_steps=10000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 16:29&lt;00:00]
#     </div>

# %%
states, actions, rewards, dones, next_states = zip(*agent._exp_buffer._buf)

# %%
plt.figure(figsize=(16, 6))
plt.plot(rewards[:200])
plt.plot(agent._exp_buffer._total_discounted_rewards[:200])

# %%
episode = 0
reward_history = []
spisode_steps_history = []
spisode_start_steps = 0

env.reset()

while True:

    for stp in range(20):
        done_reward = agent.play_step()
        if done_reward is not None:
            print(f'episode : {episode}, done reward : {done_reward}, total_step : {agent._total_step}, cur_epsilon : {agent._epsilon}')
            episode += 1
            reward_history.append(done_reward)
            spisode_steps_history.append(agent._total_step-spisode_start_steps)
            spisode_start_steps = agent._total_step

    agent.train(n_iter=20, batch_size=32)
# Out:
# episode : 0, done reward : 3.4000000655651093, total_step : 38, cur_epsilon : 0.5987333333333333
# episode : 1, done reward : 0.6000000238418579, total_step : 55, cur_epsilon : 0.5981666666666666
# episode : 2, done reward : 0.6000000238418579, total_step : 72, cur_epsilon : 0.5976
# episode : 3, done reward : 0.40000002086162567, total_step : 87, cur_epsilon : 0.5971
# episode : 4, done reward : 0.40000002086162567, total_step : 102, cur_epsilon : 0.5966
# episode : 5, done reward : 0.8000000268220901, total_step : 121, cur_epsilon : 0.5959666666666666
# episode : 6, done reward : 1.600000038743019, total_step : 148, cur_epsilon : 0.5950666666666666
# episode : 7, done reward : 0.5000000223517418, total_step : 164, cur_epsilon : 0.5945333333333334
# episode : 8, done reward : 0.5000000223517418, total_step : 180, cur_epsilon : 0.594
# episode : 9, done reward : 0.40000002086162567, total_step : 195, cur_epsilon : 0.5935
# episode : 10, done reward : 0.20000001788139343, total_step : 208, cur_epsilon : 0.5930666666666666
# episode : 11, done reward : 0.700000025331974, total_step : 226, cur_epsilon : 0.5924666666666667
# episode : 12, done reward : 0.30000001937150955, total_step : 240, cur_epsilon : 0.592
# episode : 13, done reward : 0.700000025331974, total_step : 258, cur_epsilon : 0.5913999999999999
# episode : 14, done reward : 0.6000000238418579, total_step : 275, cur_epsilon : 0.5908333333333333
# episode : 15, done reward : 0.10000001639127731, total_step : 287, cur_epsilon : 0.5904333333333334
# episode : 16, done reward : 0.30000001937150955, total_step : 301, cur_epsilon : 0.5899666666666666
# episode : 17, done reward : 0.10000001639127731, total_step : 313, cur_epsilon : 0.5895666666666667
# episode : 18, done reward : 0.10000001639127731, total_step : 325, cur_epsilon : 0.5891666666666666
# episode : 19, done reward : 1.0000000298023224, total_step : 346, cur_epsilon : 0.5884666666666667
# episode : 20, done reward : 0.30000001937150955, total_step : 360, cur_epsilon : 0.588
# episode : 21, done reward : 0.8000000268220901, total_step : 379, cur_epsilon : 0.5873666666666666
# episode : 22, done reward : 0.5000000223517418, total_step : 395, cur_epsilon : 0.5868333333333333
# episode : 23, done reward : 0.40000002086162567, total_step : 410, cur_epsilon : 0.5863333333333333
# episode : 24, done reward : 0.10000001639127731, total_step : 422, cur_epsilon : 0.5859333333333333
# episode : 25, done reward : 0.20000001788139343, total_step : 435, cur_epsilon : 0.5855
# episode : 26, done reward : 0.40000002086162567, total_step : 450, cur_epsilon : 0.585
# episode : 27, done reward : 0.10000001639127731, total_step : 462, cur_epsilon : 0.5846
# episode : 28, done reward : -0.09999998658895493, total_step : 472, cur_epsilon : 0.5842666666666666
# episode : 29, done reward : 0.40000002086162567, total_step : 487, cur_epsilon : 0.5837666666666667
# episode : 30, done reward : 0.6000000238418579, total_step : 504, cur_epsilon : 0.5831999999999999
# episode : 31, done reward : 0.10000001639127731, total_step : 516, cur_epsilon : 0.5828
# episode : 32, done reward : 0.700000025331974, total_step : 534, cur_epsilon : 0.5821999999999999
# episode : 33, done reward : 0.5000000223517418, total_step : 550, cur_epsilon : 0.5816666666666667
# episode : 34, done reward : 0.40000002086162567, total_step : 565, cur_epsilon : 0.5811666666666666
# episode : 35, done reward : 0.40000002086162567, total_step : 580, cur_epsilon : 0.5806666666666667
# episode : 36, done reward : 0.40000002086162567, total_step : 595, cur_epsilon : 0.5801666666666666
# episode : 37, done reward : 0.20000001788139343, total_step : 608, cur_epsilon : 0.5797333333333333
# episode : 38, done reward : 0.9000000283122063, total_step : 628, cur_epsilon : 0.5790666666666666
# episode : 39, done reward : 0.20000001788139343, total_step : 641, cur_epsilon : 0.5786333333333333
# episode : 40, done reward : 0.40000002086162567, total_step : 656, cur_epsilon : 0.5781333333333333
# episode : 41, done reward : 0.6000000238418579, total_step : 673, cur_epsilon : 0.5775666666666667
# episode : 42, done reward : 0.5000000223517418, total_step : 689, cur_epsilon : 0.5770333333333333
# episode : 43, done reward : 0.9000000283122063, total_step : 709, cur_epsilon : 0.5763666666666667
# episode : 44, done reward : 0.30000001937150955, total_step : 723, cur_epsilon : 0.5759
# episode : 45, done reward : 1.2000000327825546, total_step : 746, cur_epsilon : 0.5751333333333333
# episode : 46, done reward : 0.5000000223517418, total_step : 762, cur_epsilon : 0.5746
# episode : 47, done reward : 0.30000001937150955, total_step : 776, cur_epsilon : 0.5741333333333333
# episode : 48, done reward : 0.8000000268220901, total_step : 795, cur_epsilon : 0.5735
# episode : 49, done reward : 0.30000001937150955, total_step : 809, cur_epsilon : 0.5730333333333333
# episode : 50, done reward : 0.30000001937150955, total_step : 823, cur_epsilon : 0.5725666666666667
# episode : 51, done reward : 0.20000001788139343, total_step : 836, cur_epsilon : 0.5721333333333333
# episode : 52, done reward : 0.30000001937150955, total_step : 850, cur_epsilon : 0.5716666666666667
# episode : 53, done reward : 0.700000025331974, total_step : 868, cur_epsilon : 0.5710666666666666
# episode : 54, done reward : 0.8000000268220901, total_step : 887, cur_epsilon : 0.5704333333333333
# episode : 55, done reward : 0.30000001937150955, total_step : 901, cur_epsilon : 0.5699666666666666
# episode : 56, done reward : 0.30000001937150955, total_step : 915, cur_epsilon : 0.5695
# episode : 57, done reward : 1.4901161193847656e-08, total_step : 926, cur_epsilon : 0.5691333333333333
# episode : 58, done reward : 1.0000000298023224, total_step : 947, cur_epsilon : 0.5684333333333333
# episode : 59, done reward : 0.8000000268220901, total_step : 966, cur_epsilon : 0.5678
# episode : 60, done reward : 0.30000001937150955, total_step : 980, cur_epsilon : 0.5673333333333334
# episode : 61, done reward : 0.20000001788139343, total_step : 993, cur_epsilon : 0.5669
# episode : 62, done reward : 0.40000002086162567, total_step : 1008, cur_epsilon : 0.5664
# episode : 63, done reward : 0.5000000223517418, total_step : 1024, cur_epsilon : 0.5658666666666666
# episode : 64, done reward : 0.5000000223517418, total_step : 1040, cur_epsilon : 0.5653333333333334
# episode : 65, done reward : 1.4901161193847656e-08, total_step : 1051, cur_epsilon : 0.5649666666666666
# episode : 66, done reward : 0.30000001937150955, total_step : 1065, cur_epsilon : 0.5645
# episode : 67, done reward : 0.5000000223517418, total_step : 1081, cur_epsilon : 0.5639666666666666
# episode : 68, done reward : 0.10000001639127731, total_step : 1093, cur_epsilon : 0.5635666666666667
# episode : 69, done reward : 0.10000001639127731, total_step : 1105, cur_epsilon : 0.5631666666666666
# episode : 70, done reward : 0.20000001788139343, total_step : 1118, cur_epsilon : 0.5627333333333333
# episode : 71, done reward : 0.40000002086162567, total_step : 1133, cur_epsilon : 0.5622333333333334
# episode : 72, done reward : 0.20000001788139343, total_step : 1146, cur_epsilon : 0.5618
# episode : 73, done reward : 0.6000000238418579, total_step : 1163, cur_epsilon : 0.5612333333333334
# episode : 74, done reward : 0.700000025331974, total_step : 1181, cur_epsilon : 0.5606333333333333
# episode : 75, done reward : 0.10000001639127731, total_step : 1193, cur_epsilon : 0.5602333333333334
# episode : 76, done reward : 0.6000000238418579, total_step : 1210, cur_epsilon : 0.5596666666666666
# episode : 77, done reward : 0.5000000223517418, total_step : 1226, cur_epsilon : 0.5591333333333333
# episode : 78, done reward : 0.10000001639127731, total_step : 1238, cur_epsilon : 0.5587333333333333
# episode : 79, done reward : 0.5000000223517418, total_step : 1254, cur_epsilon : 0.5582
# episode : 80, done reward : 0.40000002086162567, total_step : 1269, cur_epsilon : 0.5577
# episode : 81, done reward : 0.20000001788139343, total_step : 1282, cur_epsilon : 0.5572666666666667
# episode : 82, done reward : 0.5000000223517418, total_step : 1298, cur_epsilon : 0.5567333333333333
# episode : 83, done reward : 0.5000000223517418, total_step : 1314, cur_epsilon : 0.5562
# episode : 84, done reward : 0.6000000238418579, total_step : 1331, cur_epsilon : 0.5556333333333333
# episode : 85, done reward : 0.5000000223517418, total_step : 1347, cur_epsilon : 0.5550999999999999
# episode : 86, done reward : 0.6000000238418579, total_step : 1364, cur_epsilon : 0.5545333333333333
# episode : 87, done reward : 0.8000000268220901, total_step : 1383, cur_epsilon : 0.5539
# episode : 88, done reward : 0.20000001788139343, total_step : 1396, cur_epsilon : 0.5534666666666667
# episode : 89, done reward : 1.4000000357627869, total_step : 1421, cur_epsilon : 0.5526333333333333
# episode : 90, done reward : 0.20000001788139343, total_step : 1434, cur_epsilon : 0.5522
# episode : 91, done reward : 0.20000001788139343, total_step : 1447, cur_epsilon : 0.5517666666666666
# episode : 92, done reward : 0.700000025331974, total_step : 1465, cur_epsilon : 0.5511666666666667
# episode : 93, done reward : 0.30000001937150955, total_step : 1479, cur_epsilon : 0.5507
# episode : 94, done reward : 0.30000001937150955, total_step : 1493, cur_epsilon : 0.5502333333333334
# episode : 95, done reward : 0.9000000283122063, total_step : 1513, cur_epsilon : 0.5495666666666666
# episode : 96, done reward : 0.40000002086162567, total_step : 1528, cur_epsilon : 0.5490666666666666
# episode : 97, done reward : 0.40000002086162567, total_step : 1543, cur_epsilon : 0.5485666666666666
# episode : 98, done reward : 0.6000000238418579, total_step : 1560, cur_epsilon : 0.5479999999999999
# episode : 99, done reward : 0.6000000238418579, total_step : 1577, cur_epsilon : 0.5474333333333333
# episode : 100, done reward : 1.1000000312924385, total_step : 1599, cur_epsilon : 0.5467
# episode : 101, done reward : 0.20000001788139343, total_step : 1612, cur_epsilon : 0.5462666666666667
# episode : 102, done reward : 0.5000000223517418, total_step : 1628, cur_epsilon : 0.5457333333333333
# episode : 103, done reward : 0.20000001788139343, total_step : 1641, cur_epsilon : 0.5453
# episode : 104, done reward : 0.700000025331974, total_step : 1659, cur_epsilon : 0.5447
# episode : 105, done reward : 0.5000000223517418, total_step : 1675, cur_epsilon : 0.5441666666666667
# episode : 106, done reward : 1.4901161193847656e-08, total_step : 1686, cur_epsilon : 0.5438
# episode : 107, done reward : 0.30000001937150955, total_step : 1700, cur_epsilon : 0.5433333333333333
# episode : 108, done reward : 0.30000001937150955, total_step : 1714, cur_epsilon : 0.5428666666666666
# episode : 109, done reward : 0.30000001937150955, total_step : 1728, cur_epsilon : 0.5424
# episode : 110, done reward : 0.20000001788139343, total_step : 1741, cur_epsilon : 0.5419666666666666
# episode : 111, done reward : 0.20000001788139343, total_step : 1754, cur_epsilon : 0.5415333333333333
# episode : 112, done reward : 0.8000000268220901, total_step : 1773, cur_epsilon : 0.5408999999999999
# episode : 113, done reward : 0.5000000223517418, total_step : 1789, cur_epsilon : 0.5403666666666667
# episode : 114, done reward : 0.40000002086162567, total_step : 1804, cur_epsilon : 0.5398666666666666
# episode : 115, done reward : 0.700000025331974, total_step : 1822, cur_epsilon : 0.5392666666666667
# episode : 116, done reward : -0.09999998658895493, total_step : 1832, cur_epsilon : 0.5389333333333333
# episode : 117, done reward : 0.6000000238418579, total_step : 1849, cur_epsilon : 0.5383666666666667
# episode : 118, done reward : 0.5000000223517418, total_step : 1865, cur_epsilon : 0.5378333333333333
# episode : 119, done reward : 0.700000025331974, total_step : 1883, cur_epsilon : 0.5372333333333333
# episode : 120, done reward : 0.8000000268220901, total_step : 1902, cur_epsilon : 0.5366
# episode : 121, done reward : 0.6000000238418579, total_step : 1919, cur_epsilon : 0.5360333333333334
# episode : 122, done reward : 0.8000000268220901, total_step : 1938, cur_epsilon : 0.5354
# episode : 123, done reward : 0.20000001788139343, total_step : 1951, cur_epsilon : 0.5349666666666666
# episode : 124, done reward : 1.4901161193847656e-08, total_step : 1962, cur_epsilon : 0.5346
# episode : 125, done reward : 0.700000025331974, total_step : 1980, cur_epsilon : 0.534
# episode : 126, done reward : 0.6000000238418579, total_step : 1997, cur_epsilon : 0.5334333333333333
# episode : 127, done reward : 0.30000001937150955, total_step : 2011, cur_epsilon : 0.5329666666666666
# episode : 128, done reward : 0.8000000268220901, total_step : 2030, cur_epsilon : 0.5323333333333333
# episode : 129, done reward : 0.20000001788139343, total_step : 2043, cur_epsilon : 0.5319
# episode : 130, done reward : 0.700000025331974, total_step : 2061, cur_epsilon : 0.5313
# episode : 131, done reward : 0.700000025331974, total_step : 2079, cur_epsilon : 0.5307
# episode : 132, done reward : 0.20000001788139343, total_step : 2092, cur_epsilon : 0.5302666666666667
# episode : 133, done reward : 0.5000000223517418, total_step : 2108, cur_epsilon : 0.5297333333333333
# episode : 134, done reward : 0.40000002086162567, total_step : 2123, cur_epsilon : 0.5292333333333333
# episode : 135, done reward : 0.30000001937150955, total_step : 2137, cur_epsilon : 0.5287666666666666
# episode : 136, done reward : 0.5000000223517418, total_step : 2153, cur_epsilon : 0.5282333333333333
# episode : 137, done reward : 0.5000000223517418, total_step : 2169, cur_epsilon : 0.5277
# episode : 138, done reward : 0.40000002086162567, total_step : 2184, cur_epsilon : 0.5272
# episode : 139, done reward : 1.1000000312924385, total_step : 2206, cur_epsilon : 0.5264666666666666
# episode : 140, done reward : 0.9000000283122063, total_step : 2226, cur_epsilon : 0.5257999999999999
# episode : 141, done reward : 0.700000025331974, total_step : 2244, cur_epsilon : 0.5252
# episode : 142, done reward : 0.20000001788139343, total_step : 2257, cur_epsilon : 0.5247666666666666
# episode : 143, done reward : 0.30000001937150955, total_step : 2271, cur_epsilon : 0.5243
# episode : 144, done reward : 0.30000001937150955, total_step : 2285, cur_epsilon : 0.5238333333333334
# episode : 145, done reward : 0.5000000223517418, total_step : 2301, cur_epsilon : 0.5233
# episode : 146, done reward : 0.40000002086162567, total_step : 2316, cur_epsilon : 0.5227999999999999
# episode : 147, done reward : 0.40000002086162567, total_step : 2331, cur_epsilon : 0.5223
# episode : 148, done reward : 0.30000001937150955, total_step : 2345, cur_epsilon : 0.5218333333333334
# episode : 149, done reward : 0.20000001788139343, total_step : 2358, cur_epsilon : 0.5214
# episode : 150, done reward : 0.700000025331974, total_step : 2376, cur_epsilon : 0.5207999999999999
# episode : 151, done reward : 0.10000001639127731, total_step : 2388, cur_epsilon : 0.5204
# episode : 152, done reward : 0.8000000268220901, total_step : 2407, cur_epsilon : 0.5197666666666666
# episode : 153, done reward : -0.09999998658895493, total_step : 2417, cur_epsilon : 0.5194333333333333
# episode : 154, done reward : 0.30000001937150955, total_step : 2431, cur_epsilon : 0.5189666666666667
# episode : 155, done reward : 0.20000001788139343, total_step : 2444, cur_epsilon : 0.5185333333333333
# episode : 156, done reward : 0.5000000223517418, total_step : 2460, cur_epsilon : 0.518
# episode : 157, done reward : 0.8000000268220901, total_step : 2479, cur_epsilon : 0.5173666666666666
# episode : 158, done reward : 0.40000002086162567, total_step : 2494, cur_epsilon : 0.5168666666666666
# episode : 159, done reward : 0.40000002086162567, total_step : 2509, cur_epsilon : 0.5163666666666666
# episode : 160, done reward : 1.4901161193847656e-08, total_step : 2520, cur_epsilon : 0.516
# episode : 161, done reward : 0.9000000283122063, total_step : 2540, cur_epsilon : 0.5153333333333333
# episode : 162, done reward : 1.1000000312924385, total_step : 2562, cur_epsilon : 0.5146
# episode : 163, done reward : 0.30000001937150955, total_step : 2576, cur_epsilon : 0.5141333333333333
# episode : 164, done reward : 0.30000001937150955, total_step : 2590, cur_epsilon : 0.5136666666666666
# episode : 165, done reward : 0.10000001639127731, total_step : 2602, cur_epsilon : 0.5132666666666666
# episode : 166, done reward : 0.10000001639127731, total_step : 2614, cur_epsilon : 0.5128666666666667
# episode : 167, done reward : 0.9000000283122063, total_step : 2634, cur_epsilon : 0.5122
# episode : 168, done reward : 0.8000000268220901, total_step : 2653, cur_epsilon : 0.5115666666666666
# episode : 169, done reward : 0.9000000283122063, total_step : 2673, cur_epsilon : 0.5109
# episode : 170, done reward : 0.30000001937150955, total_step : 2687, cur_epsilon : 0.5104333333333333
# episode : 171, done reward : 0.9000000283122063, total_step : 2707, cur_epsilon : 0.5097666666666667
# episode : 172, done reward : 1.1000000312924385, total_step : 2729, cur_epsilon : 0.5090333333333333
# episode : 173, done reward : 0.20000001788139343, total_step : 2742, cur_epsilon : 0.5085999999999999
# episode : 174, done reward : 0.5000000223517418, total_step : 2758, cur_epsilon : 0.5080666666666667
# episode : 175, done reward : 1.4901161193847656e-08, total_step : 2769, cur_epsilon : 0.5077
# episode : 176, done reward : 1.4901161193847656e-08, total_step : 2780, cur_epsilon : 0.5073333333333333
# episode : 177, done reward : 0.8000000268220901, total_step : 2799, cur_epsilon : 0.5066999999999999
# episode : 178, done reward : 0.40000002086162567, total_step : 2814, cur_epsilon : 0.5062
# episode : 179, done reward : 0.5000000223517418, total_step : 2830, cur_epsilon : 0.5056666666666666
# episode : 180, done reward : 0.700000025331974, total_step : 2848, cur_epsilon : 0.5050666666666667
# episode : 181, done reward : 0.5000000223517418, total_step : 2864, cur_epsilon : 0.5045333333333333
# episode : 182, done reward : 1.2000000327825546, total_step : 2887, cur_epsilon : 0.5037666666666667
# episode : 183, done reward : 1.3000000342726707, total_step : 2911, cur_epsilon : 0.5029666666666667
# episode : 184, done reward : 0.40000002086162567, total_step : 2926, cur_epsilon : 0.5024666666666666
# episode : 185, done reward : 0.10000001639127731, total_step : 2938, cur_epsilon : 0.5020666666666667
# episode : 186, done reward : 1.2000000327825546, total_step : 2961, cur_epsilon : 0.5013
# episode : 187, done reward : 0.10000001639127731, total_step : 2973, cur_epsilon : 0.5009
# episode : 188, done reward : 0.6000000238418579, total_step : 2990, cur_epsilon : 0.5003333333333333
# episode : 189, done reward : 0.20000001788139343, total_step : 3003, cur_epsilon : 0.4999
# episode : 190, done reward : 0.5000000223517418, total_step : 3019, cur_epsilon : 0.4993666666666666
# episode : 191, done reward : 0.6000000238418579, total_step : 3036, cur_epsilon : 0.49879999999999997
# episode : 192, done reward : 0.40000002086162567, total_step : 3051, cur_epsilon : 0.49829999999999997
# episode : 193, done reward : 1.2000000327825546, total_step : 3074, cur_epsilon : 0.4975333333333333
# episode : 194, done reward : 0.6000000238418579, total_step : 3091, cur_epsilon : 0.49696666666666667
# episode : 195, done reward : 0.8000000268220901, total_step : 3110, cur_epsilon : 0.4963333333333333
# episode : 196, done reward : 1.3000000342726707, total_step : 3134, cur_epsilon : 0.4955333333333333
# episode : 197, done reward : 1.1000000312924385, total_step : 3156, cur_epsilon : 0.49479999999999996
# episode : 198, done reward : 1.0000000298023224, total_step : 3177, cur_epsilon : 0.4941
# episode : 199, done reward : 1.0000000298023224, total_step : 3198, cur_epsilon : 0.49339999999999995
# episode : 200, done reward : 0.40000002086162567, total_step : 3213, cur_epsilon : 0.4929
# episode : 201, done reward : 0.6000000238418579, total_step : 3230, cur_epsilon : 0.4923333333333333
# episode : 202, done reward : 0.20000001788139343, total_step : 3243, cur_epsilon : 0.4919
# episode : 203, done reward : 0.30000001937150955, total_step : 3257, cur_epsilon : 0.4914333333333333
# episode : 204, done reward : 1.1000000312924385, total_step : 3279, cur_epsilon : 0.49069999999999997
# episode : 205, done reward : 0.6000000238418579, total_step : 3296, cur_epsilon : 0.4901333333333333
# episode : 206, done reward : 0.6000000238418579, total_step : 3313, cur_epsilon : 0.48956666666666665
# episode : 207, done reward : 0.30000001937150955, total_step : 3327, cur_epsilon : 0.4891
# episode : 208, done reward : 0.10000001639127731, total_step : 3339, cur_epsilon : 0.48869999999999997
# episode : 209, done reward : 0.20000001788139343, total_step : 3352, cur_epsilon : 0.4882666666666666
# episode : 210, done reward : 0.6000000238418579, total_step : 3369, cur_epsilon : 0.48769999999999997
# episode : 211, done reward : 0.40000002086162567, total_step : 3384, cur_epsilon : 0.48719999999999997
# episode : 212, done reward : 1.2000000327825546, total_step : 3407, cur_epsilon : 0.48643333333333333
# episode : 213, done reward : 0.30000001937150955, total_step : 3421, cur_epsilon : 0.48596666666666666
# episode : 214, done reward : 0.6000000238418579, total_step : 3438, cur_epsilon : 0.4854
# episode : 215, done reward : 0.5000000223517418, total_step : 3454, cur_epsilon : 0.48486666666666667
# episode : 216, done reward : 0.9000000283122063, total_step : 3474, cur_epsilon : 0.48419999999999996
# episode : 217, done reward : 0.700000025331974, total_step : 3492, cur_epsilon : 0.4836
# episode : 218, done reward : 0.700000025331974, total_step : 3510, cur_epsilon : 0.483
# episode : 219, done reward : 0.40000002086162567, total_step : 3525, cur_epsilon : 0.4825
# episode : 220, done reward : 1.0000000298023224, total_step : 3546, cur_epsilon : 0.4818
# episode : 221, done reward : 0.8000000268220901, total_step : 3565, cur_epsilon : 0.48116666666666663
# episode : 222, done reward : 0.30000001937150955, total_step : 3579, cur_epsilon : 0.48069999999999996
# episode : 223, done reward : 1.0000000298023224, total_step : 3600, cur_epsilon : 0.48
# episode : 224, done reward : 0.30000001937150955, total_step : 3614, cur_epsilon : 0.4795333333333333
# episode : 225, done reward : 0.20000001788139343, total_step : 3627, cur_epsilon : 0.47909999999999997
# episode : 226, done reward : 1.3000000342726707, total_step : 3651, cur_epsilon : 0.47829999999999995
# episode : 227, done reward : 0.30000001937150955, total_step : 3665, cur_epsilon : 0.47783333333333333
# episode : 228, done reward : 0.700000025331974, total_step : 3683, cur_epsilon : 0.4772333333333333
# episode : 229, done reward : 1.2000000327825546, total_step : 3706, cur_epsilon : 0.47646666666666665
# episode : 230, done reward : 1.2000000327825546, total_step : 3729, cur_epsilon : 0.4757
# episode : 231, done reward : 0.40000002086162567, total_step : 3744, cur_epsilon : 0.47519999999999996
# episode : 232, done reward : 0.8000000268220901, total_step : 3763, cur_epsilon : 0.47456666666666664
# episode : 233, done reward : 0.30000001937150955, total_step : 3777, cur_epsilon : 0.47409999999999997
# episode : 234, done reward : 0.6000000238418579, total_step : 3794, cur_epsilon : 0.4735333333333333
# episode : 235, done reward : 0.30000001937150955, total_step : 3808, cur_epsilon : 0.47306666666666664
# episode : 236, done reward : 0.30000001937150955, total_step : 3822, cur_epsilon : 0.47259999999999996
# episode : 237, done reward : 0.5000000223517418, total_step : 3838, cur_epsilon : 0.47206666666666663
# episode : 238, done reward : 0.700000025331974, total_step : 3856, cur_epsilon : 0.47146666666666665
# episode : 239, done reward : 0.8000000268220901, total_step : 3875, cur_epsilon : 0.4708333333333333
# episode : 240, done reward : 0.5000000223517418, total_step : 3891, cur_epsilon : 0.47029999999999994
# episode : 241, done reward : 0.10000001639127731, total_step : 3903, cur_epsilon : 0.4699
# episode : 242, done reward : 0.6000000238418579, total_step : 3920, cur_epsilon : 0.4693333333333333
# episode : 243, done reward : 0.6000000238418579, total_step : 3937, cur_epsilon : 0.46876666666666666
# episode : 244, done reward : 0.30000001937150955, total_step : 3951, cur_epsilon : 0.46829999999999994
# episode : 245, done reward : 1.1000000312924385, total_step : 3973, cur_epsilon : 0.4675666666666667
# episode : 246, done reward : 1.1000000312924385, total_step : 3995, cur_epsilon : 0.4668333333333333
# episode : 247, done reward : 0.20000001788139343, total_step : 4008, cur_epsilon : 0.4664
# episode : 248, done reward : 0.20000001788139343, total_step : 4021, cur_epsilon : 0.46596666666666664
# episode : 249, done reward : 0.10000001639127731, total_step : 4033, cur_epsilon : 0.4655666666666667
# episode : 250, done reward : 0.20000001788139343, total_step : 4046, cur_epsilon : 0.4651333333333333
# episode : 251, done reward : 0.10000001639127731, total_step : 4058, cur_epsilon : 0.46473333333333333
# episode : 252, done reward : 0.6000000238418579, total_step : 4075, cur_epsilon : 0.4641666666666666
# episode : 253, done reward : 0.30000001937150955, total_step : 4089, cur_epsilon : 0.4637
# episode : 254, done reward : 0.10000001639127731, total_step : 4101, cur_epsilon : 0.4633
# episode : 255, done reward : -0.09999998658895493, total_step : 4111, cur_epsilon : 0.46296666666666664
# episode : 256, done reward : 0.30000001937150955, total_step : 4125, cur_epsilon : 0.46249999999999997
# episode : 257, done reward : 0.5000000223517418, total_step : 4141, cur_epsilon : 0.46196666666666664
# episode : 258, done reward : 0.6000000238418579, total_step : 4158, cur_epsilon : 0.4614
# episode : 259, done reward : 0.5000000223517418, total_step : 4174, cur_epsilon : 0.46086666666666665
# episode : 260, done reward : 0.40000002086162567, total_step : 4189, cur_epsilon : 0.46036666666666665
# episode : 261, done reward : 0.5000000223517418, total_step : 4205, cur_epsilon : 0.4598333333333333
# episode : 262, done reward : 0.700000025331974, total_step : 4223, cur_epsilon : 0.45923333333333327
# episode : 263, done reward : 0.40000002086162567, total_step : 4238, cur_epsilon : 0.4587333333333333
# episode : 264, done reward : 0.5000000223517418, total_step : 4254, cur_epsilon : 0.45819999999999994
# episode : 265, done reward : 0.5000000223517418, total_step : 4270, cur_epsilon : 0.45766666666666667
# episode : 266, done reward : 0.700000025331974, total_step : 4288, cur_epsilon : 0.4570666666666666
# episode : 267, done reward : 0.5000000223517418, total_step : 4304, cur_epsilon : 0.45653333333333335
# episode : 268, done reward : 1.0000000298023224, total_step : 4325, cur_epsilon : 0.4558333333333333
# episode : 269, done reward : 1.2000000327825546, total_step : 4348, cur_epsilon : 0.4550666666666666
# episode : 270, done reward : 0.8000000268220901, total_step : 4367, cur_epsilon : 0.4544333333333333
# episode : 271, done reward : 0.20000001788139343, total_step : 4380, cur_epsilon : 0.45399999999999996
# episode : 272, done reward : 0.10000001639127731, total_step : 4392, cur_epsilon : 0.4536
# episode : 273, done reward : 0.9000000283122063, total_step : 4412, cur_epsilon : 0.4529333333333333
# episode : 274, done reward : 0.30000001937150955, total_step : 4426, cur_epsilon : 0.4524666666666667
# episode : 275, done reward : 0.40000002086162567, total_step : 4441, cur_epsilon : 0.4519666666666666
# episode : 276, done reward : 1.1000000312924385, total_step : 4463, cur_epsilon : 0.4512333333333333
# episode : 277, done reward : 0.40000002086162567, total_step : 4478, cur_epsilon : 0.4507333333333333
# episode : 278, done reward : 0.20000001788139343, total_step : 4491, cur_epsilon : 0.4503
# episode : 279, done reward : 0.30000001937150955, total_step : 4505, cur_epsilon : 0.4498333333333333
# episode : 280, done reward : 0.20000001788139343, total_step : 4518, cur_epsilon : 0.44939999999999997
# episode : 281, done reward : 0.30000001937150955, total_step : 4532, cur_epsilon : 0.4489333333333333
# episode : 282, done reward : 1.0000000298023224, total_step : 4553, cur_epsilon : 0.4482333333333333
# episode : 283, done reward : 0.9000000283122063, total_step : 4573, cur_epsilon : 0.44756666666666667
# episode : 284, done reward : 0.700000025331974, total_step : 4591, cur_epsilon : 0.4469666666666666
# episode : 285, done reward : 0.6000000238418579, total_step : 4608, cur_epsilon : 0.4464
# episode : 286, done reward : 1.0000000298023224, total_step : 4629, cur_epsilon : 0.4457
# episode : 287, done reward : 1.3000000342726707, total_step : 4653, cur_epsilon : 0.44489999999999996
# episode : 288, done reward : 1.600000038743019, total_step : 4680, cur_epsilon : 0.44399999999999995
# episode : 289, done reward : 0.700000025331974, total_step : 4698, cur_epsilon : 0.4434
# episode : 290, done reward : 0.700000025331974, total_step : 4716, cur_epsilon : 0.44279999999999997
# episode : 291, done reward : 2.200000047683716, total_step : 4749, cur_epsilon : 0.4417
# episode : 292, done reward : 0.30000001937150955, total_step : 4763, cur_epsilon : 0.4412333333333333
# episode : 293, done reward : 0.20000001788139343, total_step : 4776, cur_epsilon : 0.44079999999999997
# episode : 294, done reward : 0.6000000238418579, total_step : 4793, cur_epsilon : 0.4402333333333333
# episode : 295, done reward : 0.700000025331974, total_step : 4811, cur_epsilon : 0.4396333333333333
# episode : 296, done reward : 0.40000002086162567, total_step : 4826, cur_epsilon : 0.4391333333333333
# episode : 297, done reward : 0.40000002086162567, total_step : 4841, cur_epsilon : 0.4386333333333333
# episode : 298, done reward : 0.8000000268220901, total_step : 4860, cur_epsilon : 0.43799999999999994
# episode : 299, done reward : 0.5000000223517418, total_step : 4876, cur_epsilon : 0.43746666666666667
# episode : 300, done reward : 0.40000002086162567, total_step : 4891, cur_epsilon : 0.4369666666666666
# episode : 301, done reward : 0.30000001937150955, total_step : 4905, cur_epsilon : 0.4365
# episode : 302, done reward : 1.600000038743019, total_step : 4932, cur_epsilon : 0.4356
# episode : 303, done reward : 0.30000001937150955, total_step : 4946, cur_epsilon : 0.4351333333333333
# episode : 304, done reward : 0.700000025331974, total_step : 4964, cur_epsilon : 0.4345333333333333
# episode : 305, done reward : 0.40000002086162567, total_step : 4979, cur_epsilon : 0.43403333333333327
# episode : 306, done reward : 1.1000000312924385, total_step : 5001, cur_epsilon : 0.4333
# episode : 307, done reward : 0.8000000268220901, total_step : 5020, cur_epsilon : 0.43266666666666664
# episode : 308, done reward : 2.6000000536441803, total_step : 5057, cur_epsilon : 0.43143333333333334
# episode : 309, done reward : 1.3000000342726707, total_step : 5081, cur_epsilon : 0.4306333333333333
# episode : 310, done reward : 0.8000000268220901, total_step : 5100, cur_epsilon : 0.42999999999999994
# episode : 311, done reward : 0.20000001788139343, total_step : 5113, cur_epsilon : 0.42956666666666665
# episode : 312, done reward : 0.40000002086162567, total_step : 5128, cur_epsilon : 0.42906666666666665
# episode : 313, done reward : 0.9000000283122063, total_step : 5148, cur_epsilon : 0.4284
# episode : 314, done reward : 1.600000038743019, total_step : 5175, cur_epsilon : 0.4275
# episode : 315, done reward : 0.20000001788139343, total_step : 5188, cur_epsilon : 0.42706666666666665
# episode : 316, done reward : 0.5000000223517418, total_step : 5204, cur_epsilon : 0.4265333333333333
# episode : 317, done reward : 0.700000025331974, total_step : 5222, cur_epsilon : 0.4259333333333333
# episode : 318, done reward : 0.5000000223517418, total_step : 5238, cur_epsilon : 0.4254
# episode : 319, done reward : 1.7000000402331352, total_step : 5266, cur_epsilon : 0.42446666666666666
# episode : 320, done reward : 0.30000001937150955, total_step : 5280, cur_epsilon : 0.424
# episode : 321, done reward : 0.6000000238418579, total_step : 5297, cur_epsilon : 0.42343333333333333
# episode : 322, done reward : 1.1000000312924385, total_step : 5319, cur_epsilon : 0.42269999999999996
# episode : 323, done reward : 2.8000000566244125, total_step : 5358, cur_epsilon : 0.4214
# episode : 324, done reward : 1.0000000298023224, total_step : 5379, cur_epsilon : 0.42069999999999996
# episode : 325, done reward : 0.8000000268220901, total_step : 5398, cur_epsilon : 0.42006666666666664
# episode : 326, done reward : 0.6000000238418579, total_step : 5415, cur_epsilon : 0.4195
# episode : 327, done reward : 0.8000000268220901, total_step : 5434, cur_epsilon : 0.4188666666666666
# episode : 328, done reward : 0.700000025331974, total_step : 5452, cur_epsilon : 0.4182666666666667
# episode : 329, done reward : 0.30000001937150955, total_step : 5466, cur_epsilon : 0.41779999999999995
# episode : 330, done reward : 0.5000000223517418, total_step : 5482, cur_epsilon : 0.4172666666666667
# episode : 331, done reward : 0.30000001937150955, total_step : 5496, cur_epsilon : 0.41679999999999995
# episode : 332, done reward : 0.40000002086162567, total_step : 5511, cur_epsilon : 0.4163
# episode : 333, done reward : 0.700000025331974, total_step : 5529, cur_epsilon : 0.41569999999999996
# episode : 334, done reward : 0.9000000283122063, total_step : 5549, cur_epsilon : 0.4150333333333333
# episode : 335, done reward : 0.30000001937150955, total_step : 5563, cur_epsilon : 0.41456666666666664
# episode : 336, done reward : 0.20000001788139343, total_step : 5576, cur_epsilon : 0.4141333333333333
# episode : 337, done reward : 0.40000002086162567, total_step : 5591, cur_epsilon : 0.4136333333333333
# episode : 338, done reward : 1.4901161193847656e-08, total_step : 5602, cur_epsilon : 0.41326666666666667
# episode : 339, done reward : 0.9000000283122063, total_step : 5622, cur_epsilon : 0.41259999999999997
# episode : 340, done reward : 1.0000000298023224, total_step : 5643, cur_epsilon : 0.4119
# episode : 341, done reward : 0.30000001937150955, total_step : 5657, cur_epsilon : 0.4114333333333333
# episode : 342, done reward : 0.6000000238418579, total_step : 5674, cur_epsilon : 0.41086666666666666
# episode : 343, done reward : 0.6000000238418579, total_step : 5691, cur_epsilon : 0.4103
# episode : 344, done reward : 0.30000001937150955, total_step : 5705, cur_epsilon : 0.40983333333333327
# episode : 345, done reward : 0.5000000223517418, total_step : 5721, cur_epsilon : 0.4093
# episode : 346, done reward : 1.500000037252903, total_step : 5747, cur_epsilon : 0.4084333333333333
# episode : 347, done reward : 1.0000000298023224, total_step : 5768, cur_epsilon : 0.4077333333333333
# episode : 348, done reward : 1.0000000298023224, total_step : 5789, cur_epsilon : 0.4070333333333333
# episode : 349, done reward : 0.40000002086162567, total_step : 5804, cur_epsilon : 0.4065333333333333
# episode : 350, done reward : 0.5000000223517418, total_step : 5820, cur_epsilon : 0.40599999999999997
# episode : 351, done reward : 0.8000000268220901, total_step : 5839, cur_epsilon : 0.40536666666666665
# episode : 352, done reward : 0.700000025331974, total_step : 5857, cur_epsilon : 0.4047666666666666
# episode : 353, done reward : 0.30000001937150955, total_step : 5871, cur_epsilon : 0.4043
# episode : 354, done reward : 0.700000025331974, total_step : 5889, cur_epsilon : 0.40369999999999995
# episode : 355, done reward : 0.9000000283122063, total_step : 5909, cur_epsilon : 0.4030333333333333
# episode : 356, done reward : 0.8000000268220901, total_step : 5928, cur_epsilon : 0.4024
# episode : 357, done reward : 0.20000001788139343, total_step : 5941, cur_epsilon : 0.40196666666666664
# episode : 358, done reward : 0.5000000223517418, total_step : 5957, cur_epsilon : 0.4014333333333333
# episode : 359, done reward : 1.3000000342726707, total_step : 5981, cur_epsilon : 0.4006333333333333
# episode : 360, done reward : 1.0000000298023224, total_step : 6002, cur_epsilon : 0.3999333333333333
# episode : 361, done reward : 1.4000000357627869, total_step : 6027, cur_epsilon : 0.3991
# episode : 362, done reward : 1.500000037252903, total_step : 6053, cur_epsilon : 0.39823333333333333
# episode : 363, done reward : 1.600000038743019, total_step : 6080, cur_epsilon : 0.3973333333333333
# episode : 364, done reward : 1.7000000402331352, total_step : 6108, cur_epsilon : 0.3964
# episode : 365, done reward : 0.10000001639127731, total_step : 6120, cur_epsilon : 0.396
# episode : 366, done reward : 1.0000000298023224, total_step : 6141, cur_epsilon : 0.3953
# episode : 367, done reward : 0.20000001788139343, total_step : 6154, cur_epsilon : 0.39486666666666664
# episode : 368, done reward : 0.700000025331974, total_step : 6172, cur_epsilon : 0.39426666666666665
# episode : 369, done reward : 0.9000000283122063, total_step : 6192, cur_epsilon : 0.39359999999999995
# episode : 370, done reward : 0.6000000238418579, total_step : 6209, cur_epsilon : 0.39303333333333335
# episode : 371, done reward : 0.700000025331974, total_step : 6227, cur_epsilon : 0.3924333333333333
# episode : 372, done reward : 0.9000000283122063, total_step : 6247, cur_epsilon : 0.39176666666666665
# episode : 373, done reward : 0.9000000283122063, total_step : 6267, cur_epsilon : 0.3911
# episode : 374, done reward : 0.700000025331974, total_step : 6285, cur_epsilon : 0.39049999999999996
# episode : 375, done reward : 0.20000001788139343, total_step : 6298, cur_epsilon : 0.3900666666666667
# episode : 376, done reward : 0.40000002086162567, total_step : 6313, cur_epsilon : 0.3895666666666666
# episode : 377, done reward : 1.2000000327825546, total_step : 6336, cur_epsilon : 0.3888
# episode : 378, done reward : 0.30000001937150955, total_step : 6350, cur_epsilon : 0.3883333333333333
# episode : 379, done reward : 0.8000000268220901, total_step : 6369, cur_epsilon : 0.3877
# episode : 380, done reward : 0.6000000238418579, total_step : 6386, cur_epsilon : 0.38713333333333333
# episode : 381, done reward : 1.0000000298023224, total_step : 6407, cur_epsilon : 0.3864333333333333
# episode : 382, done reward : 0.9000000283122063, total_step : 6427, cur_epsilon : 0.38576666666666665
# episode : 383, done reward : 0.10000001639127731, total_step : 6439, cur_epsilon : 0.38536666666666664
# episode : 384, done reward : 0.5000000223517418, total_step : 6455, cur_epsilon : 0.3848333333333333
# episode : 385, done reward : 0.30000001937150955, total_step : 6469, cur_epsilon : 0.38436666666666663
# episode : 386, done reward : 0.6000000238418579, total_step : 6486, cur_epsilon : 0.3838
# episode : 387, done reward : 1.1000000312924385, total_step : 6508, cur_epsilon : 0.38306666666666667
# episode : 388, done reward : 0.700000025331974, total_step : 6526, cur_epsilon : 0.3824666666666666
# episode : 389, done reward : 0.20000001788139343, total_step : 6539, cur_epsilon : 0.38203333333333334
# episode : 390, done reward : 0.40000002086162567, total_step : 6554, cur_epsilon : 0.3815333333333333
# episode : 391, done reward : 0.20000001788139343, total_step : 6567, cur_epsilon : 0.3811
# episode : 392, done reward : 0.40000002086162567, total_step : 6582, cur_epsilon : 0.38059999999999994
# episode : 393, done reward : 0.5000000223517418, total_step : 6598, cur_epsilon : 0.38006666666666666
# episode : 394, done reward : 0.700000025331974, total_step : 6616, cur_epsilon : 0.3794666666666666
# episode : 395, done reward : 0.30000001937150955, total_step : 6630, cur_epsilon : 0.379
# episode : 396, done reward : 0.10000001639127731, total_step : 6642, cur_epsilon : 0.37859999999999994
# episode : 397, done reward : 0.30000001937150955, total_step : 6656, cur_epsilon : 0.3781333333333333
# episode : 398, done reward : 0.40000002086162567, total_step : 6671, cur_epsilon : 0.3776333333333333
# episode : 399, done reward : 0.5000000223517418, total_step : 6687, cur_epsilon : 0.3771
# episode : 400, done reward : 1.3000000342726707, total_step : 6711, cur_epsilon : 0.37629999999999997
# episode : 401, done reward : 0.700000025331974, total_step : 6729, cur_epsilon : 0.3757
# episode : 402, done reward : 0.30000001937150955, total_step : 6743, cur_epsilon : 0.3752333333333333
# episode : 403, done reward : 0.5000000223517418, total_step : 6759, cur_epsilon : 0.3747
# episode : 404, done reward : 0.20000001788139343, total_step : 6772, cur_epsilon : 0.37426666666666664
# episode : 405, done reward : 0.9000000283122063, total_step : 6792, cur_epsilon : 0.3736
# episode : 406, done reward : 0.700000025331974, total_step : 6810, cur_epsilon : 0.373
# episode : 407, done reward : 0.40000002086162567, total_step : 6825, cur_epsilon : 0.37249999999999994
# episode : 408, done reward : 0.30000001937150955, total_step : 6839, cur_epsilon : 0.3720333333333333
# episode : 409, done reward : 0.8000000268220901, total_step : 6858, cur_epsilon : 0.37139999999999995
# episode : 410, done reward : 0.9000000283122063, total_step : 6878, cur_epsilon : 0.3707333333333333
# episode : 411, done reward : 0.30000001937150955, total_step : 6892, cur_epsilon : 0.37026666666666663
# episode : 412, done reward : 0.8000000268220901, total_step : 6911, cur_epsilon : 0.3696333333333333
# episode : 413, done reward : 1.0000000298023224, total_step : 6932, cur_epsilon : 0.36893333333333334
# episode : 414, done reward : 0.8000000268220901, total_step : 6951, cur_epsilon : 0.36829999999999996
# episode : 415, done reward : 1.500000037252903, total_step : 6977, cur_epsilon : 0.3674333333333333
# episode : 416, done reward : 2.1000000461935997, total_step : 7009, cur_epsilon : 0.3663666666666666
# episode : 417, done reward : 0.40000002086162567, total_step : 7024, cur_epsilon : 0.3658666666666667
# episode : 418, done reward : 0.40000002086162567, total_step : 7039, cur_epsilon : 0.3653666666666666
# episode : 419, done reward : 0.6000000238418579, total_step : 7056, cur_epsilon : 0.3648
# episode : 420, done reward : 1.1000000312924385, total_step : 7078, cur_epsilon : 0.36406666666666665
# episode : 421, done reward : 0.30000001937150955, total_step : 7092, cur_epsilon : 0.3636
# episode : 422, done reward : 0.20000001788139343, total_step : 7105, cur_epsilon : 0.36316666666666664
# episode : 423, done reward : 2.8000000566244125, total_step : 7144, cur_epsilon : 0.36186666666666667
# episode : 424, done reward : 0.8000000268220901, total_step : 7163, cur_epsilon : 0.3612333333333333
# episode : 425, done reward : 1.7000000402331352, total_step : 7191, cur_epsilon : 0.36029999999999995
# episode : 426, done reward : 0.8000000268220901, total_step : 7210, cur_epsilon : 0.35966666666666663
# episode : 427, done reward : 0.20000001788139343, total_step : 7223, cur_epsilon : 0.3592333333333333
# episode : 428, done reward : 0.10000001639127731, total_step : 7235, cur_epsilon : 0.35883333333333334
# episode : 429, done reward : 0.5000000223517418, total_step : 7251, cur_epsilon : 0.35829999999999995
# episode : 430, done reward : 0.700000025331974, total_step : 7269, cur_epsilon : 0.3577
# episode : 431, done reward : 0.40000002086162567, total_step : 7284, cur_epsilon : 0.35719999999999996
# episode : 432, done reward : 0.8000000268220901, total_step : 7303, cur_epsilon : 0.35656666666666664
# episode : 433, done reward : 1.2000000327825546, total_step : 7326, cur_epsilon : 0.3558
# episode : 434, done reward : 1.0000000298023224, total_step : 7347, cur_epsilon : 0.35509999999999997
# episode : 435, done reward : 0.700000025331974, total_step : 7365, cur_epsilon : 0.3545
# episode : 436, done reward : 0.10000001639127731, total_step : 7377, cur_epsilon : 0.35409999999999997
# episode : 437, done reward : 0.8000000268220901, total_step : 7396, cur_epsilon : 0.35346666666666665
# episode : 438, done reward : 1.4901161193847656e-08, total_step : 7407, cur_epsilon : 0.35309999999999997
# episode : 439, done reward : 1.9000000432133675, total_step : 7437, cur_epsilon : 0.35209999999999997
# episode : 440, done reward : 0.9000000283122063, total_step : 7457, cur_epsilon : 0.3514333333333333
# episode : 441, done reward : 0.20000001788139343, total_step : 7470, cur_epsilon : 0.351
# episode : 442, done reward : 1.600000038743019, total_step : 7497, cur_epsilon : 0.35009999999999997
# episode : 443, done reward : 0.5000000223517418, total_step : 7513, cur_epsilon : 0.34956666666666664
# episode : 444, done reward : 2.0000000447034836, total_step : 7544, cur_epsilon : 0.3485333333333333
# episode : 445, done reward : 0.40000002086162567, total_step : 7559, cur_epsilon : 0.3480333333333333
# episode : 446, done reward : 0.5000000223517418, total_step : 7575, cur_epsilon : 0.3475
# episode : 447, done reward : 1.8000000417232513, total_step : 7604, cur_epsilon : 0.3465333333333333
# episode : 448, done reward : 1.4000000357627869, total_step : 7629, cur_epsilon : 0.34569999999999995
# episode : 449, done reward : 0.6000000238418579, total_step : 7646, cur_epsilon : 0.3451333333333333
# episode : 450, done reward : 1.2000000327825546, total_step : 7669, cur_epsilon : 0.34436666666666665
# episode : 451, done reward : 2.0000000447034836, total_step : 7700, cur_epsilon : 0.3433333333333333
# episode : 452, done reward : 0.20000001788139343, total_step : 7713, cur_epsilon : 0.3429
# episode : 453, done reward : 1.1000000312924385, total_step : 7735, cur_epsilon : 0.3421666666666666
# episode : 454, done reward : 0.5000000223517418, total_step : 7751, cur_epsilon : 0.3416333333333333
# episode : 455, done reward : 1.0000000298023224, total_step : 7772, cur_epsilon : 0.3409333333333333
# episode : 456, done reward : 1.600000038743019, total_step : 7799, cur_epsilon : 0.3400333333333333
# episode : 457, done reward : 0.30000001937150955, total_step : 7813, cur_epsilon : 0.33956666666666663
# episode : 458, done reward : 0.40000002086162567, total_step : 7828, cur_epsilon : 0.3390666666666666
# episode : 459, done reward : 0.10000001639127731, total_step : 7840, cur_epsilon : 0.33866666666666667
# episode : 460, done reward : 0.6000000238418579, total_step : 7857, cur_epsilon : 0.33809999999999996
# episode : 461, done reward : 0.30000001937150955, total_step : 7871, cur_epsilon : 0.3376333333333333
# episode : 462, done reward : 0.6000000238418579, total_step : 7888, cur_epsilon : 0.3370666666666666
# episode : 463, done reward : 1.600000038743019, total_step : 7915, cur_epsilon : 0.33616666666666667
# episode : 464, done reward : 0.700000025331974, total_step : 7933, cur_epsilon : 0.3355666666666666
# episode : 465, done reward : 2.1000000461935997, total_step : 7965, cur_epsilon : 0.33449999999999996
# episode : 466, done reward : 0.10000001639127731, total_step : 7977, cur_epsilon : 0.33409999999999995
# episode : 467, done reward : 1.7000000402331352, total_step : 8005, cur_epsilon : 0.33316666666666667
# episode : 468, done reward : 0.700000025331974, total_step : 8023, cur_epsilon : 0.3325666666666666
# episode : 469, done reward : 1.0000000298023224, total_step : 8044, cur_epsilon : 0.33186666666666664
# episode : 470, done reward : 0.30000001937150955, total_step : 8058, cur_epsilon : 0.3314
# episode : 471, done reward : 0.9000000283122063, total_step : 8078, cur_epsilon : 0.3307333333333333
# episode : 472, done reward : 0.5000000223517418, total_step : 8094, cur_epsilon : 0.3302
# episode : 473, done reward : 3.5000000670552254, total_step : 8140, cur_epsilon : 0.32866666666666666
# episode : 474, done reward : 1.2000000327825546, total_step : 8163, cur_epsilon : 0.32789999999999997
# episode : 475, done reward : 0.700000025331974, total_step : 8181, cur_epsilon : 0.3273
# episode : 476, done reward : 0.30000001937150955, total_step : 8195, cur_epsilon : 0.3268333333333333
# episode : 477, done reward : 0.10000001639127731, total_step : 8207, cur_epsilon : 0.3264333333333333
# episode : 478, done reward : 2.200000047683716, total_step : 8240, cur_epsilon : 0.3253333333333333
# episode : 479, done reward : 0.10000001639127731, total_step : 8252, cur_epsilon : 0.3249333333333333
# episode : 480, done reward : 3.100000061094761, total_step : 8294, cur_epsilon : 0.3235333333333333
# episode : 481, done reward : 0.20000001788139343, total_step : 8307, cur_epsilon : 0.3231
# episode : 482, done reward : 2.400000050663948, total_step : 8342, cur_epsilon : 0.3219333333333333
# episode : 483, done reward : 0.6000000238418579, total_step : 8359, cur_epsilon : 0.32136666666666663
# episode : 484, done reward : 0.700000025331974, total_step : 8377, cur_epsilon : 0.32076666666666664
# episode : 485, done reward : 0.8000000268220901, total_step : 8396, cur_epsilon : 0.3201333333333333
# episode : 486, done reward : 0.700000025331974, total_step : 8414, cur_epsilon : 0.31953333333333334
# episode : 487, done reward : 0.10000001639127731, total_step : 8426, cur_epsilon : 0.3191333333333333
# ...
# episode : 1111, done reward : 0.20000001788139343, total_step : 24271, cur_epsilon : 0.002
# episode : 1112, done reward : 1.600000038743019, total_step : 24298, cur_epsilon : 0.002
# episode : 1113, done reward : 0.8000000268220901, total_step : 24317, cur_epsilon : 0.002
# episode : 1114, done reward : 3.8000000715255737, total_step : 24366, cur_epsilon : 0.002
# episode : 1115, done reward : 0.700000025331974, total_step : 24384, cur_epsilon : 0.002
# episode : 1116, done reward : 0.40000002086162567, total_step : 24399, cur_epsilon : 0.002
# episode : 1117, done reward : 0.8000000268220901, total_step : 24418, cur_epsilon : 0.002
# episode : 1118, done reward : 0.8000000268220901, total_step : 24437, cur_epsilon : 0.002
# episode : 1119, done reward : 5.200000092387199, total_step : 24500, cur_epsilon : 0.002
# episode : 1120, done reward : 3.4000000655651093, total_step : 24545, cur_epsilon : 0.002
# episode : 1121, done reward : 0.30000001937150955, total_step : 24559, cur_epsilon : 0.002
# episode : 1122, done reward : 2.6000000536441803, total_step : 24596, cur_epsilon : 0.002
# episode : 1123, done reward : 0.40000002086162567, total_step : 24611, cur_epsilon : 0.002
# episode : 1124, done reward : 0.30000001937150955, total_step : 24625, cur_epsilon : 0.002
# episode : 1125, done reward : 0.700000025331974, total_step : 24643, cur_epsilon : 0.002
# episode : 1126, done reward : 0.30000001937150955, total_step : 24657, cur_epsilon : 0.002
# episode : 1127, done reward : 5.400000095367432, total_step : 24722, cur_epsilon : 0.002
# episode : 1128, done reward : 0.20000001788139343, total_step : 24735, cur_epsilon : 0.002
# episode : 1129, done reward : 3.100000061094761, total_step : 24777, cur_epsilon : 0.002
# episode : 1130, done reward : 1.0000000298023224, total_step : 24798, cur_epsilon : 0.002
# episode : 1131, done reward : 0.700000025331974, total_step : 24816, cur_epsilon : 0.002
# episode : 1132, done reward : 0.40000002086162567, total_step : 24831, cur_epsilon : 0.002
# episode : 1133, done reward : 4.800000086426735, total_step : 24890, cur_epsilon : 0.002
# episode : 1134, done reward : 0.5000000223517418, total_step : 24906, cur_epsilon : 0.002
# episode : 1135, done reward : 2.6000000536441803, total_step : 24943, cur_epsilon : 0.002
# episode : 1136, done reward : 1.0000000298023224, total_step : 24964, cur_epsilon : 0.002
# episode : 1137, done reward : 3.90000007301569, total_step : 25014, cur_epsilon : 0.002
# episode : 1138, done reward : 0.8000000268220901, total_step : 25033, cur_epsilon : 0.002
# episode : 1139, done reward : 0.6000000238418579, total_step : 25050, cur_epsilon : 0.002
# episode : 1140, done reward : 0.5000000223517418, total_step : 25066, cur_epsilon : 0.002
# episode : 1141, done reward : 0.30000001937150955, total_step : 25080, cur_epsilon : 0.002
# episode : 1142, done reward : 0.700000025331974, total_step : 25098, cur_epsilon : 0.002
# episode : 1143, done reward : 0.5000000223517418, total_step : 25114, cur_epsilon : 0.002
# episode : 1144, done reward : 0.6000000238418579, total_step : 25131, cur_epsilon : 0.002
# episode : 1145, done reward : 1.3000000342726707, total_step : 25155, cur_epsilon : 0.002
# episode : 1146, done reward : 0.5000000223517418, total_step : 25171, cur_epsilon : 0.002
# episode : 1147, done reward : 5.900000102818012, total_step : 25241, cur_epsilon : 0.002
# episode : 1148, done reward : 0.9000000283122063, total_step : 25261, cur_epsilon : 0.002
# episode : 1149, done reward : 0.5000000223517418, total_step : 25277, cur_epsilon : 0.002
# episode : 1150, done reward : 3.4000000655651093, total_step : 25322, cur_epsilon : 0.002
# episode : 1151, done reward : 0.40000002086162567, total_step : 25337, cur_epsilon : 0.002
# episode : 1152, done reward : 0.30000001937150955, total_step : 25351, cur_epsilon : 0.002
# episode : 1153, done reward : 0.20000001788139343, total_step : 25364, cur_epsilon : 0.002
# episode : 1154, done reward : 0.20000001788139343, total_step : 25377, cur_epsilon : 0.002
# episode : 1155, done reward : 0.700000025331974, total_step : 25395, cur_epsilon : 0.002
# episode : 1156, done reward : 6.300000108778477, total_step : 25469, cur_epsilon : 0.002
# episode : 1157, done reward : 0.20000001788139343, total_step : 25482, cur_epsilon : 0.002
# episode : 1158, done reward : 0.6000000238418579, total_step : 25499, cur_epsilon : 0.002
# episode : 1159, done reward : 0.5000000223517418, total_step : 25515, cur_epsilon : 0.002
# episode : 1160, done reward : 5.70000009983778, total_step : 25583, cur_epsilon : 0.002
# episode : 1161, done reward : 0.9000000283122063, total_step : 25603, cur_epsilon : 0.002
# episode : 1162, done reward : 0.30000001937150955, total_step : 25617, cur_epsilon : 0.002
# episode : 1163, done reward : 3.8000000715255737, total_step : 25666, cur_epsilon : 0.002
# episode : 1164, done reward : 0.700000025331974, total_step : 25684, cur_epsilon : 0.002
# episode : 1165, done reward : 0.20000001788139343, total_step : 25697, cur_epsilon : 0.002
# episode : 1166, done reward : 0.700000025331974, total_step : 25715, cur_epsilon : 0.002
# episode : 1167, done reward : 0.700000025331974, total_step : 25733, cur_epsilon : 0.002
# episode : 1168, done reward : 0.700000025331974, total_step : 25751, cur_epsilon : 0.002
# episode : 1169, done reward : 0.40000002086162567, total_step : 25766, cur_epsilon : 0.002
# episode : 1170, done reward : 0.8000000268220901, total_step : 25785, cur_epsilon : 0.002
# episode : 1171, done reward : 4.100000075995922, total_step : 25837, cur_epsilon : 0.002
# episode : 1172, done reward : 0.30000001937150955, total_step : 25851, cur_epsilon : 0.002
# episode : 1173, done reward : 0.40000002086162567, total_step : 25866, cur_epsilon : 0.002
# episode : 1174, done reward : 0.9000000283122063, total_step : 25886, cur_epsilon : 0.002
# episode : 1175, done reward : 2.8000000566244125, total_step : 25925, cur_epsilon : 0.002
# episode : 1176, done reward : 1.4901161193847656e-08, total_step : 25936, cur_epsilon : 0.002
# episode : 1177, done reward : 1.3000000342726707, total_step : 25960, cur_epsilon : 0.002
# episode : 1178, done reward : 3.300000064074993, total_step : 26004, cur_epsilon : 0.002
# episode : 1179, done reward : 0.20000001788139343, total_step : 26017, cur_epsilon : 0.002
# episode : 1180, done reward : 0.5000000223517418, total_step : 26033, cur_epsilon : 0.002
# episode : 1181, done reward : 5.600000098347664, total_step : 26100, cur_epsilon : 0.002
# episode : 1182, done reward : 3.6000000685453415, total_step : 26147, cur_epsilon : 0.002
# episode : 1183, done reward : 0.40000002086162567, total_step : 26162, cur_epsilon : 0.002
# episode : 1184, done reward : 0.700000025331974, total_step : 26180, cur_epsilon : 0.002
# episode : 1185, done reward : 0.8000000268220901, total_step : 26199, cur_epsilon : 0.002
# episode : 1186, done reward : 1.8000000417232513, total_step : 26228, cur_epsilon : 0.002
# episode : 1187, done reward : 0.8000000268220901, total_step : 26247, cur_epsilon : 0.002
# episode : 1188, done reward : 2.6000000536441803, total_step : 26284, cur_epsilon : 0.002
# episode : 1189, done reward : 0.30000001937150955, total_step : 26298, cur_epsilon : 0.002
# episode : 1190, done reward : 0.5000000223517418, total_step : 26314, cur_epsilon : 0.002
# episode : 1191, done reward : 5.000000089406967, total_step : 26375, cur_epsilon : 0.002
# episode : 1192, done reward : 3.100000061094761, total_step : 26417, cur_epsilon : 0.002
# episode : 1193, done reward : 1.3000000342726707, total_step : 26441, cur_epsilon : 0.002
# episode : 1194, done reward : 0.700000025331974, total_step : 26459, cur_epsilon : 0.002
# episode : 1195, done reward : 10.10000016540289, total_step : 26571, cur_epsilon : 0.002
# episode : 1196, done reward : 0.9000000283122063, total_step : 26591, cur_epsilon : 0.002
# episode : 1197, done reward : 0.8000000268220901, total_step : 26610, cur_epsilon : 0.002
# episode : 1198, done reward : 0.9000000283122063, total_step : 26630, cur_epsilon : 0.002
# episode : 1199, done reward : 0.700000025331974, total_step : 26648, cur_epsilon : 0.002
# episode : 1200, done reward : 0.5000000223517418, total_step : 26664, cur_epsilon : 0.002
# episode : 1201, done reward : 0.40000002086162567, total_step : 26679, cur_epsilon : 0.002
# episode : 1202, done reward : 0.8000000268220901, total_step : 26698, cur_epsilon : 0.002
# episode : 1203, done reward : 0.8000000268220901, total_step : 26717, cur_epsilon : 0.002
# episode : 1204, done reward : 0.40000002086162567, total_step : 26732, cur_epsilon : 0.002
# episode : 1205, done reward : 0.8000000268220901, total_step : 26751, cur_epsilon : 0.002
# episode : 1206, done reward : 0.20000001788139343, total_step : 26764, cur_epsilon : 0.002
# episode : 1207, done reward : 0.6000000238418579, total_step : 26781, cur_epsilon : 0.002
# episode : 1208, done reward : 0.6000000238418579, total_step : 26798, cur_epsilon : 0.002
# episode : 1209, done reward : 0.700000025331974, total_step : 26816, cur_epsilon : 0.002
# episode : 1210, done reward : 3.100000061094761, total_step : 26858, cur_epsilon : 0.002
# episode : 1211, done reward : 0.10000001639127731, total_step : 26870, cur_epsilon : 0.002
# episode : 1212, done reward : 0.700000025331974, total_step : 26888, cur_epsilon : 0.002
# episode : 1213, done reward : 0.40000002086162567, total_step : 26903, cur_epsilon : 0.002
# episode : 1214, done reward : 0.20000001788139343, total_step : 26916, cur_epsilon : 0.002
# episode : 1215, done reward : 0.9000000283122063, total_step : 26936, cur_epsilon : 0.002
# episode : 1216, done reward : 2.0000000447034836, total_step : 26967, cur_epsilon : 0.002
# episode : 1217, done reward : 0.8000000268220901, total_step : 26986, cur_epsilon : 0.002
# episode : 1218, done reward : 0.9000000283122063, total_step : 27006, cur_epsilon : 0.002
# episode : 1219, done reward : 0.8000000268220901, total_step : 27025, cur_epsilon : 0.002
# episode : 1220, done reward : 4.500000081956387, total_step : 27081, cur_epsilon : 0.002
# episode : 1221, done reward : 3.300000064074993, total_step : 27125, cur_epsilon : 0.002
# episode : 1222, done reward : 1.7000000402331352, total_step : 27153, cur_epsilon : 0.002
# episode : 1223, done reward : 3.90000007301569, total_step : 27203, cur_epsilon : 0.002
# episode : 1224, done reward : 0.20000001788139343, total_step : 27216, cur_epsilon : 0.002
# episode : 1225, done reward : 0.6000000238418579, total_step : 27233, cur_epsilon : 0.002
# episode : 1226, done reward : 0.40000002086162567, total_step : 27248, cur_epsilon : 0.002
# episode : 1227, done reward : 0.5000000223517418, total_step : 27264, cur_epsilon : 0.002
# episode : 1228, done reward : 0.6000000238418579, total_step : 27281, cur_epsilon : 0.002
# episode : 1229, done reward : 0.30000001937150955, total_step : 27295, cur_epsilon : 0.002
# episode : 1230, done reward : 0.700000025331974, total_step : 27313, cur_epsilon : 0.002
# episode : 1231, done reward : 0.6000000238418579, total_step : 27330, cur_epsilon : 0.002
# episode : 1232, done reward : 0.20000001788139343, total_step : 27343, cur_epsilon : 0.002
# episode : 1233, done reward : 8.200000137090683, total_step : 27436, cur_epsilon : 0.002
# episode : 1234, done reward : 1.0000000298023224, total_step : 27457, cur_epsilon : 0.002
# episode : 1235, done reward : 0.8000000268220901, total_step : 27476, cur_epsilon : 0.002
# episode : 1236, done reward : 0.40000002086162567, total_step : 27491, cur_epsilon : 0.002
# episode : 1237, done reward : 1.500000037252903, total_step : 27517, cur_epsilon : 0.002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[142], line 11
#       8 while True:
#      10     for stp in range(20):
# ---> 11         done_reward = agent.play_step()
#      12         if done_reward is not None:
#      13             print(f'episode : {episode}, done reward : {done_reward}, total_step : {agent._total_step}, cur_epsilon : {agent._epsilon}')
#
# File ~/.cache/pypoetry/virtualenvs/mlagent-learn-20-test-54-2MrXv-py3.9/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[107], line 67, in Agent.play_step(self, epsilon, sync_target)
#      64     action = mu_v.squeeze(dim=0).data.cpu().numpy()
#      65     action = np.clip(action, -1, 1)
# ---> 67 next_state, reward, is_done, _ = self._env.step(action)
#      68 self._total_reward += reward
#      70 bonus_reward = self._bonus_reward_factor * self._episode_steps
#
# Cell In[108], line 10, in UnityToGymNumpyWrapper.step(self, *args, **kwargs)
#       9 def step(self, *args, **kwargs):
# ---> 10     next_state, reward, is_done, info = super().step(*args, **kwargs)
#      11     return np.array(next_state[0]), reward, is_done, info
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/envs/unity_gym_env.py:200, in UnityToGymWrapper.step(self, action)
#     197     action_tuple.add_discrete(action)
#     198 self._env.set_actions(self.name, action_tuple)
# --> 200 self._env.step()
#     201 decision_step, terminal_step = self._env.get_steps(self.name)
#     202 self._check_agents(max(len(decision_step), len(terminal_step)))
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/timers.py:305, in timed.<locals>.wrapped(*args, **kwargs)
#     303 def wrapped(*args, **kwargs):
#     304     with hierarchical_timer(func.__qualname__):
# --> 305         return func(*args, **kwargs)
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/environment.py:348, in UnityEnvironment.step(self)
#     346 step_input = self._generate_step_input(self._env_actions)
#     347 with hierarchical_timer("communicator.exchange"):
# --> 348     outputs = self._communicator.exchange(step_input, self._poll_process)
#     349 if outputs is None:
#     350     raise UnityCommunicatorStoppedException("Communicator has exited.")
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/rpc_communicator.py:142, in RpcCommunicator.exchange(self, inputs, poll_callback)
#     140 message.unity_input.CopyFrom(inputs)
#     141 self.unity_to_external.parent_conn.send(message)
# --> 142 self.poll_for_timeout(poll_callback)
#     143 output = self.unity_to_external.parent_conn.recv()
#     144 if output.header.status != 200:
#
# File /mnt/d/Program Files/Unity/ml-agents-release_20/ml-agents-envs/mlagents_envs/rpc_communicator.py:106, in RpcCommunicator.poll_for_timeout(self, poll_callback)
#     104 callback_timeout_wait = self.timeout_wait // 10
#     105 while time.monotonic() < deadline:
# --> 106     if self.unity_to_external.parent_conn.poll(callback_timeout_wait):
#     107         # Got an acknowledgment from the connection
#     108         return
#     109     if poll_callback:
#     110         # Fire the callback - if it detects something wrong, it should raise an exception.
#
# File /usr/lib/python3.9/multiprocessing/connection.py:262, in _ConnectionBase.poll(self, timeout)
#     260 self._check_closed()
#     261 self._check_readable()
# --> 262 return self._poll(timeout)
#
# File /usr/lib/python3.9/multiprocessing/connection.py:429, in Connection._poll(self, timeout)
#     428 def _poll(self, timeout):
# --> 429     r = wait([self], timeout)
#     430     return bool(r)
#
# File /usr/lib/python3.9/multiprocessing/connection.py:936, in wait(object_list, timeout)
#     933     deadline = time.monotonic() + timeout
#     935 while True:
# --> 936     ready = selector.select(timeout)
#     937     if ready:
#     938         return [key.fileobj for (key, events) in ready]
#
# File /usr/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
plt.plot(reward_history)
plt.xlabel('episode')
plt.ylabel('episode total reward')
# Out:
# Text(0, 0.5, 'episode total reward')

# %%
plt.plot(reward_history)
plt.xlabel('episode')
plt.ylabel('episode total reward')
# Out:
# Text(0, 0.5, 'episode total reward')

# %%
plt.plot(spisode_steps_history)
plt.xlabel('episode')
plt.ylabel('episode steps')
# Out:
# Text(0, 0.5, 'episode steps')

# %%
env.close()
